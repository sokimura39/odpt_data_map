# %% [markdown]
# # Convert data to GeoJSON
#
# Use the data and convert to GeoJSON

# %% [markdown]
# ## Load Data
#
# Load all the required data

# %%
# import libraries
import os
import json

# %%
# set path
path_odpt = '../data/odpt_api/'
path_edit = '../data/edit/'

# create directory if not existing
os.makedirs(path_edit, exist_ok = True)

# load station data
with open(path_odpt + 'Station.json', 'r') as f:
    station_dict = json.load(f)

# load operator data
with open(path_odpt + 'Operator.json', 'r') as f:
    operator_dict = json.load(f)

# load railway data
with open(path_odpt + 'Railway.json', 'r') as f:
    railway_dict = json.load(f)

# %%
operator_dict
# Out:
# [{'@id': 'urn:ucode:_00001C000000000000010000030E660A',
#   '@type': 'odpt:Operator',
#   'dc:date': '2020-03-27T13:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東京臨海高速鉄道',
#   'owl:sameAs': 'odpt.Operator:TWR',
#   'odpt:operatorTitle': {'en': 'Tokyo Waterfront Area Rapid Transit',
#    'ja': '東京臨海高速鉄道'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003200322',
#   '@type': 'odpt:Operator',
#   'dc:date': '2019-04-22T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '全日本空輸',
#   'owl:sameAs': 'odpt.Operator:ANA',
#   'odpt:operatorTitle': {'en': 'All Nippon Airways', 'ja': '全日本空輸'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003230765',
#   '@type': 'odpt:Operator',
#   'dc:date': '2019-04-22T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '日本航空',
#   'owl:sameAs': 'odpt.Operator:JAL',
#   'odpt:operatorTitle': {'en': 'Japan Airlines', 'ja': '日本航空'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003395501',
#   '@type': 'odpt:Operator',
#   'dc:date': '2020-03-03T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '横浜市交通局',
#   'owl:sameAs': 'odpt.Operator:YokohamaMunicipal',
#   'odpt:operatorTitle': {'en': 'Transportation Bureau, City of Yokohama',
#    'ja': '横浜市交通局'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003464DAD',
#   '@type': 'odpt:Operator',
#   'dc:date': '2021-06-24T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '多摩都市モノレール',
#   'owl:sameAs': 'odpt.Operator:TamaMonorail',
#   'odpt:operatorTitle': {'en': 'Tokyo Tama Intercity Monorail',
#    'ja': '多摩都市モノレール'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6609',
#   '@type': 'odpt:Operator',
#   'dc:date': '2019-04-22T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東京都交通局',
#   'owl:sameAs': 'odpt.Operator:Toei',
#   'odpt:operatorTitle': {'en': 'Tokyo Metropolitan Bureau of Transportation',
#    'ja': '東京都交通局'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E796',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エア・ドゥ',
#   'owl:sameAs': 'odpt.Operator:ADO',
#   'odpt:operatorTitle': {'en': 'AIR DO', 'ja': 'エア・ドゥ'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E798',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エアージャパン',
#   'owl:sameAs': 'odpt.Operator:AJX',
#   'odpt:operatorTitle': {'en': 'Air Japan', 'ja': 'エアージャパン'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7AF',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'アイベックスエアラインズ',
#   'owl:sameAs': 'odpt.Operator:IBX',
#   'odpt:operatorTitle': {'en': 'IBEX Airlines', 'ja': 'アイベックスエアラインズ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032097E0',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'JR東海',
#   'owl:sameAs': 'odpt.Operator:JR-Central',
#   'odpt:operatorTitle': {'en': 'JR Central', 'ja': 'JR東海'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032BC85A',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '日本トランスオーシャン航空',
#   'owl:sameAs': 'odpt.Operator:JTA',
#   'odpt:operatorTitle': {'en': 'Japan Transocean Air', 'ja': '日本トランスオーシャン航空'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003792F74',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '関東鉄道',
#   'owl:sameAs': 'odpt.Operator:KantoRailway',
#   'odpt:operatorTitle': {'en': 'Kanto Railway', 'ja': '関東鉄道'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003208775',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '横浜高速鉄道',
#   'owl:sameAs': 'odpt.Operator:Minatomirai',
#   'odpt:operatorTitle': {'en': 'Yokohama Minatomirai Railway',
#    'ja': '横浜高速鉄道'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B3',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'オリエンタルエアブリッジ',
#   'owl:sameAs': 'odpt.Operator:ORC',
#   'odpt:operatorTitle': {'en': 'Oriental Air Bridge', 'ja': 'オリエンタルエアブリッジ'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B7',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'スターフライヤー',
#   'owl:sameAs': 'odpt.Operator:SFJ',
#   'odpt:operatorTitle': {'en': 'Star Flyer', 'ja': 'スターフライヤー'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B9',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ソラシドエア',
#   'owl:sameAs': 'odpt.Operator:SNJ',
#   'odpt:operatorTitle': {'en': 'Solaseed Air', 'ja': 'ソラシドエア'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003395500',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '相模鉄道',
#   'owl:sameAs': 'odpt.Operator:Sotetsu',
#   'odpt:operatorTitle': {'en': 'Sagami Railway', 'ja': '相模鉄道'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003208777',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東葉高速鉄道',
#   'owl:sameAs': 'odpt.Operator:ToyoRapid',
#   'odpt:operatorTitle': {'en': 'Toyo Rapid Railway', 'ja': '東葉高速鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032095FA',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '北総鉄道',
#   'owl:sameAs': 'odpt.Operator:Hokuso',
#   'odpt:operatorTitle': {'en': 'Hokuso Railway', 'ja': '北総鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6606',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'JR東日本',
#   'owl:sameAs': 'odpt.Operator:JR-East',
#   'odpt:operatorTitle': {'en': 'JR East', 'ja': 'JR東日本'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6605',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '京急電鉄',
#   'owl:sameAs': 'odpt.Operator:Keikyu',
#   'odpt:operatorTitle': {'en': 'Keikyu Corporation', 'ja': '京急電鉄'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6607',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '京王電鉄',
#   'owl:sameAs': 'odpt.Operator:Keio',
#   'odpt:operatorTitle': {'en': 'Keio Corporation', 'ja': '京王電鉄'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6604',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '京成電鉄',
#   'owl:sameAs': 'odpt.Operator:Keisei',
#   'odpt:operatorTitle': {'en': 'Keisei Electric Railway', 'ja': '京成電鉄'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6603',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '小田急電鉄',
#   'owl:sameAs': 'odpt.Operator:Odakyu',
#   'odpt:operatorTitle': {'en': 'Odakyu Electric Railway', 'ja': '小田急電鉄'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003208776',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '埼玉高速鉄道',
#   'owl:sameAs': 'odpt.Operator:SaitamaRailway',
#   'odpt:operatorTitle': {'en': 'Saitama Railway', 'ja': '埼玉高速鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6601',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '西武鉄道',
#   'owl:sameAs': 'odpt.Operator:Seibu',
#   'odpt:operatorTitle': {'en': 'Seibu Railway', 'ja': '西武鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032095FB',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '芝山鉄道',
#   'owl:sameAs': 'odpt.Operator:Shibayama',
#   'odpt:operatorTitle': {'en': 'Shibayama Railway', 'ja': '芝山鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E660B',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東武鉄道',
#   'owl:sameAs': 'odpt.Operator:Tobu',
#   'odpt:operatorTitle': {'en': 'Tobu Railway', 'ja': '東武鉄道'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003230767',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東京モノレール',
#   'owl:sameAs': 'odpt.Operator:TokyoMonorail',
#   'odpt:operatorTitle': {'en': 'Tokyo Monorail', 'ja': '東京モノレール'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6602',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-03-16T11:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東急電鉄',
#   'owl:sameAs': 'odpt.Operator:Tokyu',
#   'odpt:operatorTitle': {'en': 'Tokyu Corporation', 'ja': '東急電鉄'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003230641',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-06-20T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '小田急箱根',
#   'owl:sameAs': 'odpt.Operator:OdakyuHakone',
#   'odpt:operatorTitle': {'en': 'Odakyu Hakone', 'ja': '小田急箱根'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000320031C',
#   '@type': 'odpt:Operator',
#   'dc:date': '2019-04-22T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '京王バス',
#   'owl:sameAs': 'odpt.Operator:KeioBus',
#   'odpt:operatorTitle': {'en': 'Keio Bus', 'ja': '京王バス'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000320031E',
#   '@type': 'odpt:Operator',
#   'dc:date': '2019-04-22T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '西東京バス',
#   'owl:sameAs': 'odpt.Operator:NishiTokyoBus',
#   'odpt:operatorTitle': {'en': 'Nishi Tokyo Bus', 'ja': '西東京バス'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000320031F',
#   '@type': 'odpt:Operator',
#   'dc:date': '2019-04-22T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '小田急バス',
#   'owl:sameAs': 'odpt.Operator:OdakyuBus',
#   'odpt:operatorTitle': {'en': 'Odakyu Bus', 'ja': '小田急バス'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003200320',
#   '@type': 'odpt:Operator',
#   'dc:date': '2019-04-22T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '西武バス',
#   'owl:sameAs': 'odpt.Operator:SeibuBus',
#   'odpt:operatorTitle': {'en': 'Seibu Bus', 'ja': '西武バス'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032097E3',
#   '@type': 'odpt:Operator',
#   'dc:date': '2019-04-22T15:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東急バス',
#   'owl:sameAs': 'odpt.Operator:TokyuBus',
#   'odpt:operatorTitle': {'en': 'Tokyu Bus', 'ja': '東急バス'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000033822E6',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-02-07T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '相鉄バス',
#   'owl:sameAs': 'odpt.Operator:SotetsuBus',
#   'odpt:operatorTitle': {'en': 'Sotetsu Bus', 'ja': '相鉄バス'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003999521',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-06-19T14:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '江ノ島電鉄',
#   'owl:sameAs': 'odpt.Operator:Enoden',
#   'odpt:operatorTitle': {'en': 'Enoshima Electric Railway', 'ja': '江ノ島電鉄'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032097DE',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-06-19T14:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '伊豆箱根鉄道',
#   'owl:sameAs': 'odpt.Operator:IzuHakone',
#   'odpt:operatorTitle': {'en': 'IzuHakone Railway', 'ja': '伊豆箱根鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6608',
#   '@type': 'odpt:Operator',
#   'dc:date': '2021-06-24T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '首都圏新都市鉄道',
#   'owl:sameAs': 'odpt.Operator:MIR',
#   'odpt:operatorTitle': {'en': 'Metropolitan Intercity Railway',
#    'ja': '首都圏新都市鉄道'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000394F7C6',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-01-18T10:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '琉球エアーコミューター',
#   'owl:sameAs': 'odpt.Operator:RAC',
#   'odpt:operatorTitle': {'en': 'Ryukyu Air Commuter', 'ja': '琉球エアーコミューター'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000034B2F11',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ジップエア',
#   'owl:sameAs': 'odpt.Operator:TZP',
#   'odpt:operatorTitle': {'en': 'ZIPAIR', 'ja': 'ジップエア'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E6600',
#   '@type': 'odpt:Operator',
#   'dc:date': '2022-02-24T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東京メトロ',
#   'owl:sameAs': 'odpt.Operator:TokyoMetro',
#   'odpt:operatorTitle': {'en': 'Tokyo Metro', 'ja': '東京メトロ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000030E660C',
#   '@type': 'odpt:Operator',
#   'dc:date': '2020-03-27T13:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ゆりかもめ',
#   'owl:sameAs': 'odpt.Operator:Yurikamome',
#   'odpt:operatorTitle': {'en': 'Yurikamome', 'ja': 'ゆりかもめ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032095F8',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-12T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '会津鉄道',
#   'owl:sameAs': 'odpt.Operator:Aizu',
#   'odpt:operatorTitle': {'en': 'Aizu Railway', 'ja': '会津鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032095F9',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-12T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '秩父鉄道',
#   'owl:sameAs': 'odpt.Operator:Chichibu',
#   'odpt:operatorTitle': {'en': 'Chichibu Railway', 'ja': '秩父鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032095FC',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-12T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '新京成電鉄',
#   'owl:sameAs': 'odpt.Operator:ShinKeisei',
#   'odpt:operatorTitle': {'en': 'Shinkeisei Electric Railway', 'ja': '新京成電鉄'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032095FD',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-12T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '野岩鉄道',
#   'owl:sameAs': 'odpt.Operator:Yagan',
#   'odpt:operatorTitle': {'en': 'Yagantetsudo Railway', 'ja': '野岩鉄道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000039A3733',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-12T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '上毛電鉄',
#   'owl:sameAs': 'odpt.Operator:Jomo',
#   'odpt:operatorTitle': {'en': 'Jomo Electric Railway', 'ja': '上毛電鉄'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000039A3734',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-12T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '埼玉新都市交通',
#   'owl:sameAs': 'odpt.Operator:SaitamaTransit',
#   'odpt:operatorTitle': {'en': 'Saitama New Urban Transit', 'ja': '埼玉新都市交通'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000039A3735',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-12T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'わたらせ渓谷鐵道',
#   'owl:sameAs': 'odpt.Operator:WataraseKeikoku',
#   'odpt:operatorTitle': {'en': 'Watarase Keikoku Railway', 'ja': 'わたらせ渓谷鐵道'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000039A3736',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-12T16:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '横浜シーサイドライン',
#   'owl:sameAs': 'odpt.Operator:YokohamaSeaside',
#   'odpt:operatorTitle': {'ja': '横浜シーサイドライン'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E793',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'アメリカン航空',
#   'owl:sameAs': 'odpt.Operator:AAL',
#   'odpt:operatorTitle': {'en': 'American Airlines', 'ja': 'アメリカン航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E794',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'アシアナ航空',
#   'owl:sameAs': 'odpt.Operator:AAR',
#   'odpt:operatorTitle': {'en': 'Asiana Airlines', 'ja': 'アシアナ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F1',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エアプサン',
#   'owl:sameAs': 'odpt.Operator:ABL',
#   'odpt:operatorTitle': {'en': 'Air Busan', 'ja': 'エアプサン'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E795',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エア・カナダ',
#   'owl:sameAs': 'odpt.Operator:ACA',
#   'odpt:operatorTitle': {'en': 'Air Canada', 'ja': 'エア・カナダ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F2',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エアカラン',
#   'owl:sameAs': 'odpt.Operator:ACI',
#   'odpt:operatorTitle': {'en': 'Aircalin', 'ja': 'エアカラン'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F3',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'アエロフロート',
#   'owl:sameAs': 'odpt.Operator:AFL',
#   'odpt:operatorTitle': {'en': 'Aeroflot', 'ja': 'アエロフロート'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E797',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エールフランス航空',
#   'owl:sameAs': 'odpt.Operator:AFR',
#   'odpt:operatorTitle': {'en': 'Air France', 'ja': 'エールフランス航空'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003305FC9',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'アンガラ航空',
#   'owl:sameAs': 'odpt.Operator:AGU',
#   'odpt:operatorTitle': {'en': 'Angara Airlines', 'ja': 'アンガラ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F4',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エア・インディア',
#   'owl:sameAs': 'odpt.Operator:AIC',
#   'odpt:operatorTitle': {'en': 'Air India', 'ja': 'エア・インディア'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E799',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ANAウイングス',
#   'owl:sameAs': 'odpt.Operator:AKX',
#   'odpt:operatorTitle': {'en': 'ANA Wings', 'ja': 'ANAウイングス'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17B7',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'スリランカ航空',
#   'owl:sameAs': 'odpt.Operator:ALK',
#   'odpt:operatorTitle': {'en': 'SriLankan Airlines', 'ja': 'スリランカ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17B8',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'マカオ航空',
#   'owl:sameAs': 'odpt.Operator:AMU',
#   'odpt:operatorTitle': {'en': 'Air Macau', 'ja': 'マカオ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F5',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'アエロメヒコ',
#   'owl:sameAs': 'odpt.Operator:AMX',
#   'odpt:operatorTitle': {'en': 'AeroMexico', 'ja': 'アエロメヒコ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E180D',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ニューギニア航空',
#   'owl:sameAs': 'odpt.Operator:ANG',
#   'odpt:operatorTitle': {'en': 'Air Niugini', 'ja': 'ニューギニア航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E79A',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ニュージーランド航空',
#   'owl:sameAs': 'odpt.Operator:ANZ',
#   'odpt:operatorTitle': {'en': 'Air New Zealand', 'ja': 'ニュージーランド航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E79B',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'Peach Aviation',
#   'owl:sameAs': 'odpt.Operator:APJ',
#   'odpt:operatorTitle': {'en': 'Peach Aviation', 'ja': 'Peach Aviation'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000039AB8E7',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'アラスカ航空',
#   'owl:sameAs': 'odpt.Operator:ASA',
#   'odpt:operatorTitle': {'en': 'Alaska Airlines', 'ja': 'アラスカ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F6',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エアソウル',
#   'owl:sameAs': 'odpt.Operator:ASV',
#   'odpt:operatorTitle': {'en': 'Air Seoul', 'ja': 'エアソウル'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003303F69',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'オーストリア航空',
#   'owl:sameAs': 'odpt.Operator:AUA',
#   'odpt:operatorTitle': {'en': 'Austrian Airlines', 'ja': 'オーストリア航空'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003504DA1',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'バンブー・エアウェイズ',
#   'owl:sameAs': 'odpt.Operator:BAV',
#   'odpt:operatorTitle': {'en': 'Bamboo Airways', 'ja': 'バンブー・エアウェイズ'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E79C',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ブリティッシュ・エアウェイズ',
#   'owl:sameAs': 'odpt.Operator:BAW',
#   'odpt:operatorTitle': {'en': 'British Airways', 'ja': 'ブリティッシュ・エアウェイズ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000034886F7',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ビーマン・バングラデシュ航空',
#   'owl:sameAs': 'odpt.Operator:BBC',
#   'odpt:operatorTitle': {'en': 'Biman Bangladesh Airlines',
#    'ja': 'ビーマン・バングラデシュ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17BA',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'バンコク・エアウェイズ',
#   'owl:sameAs': 'odpt.Operator:BKP',
#   'odpt:operatorTitle': {'en': 'Bangkok Airways', 'ja': 'バンコク・エアウェイズ'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E79D',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'チャイナエアライン',
#   'owl:sameAs': 'odpt.Operator:CAL',
#   'odpt:operatorTitle': {'en': 'China Airlines', 'ja': 'チャイナエアライン'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E79E',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '中国国際航空',
#   'owl:sameAs': 'odpt.Operator:CCA',
#   'odpt:operatorTitle': {'en': 'Air China', 'ja': '中国国際航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17BB',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '山東航空',
#   'owl:sameAs': 'odpt.Operator:CDG',
#   'odpt:operatorTitle': {'en': 'Shandong Airlines', 'ja': '山東航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F7',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'セブパシフィック',
#   'owl:sameAs': 'odpt.Operator:CEB',
#   'odpt:operatorTitle': {'en': 'Cebu Pacific', 'ja': 'セブパシフィック'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E79F',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '中国東方航空',
#   'owl:sameAs': 'odpt.Operator:CES',
#   'odpt:operatorTitle': {'en': 'China Eastern Airlines', 'ja': '中国東方航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A0',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '海南航空',
#   'owl:sameAs': 'odpt.Operator:CHH',
#   'odpt:operatorTitle': {'en': 'Hainan Airlines', 'ja': '海南航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A1',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'キャセイパシフィック航空',
#   'owl:sameAs': 'odpt.Operator:CPA',
#   'odpt:operatorTitle': {'en': 'Cathay Pacific Airways',
#    'ja': 'キャセイパシフィック航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A2',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '春秋航空',
#   'owl:sameAs': 'odpt.Operator:CQH',
#   'odpt:operatorTitle': {'en': 'Spring Airlines', 'ja': '春秋航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F8',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '香港航空',
#   'owl:sameAs': 'odpt.Operator:CRK',
#   'odpt:operatorTitle': {'en': 'Hong Kong Airlines', 'ja': '香港航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17F9',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '四川航空',
#   'owl:sameAs': 'odpt.Operator:CSC',
#   'odpt:operatorTitle': {'en': 'Sichuan Airlines', 'ja': '四川航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A3',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '上海航空',
#   'owl:sameAs': 'odpt.Operator:CSH',
#   'odpt:operatorTitle': {'en': 'Shanghai Airlines', 'ja': '上海航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A4',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '中国南方航空',
#   'owl:sameAs': 'odpt.Operator:CSN',
#   'odpt:operatorTitle': {'en': 'China Southern Airlines', 'ja': '中国南方航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17FA',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '深圳航空',
#   'owl:sameAs': 'odpt.Operator:CSZ',
#   'odpt:operatorTitle': {'en': 'Shenzhen Airlines', 'ja': '深圳航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17BC',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '厦門航空',
#   'owl:sameAs': 'odpt.Operator:CXA',
#   'odpt:operatorTitle': {'en': 'Xiamen Airlines', 'ja': '厦門航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A5',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'デルタ航空',
#   'owl:sameAs': 'odpt.Operator:DAL',
#   'odpt:operatorTitle': {'en': 'Delta Air Lines', 'ja': 'デルタ航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A6',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '吉祥航空',
#   'owl:sameAs': 'odpt.Operator:DKH',
#   'odpt:operatorTitle': {'en': 'Juneyao Airlines', 'ja': '吉祥航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A7',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ルフトハンザ・ドイツ航空',
#   'owl:sameAs': 'odpt.Operator:DLH',
#   'odpt:operatorTitle': {'en': 'Lufthansa German Airlines',
#    'ja': 'ルフトハンザ・ドイツ航空'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003289F7A',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'イースター航空',
#   'owl:sameAs': 'odpt.Operator:ESR',
#   'odpt:operatorTitle': {'en': 'Easter Jet', 'ja': 'イースター航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17BD',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エティハド航空',
#   'owl:sameAs': 'odpt.Operator:ETD',
#   'odpt:operatorTitle': {'en': 'Etihad Airways', 'ja': 'エティハド航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17BE',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エチオピア航空',
#   'owl:sameAs': 'odpt.Operator:ETH',
#   'odpt:operatorTitle': {'en': 'Ethiopian Airlines', 'ja': 'エチオピア航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A8',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エバー航空',
#   'owl:sameAs': 'odpt.Operator:EVA',
#   'odpt:operatorTitle': {'en': 'EVA Airways', 'ja': 'エバー航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E6264',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'フジドリームエアラインズ',
#   'owl:sameAs': 'odpt.Operator:FDA',
#   'odpt:operatorTitle': {'en': 'Fuji Dream Airlines', 'ja': 'フジドリームエアラインズ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E180E',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ファイアフライ',
#   'owl:sameAs': 'odpt.Operator:FFM',
#   'odpt:operatorTitle': {'en': 'Firefly', 'ja': 'ファイアフライ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17BF',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'フィンエアー',
#   'owl:sameAs': 'odpt.Operator:FIN',
#   'odpt:operatorTitle': {'en': 'Finnair', 'ja': 'フィンエアー'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C0',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'フィジー・エアウェイズ',
#   'owl:sameAs': 'odpt.Operator:FJI',
#   'odpt:operatorTitle': {'en': 'Fiji Airways', 'ja': 'フィジー・エアウェイズ'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7A9',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '天津航空',
#   'owl:sameAs': 'odpt.Operator:GCR',
#   'odpt:operatorTitle': {'en': 'TianJin Airlines', 'ja': '天津航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7AA',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ガルーダ・インドネシア航空',
#   'owl:sameAs': 'odpt.Operator:GIA',
#   'odpt:operatorTitle': {'en': 'Garuda Indonesia', 'ja': 'ガルーダ・インドネシア航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7AB',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ハワイアン航空',
#   'owl:sameAs': 'odpt.Operator:HAL',
#   'odpt:operatorTitle': {'en': 'Hawaiian Airlines', 'ja': 'ハワイアン航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7AC',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'キャセイドラゴン航空',
#   'owl:sameAs': 'odpt.Operator:HDA',
#   'odpt:operatorTitle': {'en': 'Cathay Dragon', 'ja': 'キャセイドラゴン航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7AD',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '香港エクスプレス航空',
#   'owl:sameAs': 'odpt.Operator:HKE',
#   'odpt:operatorTitle': {'en': 'Hong Kong Express Airways',
#    'ja': '香港エクスプレス航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032BC859',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '日本空港ビルデング',
#   'owl:sameAs': 'odpt.Operator:HND-JAT',
#   'odpt:operatorTitle': {'en': 'Japan Airport Terminal', 'ja': '日本空港ビルデング'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003230764',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東京国際空港ターミナル',
#   'owl:sameAs': 'odpt.Operator:HND-TIAT',
#   'odpt:operatorTitle': {'en': 'Tokyo International Air Terminal',
#    'ja': '東京国際空港ターミナル'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7AE',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ベトナム航空',
#   'owl:sameAs': 'odpt.Operator:HVN',
#   'odpt:operatorTitle': {'en': 'Vietnam Airlines', 'ja': 'ベトナム航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17FB',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'イベリア航空',
#   'owl:sameAs': 'odpt.Operator:IBE',
#   'odpt:operatorTitle': {'en': 'Iberia', 'ja': 'イベリア航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000344DF82',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'アイスランド航空',
#   'owl:sameAs': 'odpt.Operator:ICE',
#   'odpt:operatorTitle': {'en': 'Icelandair', 'ja': 'アイスランド航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17FC',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'インドネシア・エアアジアX',
#   'owl:sameAs': 'odpt.Operator:IDX',
#   'odpt:operatorTitle': {'en': 'Indonesia AirAsia X', 'ja': 'インドネシア・エアアジアX'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17B9',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ITAエアウェイズ',
#   'owl:sameAs': 'odpt.Operator:ITY',
#   'odpt:operatorTitle': {'en': 'ITA Airways', 'ja': 'ITAエアウェイズ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E62A3',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '日本エアコミューター',
#   'owl:sameAs': 'odpt.Operator:JAC',
#   'odpt:operatorTitle': {'en': 'Japan Air Commuter', 'ja': '日本エアコミューター'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C1',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ジェットエアウェイズ',
#   'owl:sameAs': 'odpt.Operator:JAI',
#   'odpt:operatorTitle': {'en': 'Jet Airways', 'ja': 'ジェットエアウェイズ'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B0',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'チェジュ航空',
#   'owl:sameAs': 'odpt.Operator:JJA',
#   'odpt:operatorTitle': {'en': 'Jeju Air', 'ja': 'チェジュ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C2',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ジェットスター・ジャパン',
#   'owl:sameAs': 'odpt.Operator:JJP',
#   'odpt:operatorTitle': {'en': 'Jetstar Japan', 'ja': 'ジェットスター・ジャパン'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17FD',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ジンエアー',
#   'owl:sameAs': 'odpt.Operator:JNA',
#   'odpt:operatorTitle': {'en': 'Jin Air', 'ja': 'ジンエアー'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17FE',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ジェットスター航空',
#   'owl:sameAs': 'odpt.Operator:JST',
#   'odpt:operatorTitle': {'en': 'Jetstar Airways', 'ja': 'ジェットスター航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B1',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '大韓航空',
#   'owl:sameAs': 'odpt.Operator:KAL',
#   'odpt:operatorTitle': {'en': 'Korean Air', 'ja': '大韓航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C3',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'KLMオランダ航空',
#   'owl:sameAs': 'odpt.Operator:KLM',
#   'odpt:operatorTitle': {'en': 'KLM Dutch Airlines', 'ja': 'KLMオランダ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C4',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'LATAMチリ',
#   'owl:sameAs': 'odpt.Operator:LAN',
#   'odpt:operatorTitle': {'en': 'LATAM Airlines Chile', 'ja': 'LATAMチリ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C5',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'LOTポーランド航空',
#   'owl:sameAs': 'odpt.Operator:LOT',
#   'odpt:operatorTitle': {'en': 'LOT Polish Airlines', 'ja': 'LOTポーランド航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C6',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'マレーシア航空',
#   'owl:sameAs': 'odpt.Operator:MAS',
#   'odpt:operatorTitle': {'en': 'Malaysia Airlines', 'ja': 'マレーシア航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17FF',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'マンダリン航空',
#   'owl:sameAs': 'odpt.Operator:MDA',
#   'odpt:operatorTitle': {'en': 'Mandarin Airlines', 'ja': 'マンダリン航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1800',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'MIATモンゴル航空',
#   'owl:sameAs': 'odpt.Operator:MGL',
#   'odpt:operatorTitle': {'en': 'MIAT Mongolian Airlines', 'ja': 'MIATモンゴル航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E180F',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エジプト航空',
#   'owl:sameAs': 'odpt.Operator:MSR',
#   'odpt:operatorTitle': {'en': 'EgyptAir', 'ja': 'エジプト航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E62A4',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'マリンド・エア',
#   'owl:sameAs': 'odpt.Operator:MXD',
#   'odpt:operatorTitle': {'en': 'Malindo Air', 'ja': 'マリンド・エア'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C7',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '成田国際空港',
#   'owl:sameAs': 'odpt.Operator:NAA',
#   'odpt:operatorTitle': {'en': 'Narita International Airport Corporation',
#    'ja': '成田国際空港'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1801',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ノックスクート',
#   'owl:sameAs': 'odpt.Operator:NCT',
#   'odpt:operatorTitle': {'en': 'NokScoot', 'ja': 'ノックスクート'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B2',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '奥凱航空',
#   'owl:sameAs': 'odpt.Operator:OKA',
#   'odpt:operatorTitle': {'en': 'Okay Airways', 'ja': '奥凱航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B4',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'フィリピン航空',
#   'owl:sameAs': 'odpt.Operator:PAL',
#   'odpt:operatorTitle': {'en': 'Philippine Airlines', 'ja': 'フィリピン航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1802',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'パキスタン国際航空',
#   'owl:sameAs': 'odpt.Operator:PIA',
#   'odpt:operatorTitle': {'en': 'Pakistan International Airlines',
#    'ja': 'パキスタン国際航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000034C4F11',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '青島航空',
#   'owl:sameAs': 'odpt.Operator:QDA',
#   'odpt:operatorTitle': {'en': 'Qingdao Airlines', 'ja': '青島航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B5',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'カンタス航空',
#   'owl:sameAs': 'odpt.Operator:QFA',
#   'odpt:operatorTitle': {'en': 'Qantas Airways', 'ja': 'カンタス航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B6',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'カタール航空',
#   'owl:sameAs': 'odpt.Operator:QTR',
#   'odpt:operatorTitle': {'en': 'Qatar Airways', 'ja': 'カタール航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1810',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ロイヤルブルネイ航空',
#   'owl:sameAs': 'odpt.Operator:RBA',
#   'odpt:operatorTitle': {'en': 'Royal Brunei Airlines', 'ja': 'ロイヤルブルネイ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000034659C8',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ネパール航空',
#   'owl:sameAs': 'odpt.Operator:RNA',
#   'odpt:operatorTitle': {'en': 'Nepal Airlines', 'ja': 'ネパール航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C8',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '南アフリカ航空',
#   'owl:sameAs': 'odpt.Operator:SAA',
#   'odpt:operatorTitle': {'en': 'South African Airways', 'ja': '南アフリカ航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17C9',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'スカンジナビア航空',
#   'owl:sameAs': 'odpt.Operator:SAS',
#   'odpt:operatorTitle': {'en': 'Scandinavian Airlines System',
#    'ja': 'スカンジナビア航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1803',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'S7航空',
#   'owl:sameAs': 'odpt.Operator:SBI',
#   'odpt:operatorTitle': {'en': 'S7 Airlines', 'ja': 'S7航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1804',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'オーロラ',
#   'owl:sameAs': 'odpt.Operator:SHU',
#   'odpt:operatorTitle': {'en': 'Aurora', 'ja': 'オーロラ'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7B8',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'シンガポール航空',
#   'owl:sameAs': 'odpt.Operator:SIA',
#   'odpt:operatorTitle': {'en': 'Singapore Airlines', 'ja': 'シンガポール航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1805',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '春秋航空日本',
#   'owl:sameAs': 'odpt.Operator:SJO',
#   'odpt:operatorTitle': {'en': 'Spring Airlines Japan', 'ja': '春秋航空日本'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003529FF0',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'スターラックス航空',
#   'owl:sameAs': 'odpt.Operator:SJX',
#   'odpt:operatorTitle': {'en': 'Starlux Airlines', 'ja': 'スターラックス航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032BC85B',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'スカイマーク',
#   'owl:sameAs': 'odpt.Operator:SKY',
#   'odpt:operatorTitle': {'en': 'Skymark Airlines', 'ja': 'スカイマーク'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1806',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'スイスインターナショナルエアラインズ',
#   'owl:sameAs': 'odpt.Operator:SWR',
#   'odpt:operatorTitle': {'en': 'Swiss Internatilnal Air Lines',
#    'ja': 'スイスインターナショナルエアラインズ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1807',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ヤクーツク航空',
#   'owl:sameAs': 'odpt.Operator:SYL',
#   'odpt:operatorTitle': {'en': 'Yakutia Airlines', 'ja': 'ヤクーツク航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17CA',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'LATAMブラジル',
#   'owl:sameAs': 'odpt.Operator:TAM',
#   'odpt:operatorTitle': {'en': 'LATAM Airlines Brazil', 'ja': 'LATAMブラジル'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1808',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'タイ・エアアジアX',
#   'owl:sameAs': 'odpt.Operator:TAX',
#   'odpt:operatorTitle': {'en': 'Thai Airasia X', 'ja': 'タイ・エアアジアX'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1809',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'スクート',
#   'owl:sameAs': 'odpt.Operator:TGW',
#   'odpt:operatorTitle': {'en': 'Scoot', 'ja': 'スクート'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7BA',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'タイ国際航空',
#   'owl:sameAs': 'odpt.Operator:THA',
#   'odpt:operatorTitle': {'en': 'Thai Airways International', 'ja': 'タイ国際航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E180A',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エアタヒチヌイ',
#   'owl:sameAs': 'odpt.Operator:THT',
#   'odpt:operatorTitle': {'en': 'Air Tahiti Nui', 'ja': 'エアタヒチヌイ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17CB',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ターキッシュ・エアラインズ',
#   'owl:sameAs': 'odpt.Operator:THY',
#   'odpt:operatorTitle': {'en': 'Turkish Airlines', 'ja': 'ターキッシュ・エアラインズ'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E180B',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'タイ・ライオン・エア',
#   'owl:sameAs': 'odpt.Operator:TLM',
#   'odpt:operatorTitle': {'en': 'Thai Lion Air', 'ja': 'タイ・ライオン・エア'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7BB',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'タイガーエア台湾',
#   'owl:sameAs': 'odpt.Operator:TTW',
#   'odpt:operatorTitle': {'en': 'Tigerair Taiwan', 'ja': 'タイガーエア台湾'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E180C',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ティーウェイ航空',
#   'owl:sameAs': 'odpt.Operator:TWB',
#   'odpt:operatorTitle': {'en': "T'Way Airlines", 'ja': 'ティーウェイ航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7BC',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エミレーツ航空',
#   'owl:sameAs': 'odpt.Operator:UAE',
#   'odpt:operatorTitle': {'en': 'Emirates', 'ja': 'エミレーツ航空'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7BD',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ユナイテッド航空',
#   'owl:sameAs': 'odpt.Operator:UAL',
#   'odpt:operatorTitle': {'en': 'United Airlines', 'ja': 'ユナイテッド航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E62A5',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ウズベキスタン航空',
#   'owl:sameAs': 'odpt.Operator:UZB',
#   'odpt:operatorTitle': {'en': 'Uzbekistan Airways', 'ja': 'ウズベキスタン航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032EEA76',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ベトジェットエア',
#   'owl:sameAs': 'odpt.Operator:VJC',
#   'odpt:operatorTitle': {'en': 'Vietjet Air', 'ja': 'ベトジェットエア'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E17CC',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'バニラ・エア',
#   'owl:sameAs': 'odpt.Operator:VNL',
#   'odpt:operatorTitle': {'en': 'Vanilla Air', 'ja': 'バニラ・エア'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000032E1811',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ヴァージン・オーストラリア',
#   'owl:sameAs': 'odpt.Operator:VOZ',
#   'odpt:operatorTitle': {'en': 'Virgin Australia', 'ja': 'ヴァージン・オーストラリア'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003379DEE',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'SCAT航空',
#   'owl:sameAs': 'odpt.Operator:VSV',
#   'odpt:operatorTitle': {'en': 'SCAT Airlines', 'ja': 'SCAT航空'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000034659C9',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ビスタラ',
#   'owl:sameAs': 'odpt.Operator:VTI',
#   'odpt:operatorTitle': {'en': 'Vistara', 'ja': 'ビスタラ'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327E7BE',
#   '@type': 'odpt:Operator',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'エアアジアＸ',
#   'owl:sameAs': 'odpt.Operator:XAX',
#   'odpt:operatorTitle': {'en': 'AirAsia X', 'ja': 'エアアジアＸ'}}]

# %% [markdown]
# ## Convert Station to GeoJSON
#
# Using the coordinates, change station data to GeoJSON

# %%
# initialise GeoJSON
station_geojson = {
    'type': 'FeatureCollection',
    'features': []
}

# add stations to GeoJSON
for s in station_dict:
    # only do this if location data is not missing
    try:
        feature = {
            'type': 'Feature',
            'geometry': {
                'type': 'Point',
                'coordinates': [s['geo:long'], s['geo:lat']]
            },
            'properties': {
                'id': s['owl:sameAs'],
                'name': s['dc:title'],
            }
        }
        
        # add the features - they can be optional (especially the station code)
        for c in ['odpt:railway', 'odpt:operator', 'odpt:stationCode']:
            if c in s:
                feature['properties'][c] = s[c]
        
        # add railway info
        railway_name = [d['dc:title'] for d in railway_dict if d['owl:sameAs'] == s['odpt:railway']][0]
        feature['properties']['railway_name'] = railway_name        

        # add operator info
        operator_name = [d['dc:title'] for d in operator_dict if d['owl:sameAs'] == s['odpt:operator']][0]
        feature['properties']['operator_name'] = operator_name
        
        # add to dictionary
        station_geojson['features'].append(feature)

    # if feature is missing ignore
    except:
        pass

# %%
len(station_geojson['features'])
# Out:
# 1029

# %%
station_dict
# Out:
# [{'@id': 'urn:ucode:_00001C00000000000001000003102AB7',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.34812,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '藤沢本町',
#   'geo:long': 139.47601,
#   'owl:sameAs': 'odpt.Station:Odakyu.Enoshima.FujisawaHommachi',
#   'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#   'odpt:operator': 'odpt.Operator:Odakyu',
#   'odpt:stationCode': 'OE12',
#   'odpt:stationTitle': {'en': 'Fujisawa-Hommachi', 'ja': '藤沢本町'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Odakyu.FujisawaHommachi'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Odakyu.Enoshima.FujisawaHommachi.Inbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.FujisawaHommachi.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Odakyu.Enoshima.FujisawaHommachi.Outbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.FujisawaHommachi.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102AB8',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.33859,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '藤沢',
#   'geo:long': 139.48764,
#   'owl:sameAs': 'odpt.Station:Odakyu.Enoshima.Fujisawa',
#   'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#   'odpt:operator': 'odpt.Operator:Odakyu',
#   'odpt:stationCode': 'OE13',
#   'odpt:stationTitle': {'en': 'Fujisawa', 'ja': '藤沢'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Odakyu.Fujisawa'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Odakyu.Enoshima.Fujisawa.Inbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Fujisawa.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Fujisawa.Outbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Fujisawa.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Enoden.Enoden',
#    'odpt.Railway:JR-East.Tokaido'],
#   'odpt:connectingStation': ['odpt.Station:Enoden.Enoden.Fujisawa',
#    'odpt.Station:JR-East.Tokaido.Fujisawa']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102918',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '菊名',
#   'owl:sameAs': 'odpt.Station:JR-East.Yokohama.Kikuna',
#   'odpt:railway': 'odpt.Railway:JR-East.Yokohama',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Kikuna', 'ja': '菊名'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102AB5',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.38358,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '六会日大前',
#   'geo:long': 139.47083,
#   'owl:sameAs': 'odpt.Station:Odakyu.Enoshima.MutsuaiNichidaiMae',
#   'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#   'odpt:operator': 'odpt.Operator:Odakyu',
#   'odpt:stationCode': 'OE10',
#   'odpt:stationTitle': {'en': 'Mutsuai-Nichidai-Mae', 'ja': '六会日大前'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Odakyu.MutsuaiNichidaiMae'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Odakyu.Enoshima.MutsuaiNichidaiMae.Inbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.MutsuaiNichidaiMae.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Odakyu.Enoshima.MutsuaiNichidaiMae.Outbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.MutsuaiNichidaiMae.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102AB6',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.36279,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '善行',
#   'geo:long': 139.47325,
#   'owl:sameAs': 'odpt.Station:Odakyu.Enoshima.Zengyo',
#   'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#   'odpt:operator': 'odpt.Operator:Odakyu',
#   'odpt:stationCode': 'OE11',
#   'odpt:stationTitle': {'en': 'Zengyo', 'ja': '善行'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Odakyu.Zengyo'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Odakyu.Enoshima.Zengyo.Inbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Zengyo.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Zengyo.Outbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Zengyo.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102413',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.41764,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '愛甲石田',
#   'geo:long': 139.34394,
#   'owl:sameAs': 'odpt.Station:Odakyu.Odawara.AikoIshida',
#   'odpt:railway': 'odpt.Railway:Odakyu.Odawara',
#   'odpt:operator': 'odpt.Operator:Odakyu',
#   'odpt:stationCode': 'OH35',
#   'odpt:stationTitle': {'en': 'Aiko-Ishida', 'ja': '愛甲石田'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Odakyu.AikoIshida'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Odakyu.Odawara.AikoIshida.Inbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Odawara.AikoIshida.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Odakyu.Odawara.AikoIshida.Outbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Odawara.AikoIshida.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C000000000000010000031027E1',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '飯田橋',
#   'owl:sameAs': 'odpt.Station:JR-East.ChuoSobuLocal.Iidabashi',
#   'odpt:railway': 'odpt.Railway:JR-East.ChuoSobuLocal',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Iidabashi', 'ja': '飯田橋'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003999525',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '小田原',
#   'owl:sameAs': 'odpt.Station:OdakyuHakone.HakoneTozan.Odawara',
#   'odpt:railway': 'odpt.Railway:OdakyuHakone.HakoneTozan',
#   'odpt:operator': 'odpt.Operator:OdakyuHakone',
#   'odpt:stationTitle': {'en': 'Odawara', 'ja': '小田原'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102AC0',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.62987,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '小田急永山',
#   'geo:long': 139.4483,
#   'owl:sameAs': 'odpt.Station:Odakyu.Tama.OdakyuNagayama',
#   'odpt:railway': 'odpt.Railway:Odakyu.Tama',
#   'odpt:operator': 'odpt.Operator:Odakyu',
#   'odpt:stationCode': 'OT05',
#   'odpt:stationTitle': {'en': 'Odakyu-Nagayama', 'ja': '小田急永山'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Odakyu.OdakyuNagayama'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Odakyu.Tama.OdakyuNagayama.Inbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Tama.OdakyuNagayama.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Odakyu.Tama.OdakyuNagayama.Outbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Tama.OdakyuNagayama.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Keio.Sagamihara'],
#   'odpt:connectingStation': ['odpt.Station:Keio.Sagamihara.KeioNagayama']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465857',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.6995,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '立川北',
#   'geo:long': 139.4127,
#   'owl:sameAs': 'odpt.Station:TamaMonorail.TamaMonorail.TachikawaKita',
#   'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#   'odpt:operator': 'odpt.Operator:TamaMonorail',
#   'odpt:stationCode': 'TT12',
#   'odpt:stationTitle': {'en': 'Tachikawa-Kita', 'ja': '立川北'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TamaMonorail.TachikawaKita'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TamaMonorail.TamaMonorail.TachikawaKita.Southbound.Weekday',
#    'odpt.StationTimetable:TamaMonorail.TamaMonorail.TachikawaKita.Southbound.SaturdayHoliday',
#    'odpt.StationTimetable:TamaMonorail.TamaMonorail.TachikawaKita.Northbound.Weekday',
#    'odpt.StationTimetable:TamaMonorail.TamaMonorail.TachikawaKita.Northbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.ChuoRapid',
#    'odpt.Railway:JR-East.Nambu',
#    'odpt.Railway:JR-East.Ome'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.ChuoRapid.Tachikawa',
#    'odpt.Station:JR-East.Nambu.Tachikawa',
#    'odpt.Station:JR-East.Ome.Tachikawa']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003395506',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.568022,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'あざみ野',
#   'geo:long': 139.553876,
#   'owl:sameAs': 'odpt.Station:YokohamaMunicipal.Blue.Azamino',
#   'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#   'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#   'odpt:stationCode': 'B32',
#   'odpt:stationTitle': {'en': 'Azamino', 'ja': 'あざみ野'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:YokohamaMunicipal.Azamino'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:YokohamaMunicipal.Blue.Azamino.Outbound.Weekday',
#    'odpt.StationTimetable:YokohamaMunicipal.Blue.Azamino.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Tokyu.DenEnToshi'],
#   'odpt:connectingStation': ['odpt.Station:Tokyu.DenEnToshi.Azamino']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003395508',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.553383,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'センター北',
#   'geo:long': 139.579045,
#   'owl:sameAs': 'odpt.Station:YokohamaMunicipal.Blue.CenterKita',
#   'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#   'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#   'odpt:stationCode': 'B30',
#   'odpt:stationTitle': {'en': 'Center Kita', 'ja': 'センター北'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:YokohamaMunicipal.Blue.CenterKita'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:YokohamaMunicipal.Blue.CenterKita.Outbound.Weekday',
#    'odpt.StationTimetable:YokohamaMunicipal.Blue.CenterKita.Outbound.SaturdayHoliday',
#    'odpt.StationTimetable:YokohamaMunicipal.Blue.CenterKita.Inbound.Weekday',
#    'odpt.StationTimetable:YokohamaMunicipal.Blue.CenterKita.Inbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:YokohamaMunicipal.Green'],
#   'odpt:connectingStation': ['odpt.Station:YokohamaMunicipal.Green.CenterKita']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102637',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '新橋',
#   'owl:sameAs': 'odpt.Station:JR-East.KeihinTohokuNegishi.Shimbashi',
#   'odpt:railway': 'odpt.Railway:JR-East.KeihinTohokuNegishi',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Shimbashi', 'ja': '新橋'}},
#  {'@id': 'urn:ucode:_00001C000000000000010000031026E8',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '渋谷',
#   'owl:sameAs': 'odpt.Station:JR-East.ShonanShinjuku.Shibuya',
#   'odpt:railway': 'odpt.Railway:JR-East.ShonanShinjuku',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Shibuya', 'ja': '渋谷'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102640',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '西日暮里',
#   'owl:sameAs': 'odpt.Station:JR-East.KeihinTohokuNegishi.NishiNippori',
#   'odpt:railway': 'odpt.Railway:JR-East.KeihinTohokuNegishi',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Nishi-Nippori', 'ja': '西日暮里'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B31',
#   '@type': 'odpt:Station',
#   'dc:date': '2021-06-21T14:00:00+09:00',
#   'geo:lat': 35.60897,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '品川シーサイド',
#   'geo:long': 139.74967,
#   'owl:sameAs': 'odpt.Station:TWR.Rinkai.ShinagawaSeaside',
#   'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#   'odpt:operator': 'odpt.Operator:TWR',
#   'odpt:stationCode': 'R6',
#   'odpt:stationTitle': {'en': 'Shinagawa Seaside',
#    'ja': '品川シーサイド',
#    'ko': '시나가와시사이드',
#    'zh-Hans': '品川海滨',
#    'zh-Hant': '品川海濱'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TWR.ShinagawaSeaside'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TWR.Rinkai.ShinagawaSeaside.Inbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.ShinagawaSeaside.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:TWR.Rinkai.ShinagawaSeaside.Outbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.ShinagawaSeaside.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B2D',
#   '@type': 'odpt:Station',
#   'dc:date': '2021-06-21T14:00:00+09:00',
#   'geo:lat': 35.6406,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東雲',
#   'geo:long': 139.80328,
#   'owl:sameAs': 'odpt.Station:TWR.Rinkai.Shinonome',
#   'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#   'odpt:operator': 'odpt.Operator:TWR',
#   'odpt:stationCode': 'R2',
#   'odpt:stationTitle': {'en': 'Shinonome',
#    'ja': '東雲',
#    'ko': '시노노메',
#    'zh-Hans': '东云',
#    'zh-Hant': '東雲'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TWR.Shinonome'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TWR.Rinkai.Shinonome.Inbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.Shinonome.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:TWR.Rinkai.Shinonome.Outbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.Shinonome.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B2F',
#   '@type': 'odpt:Station',
#   'dc:date': '2021-06-21T14:00:00+09:00',
#   'geo:lat': 35.62754,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東京テレポート',
#   'geo:long': 139.77885,
#   'owl:sameAs': 'odpt.Station:TWR.Rinkai.TokyoTeleport',
#   'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#   'odpt:operator': 'odpt.Operator:TWR',
#   'odpt:stationCode': 'R4',
#   'odpt:stationTitle': {'en': 'Tokyo Teleport',
#    'ja': '東京テレポート',
#    'ko': '도쿄텔레포트',
#    'zh-Hans': '东京电讯',
#    'zh-Hant': '東京電訊'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TWR.TokyoTeleport'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TWR.Rinkai.TokyoTeleport.Inbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.TokyoTeleport.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:TWR.Rinkai.TokyoTeleport.Outbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.TokyoTeleport.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B2E',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.63457,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '国際展示場',
#   'geo:long': 139.79163,
#   'owl:sameAs': 'odpt.Station:TWR.Rinkai.KokusaiTenjijo',
#   'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#   'odpt:operator': 'odpt.Operator:TWR',
#   'odpt:stationCode': 'R3',
#   'odpt:stationTitle': {'en': 'Kokusai-tenjijo',
#    'ja': '国際展示場',
#    'ko': '국제전시장',
#    'zh-Hans': '国际展示场',
#    'zh-Hant': '國際展示場'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TWR.KokusaiTenjijo'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TWR.Rinkai.KokusaiTenjijo.Inbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.KokusaiTenjijo.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:TWR.Rinkai.KokusaiTenjijo.Outbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.KokusaiTenjijo.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Yurikamome.Yurikamome'],
#   'odpt:connectingStation': ['odpt.Station:Yurikamome.Yurikamome.Ariake']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102841',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東京',
#   'owl:sameAs': 'odpt.Station:JR-East.Tokaido.Tokyo',
#   'odpt:railway': 'odpt.Railway:JR-East.Tokaido',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Tokyo', 'ja': '東京'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B32',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.60741,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '大井町',
#   'geo:long': 139.73474,
#   'owl:sameAs': 'odpt.Station:TWR.Rinkai.Oimachi',
#   'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#   'odpt:operator': 'odpt.Operator:TWR',
#   'odpt:stationCode': 'R7',
#   'odpt:stationTitle': {'en': 'Oimachi',
#    'ja': '大井町',
#    'ko': '오이마치',
#    'zh-Hans': '大井町',
#    'zh-Hant': '大井町'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TWR.Oimachi'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TWR.Rinkai.Oimachi.Inbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.Oimachi.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:TWR.Rinkai.Oimachi.Outbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.Oimachi.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.KeihinTohokuNegishi',
#    'odpt.Railway:Tokyu.Oimachi'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.KeihinTohokuNegishi.Oimachi',
#    'odpt.Station:Tokyu.Oimachi.Oimachi']},
#  {'@id': 'urn:ucode:_00001C0000000000000100000310215E',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '新宿',
#   'owl:sameAs': 'odpt.Station:Keio.KeioNew.Shinjuku',
#   'odpt:railway': 'odpt.Railway:Keio.KeioNew',
#   'odpt:operator': 'odpt.Operator:Keio',
#   'odpt:stationTitle': {'en': 'Shinjuku', 'ja': '新宿'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B33',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.62002,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '大崎',
#   'geo:long': 139.7282,
#   'owl:sameAs': 'odpt.Station:TWR.Rinkai.Osaki',
#   'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#   'odpt:operator': 'odpt.Operator:TWR',
#   'odpt:stationCode': 'R8',
#   'odpt:stationTitle': {'en': 'Osaki',
#    'ja': '大崎',
#    'ko': '오사키',
#    'zh-Hans': '大崎',
#    'zh-Hant': '大崎'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TWR.Osaki'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TWR.Rinkai.Osaki.Inbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.Osaki.Inbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.SaikyoKawagoe',
#    'odpt.Railway:JR-East.ShonanShinjuku',
#    'odpt.Railway:JR-East.SotetsuDirect',
#    'odpt.Railway:JR-East.Yamanote'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.SaikyoKawagoe.Osaki',
#    'odpt.Station:JR-East.ShonanShinjuku.Osaki',
#    'odpt.Station:JR-East.SotetsuDirect.Osaki',
#    'odpt.Station:JR-East.Yamanote.Osaki']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B2C',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.64604,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '新木場',
#   'geo:long': 139.82678,
#   'owl:sameAs': 'odpt.Station:TWR.Rinkai.ShinKiba',
#   'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#   'odpt:operator': 'odpt.Operator:TWR',
#   'odpt:stationCode': 'R1',
#   'odpt:stationTitle': {'en': 'Shin-kiba',
#    'ja': '新木場',
#    'ko': '신키바',
#    'zh-Hans': '新木场',
#    'zh-Hant': '新木場'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TWR.ShinKiba'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TWR.Rinkai.ShinKiba.Outbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.ShinKiba.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.Keiyo',
#    'odpt.Railway:TokyoMetro.Yurakucho'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.Keiyo.ShinKiba',
#    'odpt.Station:TokyoMetro.Yurakucho.ShinKiba']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B30',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.62038,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '天王洲アイル',
#   'geo:long': 139.75084,
#   'owl:sameAs': 'odpt.Station:TWR.Rinkai.TennozuIsle',
#   'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#   'odpt:operator': 'odpt.Operator:TWR',
#   'odpt:stationCode': 'R5',
#   'odpt:stationTitle': {'en': 'Tennozu Isle',
#    'ja': '天王洲アイル',
#    'ko': '덴노즈아일',
#    'zh-Hans': '天王洲岛',
#    'zh-Hant': '天王洲島'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TWR.TennozuIsle'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TWR.Rinkai.TennozuIsle.Inbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.TennozuIsle.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:TWR.Rinkai.TennozuIsle.Outbound.Weekday',
#    'odpt.StationTimetable:TWR.Rinkai.TennozuIsle.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:TokyoMonorail.HanedaAirport'],
#   'odpt:connectingStation': ['odpt.Station:TokyoMonorail.HanedaAirport.TennozuIsle']},
#  {'@id': 'urn:ucode:_00001C000000000000010000031027DE',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '秋葉原',
#   'owl:sameAs': 'odpt.Station:JR-East.ChuoSobuLocal.Akihabara',
#   'odpt:railway': 'odpt.Railway:JR-East.ChuoSobuLocal',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Akihabara', 'ja': '秋葉原'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102AC1',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.62495,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '小田急多摩センター',
#   'geo:long': 139.42443,
#   'owl:sameAs': 'odpt.Station:Odakyu.Tama.OdakyuTamaCenter',
#   'odpt:railway': 'odpt.Railway:Odakyu.Tama',
#   'odpt:operator': 'odpt.Operator:Odakyu',
#   'odpt:stationCode': 'OT06',
#   'odpt:stationTitle': {'en': 'Odakyu Tama Center', 'ja': '小田急多摩センター'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Odakyu.OdakyuTamaCenter'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Odakyu.Tama.OdakyuTamaCenter.Inbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Tama.OdakyuTamaCenter.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Odakyu.Tama.OdakyuTamaCenter.Outbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Tama.OdakyuTamaCenter.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Keio.Sagamihara',
#    'odpt.Railway:TamaMonorail.TamaMonorail'],
#   'odpt:connectingStation': ['odpt.Station:Keio.Sagamihara.KeioTamaCenter',
#    'odpt.Station:TamaMonorail.TamaMonorail.TamaCenter']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465307',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.911,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '柏たなか',
#   'geo:long': 139.9575,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.KashiwaTanaka',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX14',
#   'odpt:stationTitle': {'en': 'Kashiwa-Tanaka',
#    'ja': '柏たなか',
#    'ko': '가시와 다나카',
#    'zh-Hans': '柏田中',
#    'zh-Hant': '柏田中'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.KashiwaTanaka'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.KashiwaTanaka.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KashiwaTanaka.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KashiwaTanaka.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KashiwaTanaka.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C0000000000000100000310264F',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '東京',
#   'owl:sameAs': 'odpt.Station:JR-East.Keiyo.Tokyo',
#   'odpt:railway': 'odpt.Railway:JR-East.Keiyo',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Tokyo', 'ja': '東京'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000310286A',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.49021,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '鶴間',
#   'geo:long': 139.45084,
#   'owl:sameAs': 'odpt.Station:Odakyu.Enoshima.Tsuruma',
#   'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#   'odpt:operator': 'odpt.Operator:Odakyu',
#   'odpt:stationCode': 'OE04',
#   'odpt:stationTitle': {'en': 'Tsuruma', 'ja': '鶴間'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Odakyu.Tsuruma'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Odakyu.Enoshima.Tsuruma.Inbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Tsuruma.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Tsuruma.Outbound.Weekday',
#    'odpt.StationTimetable:Odakyu.Enoshima.Tsuruma.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003999528',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '小田原',
#   'owl:sameAs': 'odpt.Station:JR-Central.TokaidoShinkansen.Odawara',
#   'odpt:railway': 'odpt.Railway:JR-Central.TokaidoShinkansen',
#   'odpt:operator': 'odpt.Operator:JR-Central',
#   'odpt:stationTitle': {'en': 'Odawara', 'ja': '小田原'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465303',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.69894,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '秋葉原',
#   'geo:long': 139.77428,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Akihabara',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX01',
#   'odpt:stationTitle': {'en': 'Akihabara',
#    'ja': '秋葉原',
#    'ko': '아키하바라',
#    'zh-Hans': '秋叶原',
#    'zh-Hant': '秋葉原'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Akihabara'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Akihabara.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Akihabara.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.ChuoSobuLocal',
#    'odpt.Railway:JR-East.KeihinTohokuNegishi',
#    'odpt.Railway:JR-East.Yamanote',
#    'odpt.Railway:Toei.Shinjuku',
#    'odpt.Railway:TokyoMetro.Hibiya'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.ChuoSobuLocal.Akihabara',
#    'odpt.Station:JR-East.KeihinTohokuNegishi.Akihabara',
#    'odpt.Station:JR-East.Yamanote.Akihabara',
#    'odpt.Station:Toei.Shinjuku.Iwamotocho',
#    'odpt.Station:TokyoMetro.Hibiya.Akihabara']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465304',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.7725,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '青井',
#   'geo:long': 139.82033,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Aoi',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX06',
#   'odpt:stationTitle': {'en': 'Aoi',
#    'ja': '青井',
#    'ko': '아오이',
#    'zh-Hans': '青井',
#    'zh-Hant': '青井'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Aoi'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Aoi.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Aoi.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Aoi.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Aoi.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465305',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.714,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '浅草',
#   'geo:long': 139.79239,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Asakusa',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX03',
#   'odpt:stationTitle': {'en': 'Asakusa',
#    'ja': '浅草',
#    'ko': '아사쿠사',
#    'zh-Hans': '浅草',
#    'zh-Hant': '淺草'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Asakusa'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Asakusa.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Asakusa.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Asakusa.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Asakusa.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465306',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 36.05847,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '万博記念公園',
#   'geo:long': 140.05944,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.BampakuKinenKoen',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX18',
#   'odpt:stationTitle': {'en': 'Bampaku-kinenkōen',
#    'ja': '万博記念公園',
#    'ko': '반파쿠 기넨코엔',
#    'zh-Hans': '万博纪念公园',
#    'zh-Hant': '萬博紀念公園'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.BampakuKinenKoen'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.BampakuKinenKoen.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.BampakuKinenKoen.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.BampakuKinenKoen.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.BampakuKinenKoen.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C000000000000010000031027DB',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '錦糸町',
#   'owl:sameAs': 'odpt.Station:JR-East.ChuoSobuLocal.Kinshicho',
#   'odpt:railway': 'odpt.Railway:JR-East.ChuoSobuLocal',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Kinshicho', 'ja': '錦糸町'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465308',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.89336,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '柏の葉キャンパス',
#   'geo:long': 139.9525,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.KashiwanohaCampus',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX13',
#   'odpt:stationTitle': {'en': 'Kashiwanoha-campus',
#    'ja': '柏の葉キャンパス',
#    'ko': '가시와노하 캠퍼스',
#    'zh-Hans': '柏之叶校园',
#    'zh-Hant': '柏之葉園地'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.KashiwanohaCampus'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.KashiwanohaCampus.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KashiwanohaCampus.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KashiwanohaCampus.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KashiwanohaCampus.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C000000000000010000031029CA',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '大宮',
#   'owl:sameAs': 'odpt.Station:JR-East.AkitaShinkansen.Omiya',
#   'odpt:railway': 'odpt.Railway:JR-East.AkitaShinkansen',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Omiya', 'ja': '大宮'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465309',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 36.08217,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '研究学園',
#   'geo:long': 140.08239,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.KenkyuGakuen',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX19',
#   'odpt:stationTitle': {'en': 'Kenkyū-gakuen',
#    'ja': '研究学園',
#    'ko': '겐큐 가쿠엔',
#    'zh-Hans': '研究学园',
#    'zh-Hant': '研究學園'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.KenkyuGakuen'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.KenkyuGakuen.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KenkyuGakuen.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KenkyuGakuen.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KenkyuGakuen.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C0000000000000100000346530A',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.74975,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '北千住',
#   'geo:long': 139.80533,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.KitaSenju',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX05',
#   'odpt:stationTitle': {'en': 'Kita-Senju',
#    'ja': '北千住',
#    'ko': '기타 센주',
#    'zh-Hans': '北千住',
#    'zh-Hant': '北千住'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.KitaSenju'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.KitaSenju.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KitaSenju.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KitaSenju.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.KitaSenju.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.JobanRapid',
#    'odpt.Railway:Tobu.TobuSkytree',
#    'odpt.Railway:TokyoMetro.Chiyoda',
#    'odpt.Railway:TokyoMetro.Hibiya'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.JobanRapid.KitaSenju',
#    'odpt.Station:Tobu.TobuSkytree.KitaSenju',
#    'odpt.Station:TokyoMetro.Chiyoda.KitaSenju',
#    'odpt.Station:TokyoMetro.Hibiya.KitaSenju']},
#  {'@id': 'urn:ucode:_00001C0000000000000100000346530B',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 36.02994,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'みどりの',
#   'geo:long': 140.05625,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Midorino',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX17',
#   'odpt:stationTitle': {'en': 'Midorino',
#    'ja': 'みどりの',
#    'ko': '미도리노',
#    'zh-Hans': '绿野',
#    'zh-Hant': '綠野'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Midorino'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Midorino.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Midorino.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Midorino.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Midorino.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C0000000000000100000346530C',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.83786,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '南流山',
#   'geo:long': 139.90433,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.MinamiNagareyama',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX10',
#   'odpt:stationTitle': {'en': 'Minami-Nagareyama',
#    'ja': '南流山',
#    'ko': '미나미 나가레야마',
#    'zh-Hans': '南流山',
#    'zh-Hant': '南流山'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.MinamiNagareyama'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.MinamiNagareyama.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MinamiNagareyama.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MinamiNagareyama.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MinamiNagareyama.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.Musashino'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.Musashino.MinamiNagareyama']},
#  {'@id': 'urn:ucode:_00001C0000000000000100000346530D',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.73344,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '南千住',
#   'geo:long': 139.79911,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.MinamiSenju',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX04',
#   'odpt:stationTitle': {'en': 'Minami-Senju',
#    'ja': '南千住',
#    'ko': '미나미 센주',
#    'zh-Hans': '南千住',
#    'zh-Hant': '南千住'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.MinamiSenju'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.MinamiSenju.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MinamiSenju.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MinamiSenju.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MinamiSenju.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.JobanRapid',
#    'odpt.Railway:TokyoMetro.Hibiya'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.JobanRapid.MinamiSenju',
#    'odpt.Station:TokyoMetro.Hibiya.MinamiSenju']},
#  {'@id': 'urn:ucode:_00001C000000000000010000031027D3',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '西船橋',
#   'owl:sameAs': 'odpt.Station:JR-East.ChuoSobuLocal.NishiFunabashi',
#   'odpt:railway': 'odpt.Railway:JR-East.ChuoSobuLocal',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Nishi-Funabashi', 'ja': '西船橋'}},
#  {'@id': 'urn:ucode:_00001C0000000000000100000346530E',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.99475,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'みらい平',
#   'geo:long': 140.03831,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Miraidaira',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX16',
#   'odpt:stationTitle': {'en': 'Miraidaira',
#    'ja': 'みらい平',
#    'ko': '미라이다이라',
#    'zh-Hans': '未来平',
#    'zh-Hant': '未來平'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Miraidaira'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Miraidaira.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Miraidaira.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Miraidaira.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Miraidaira.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C0000000000000100000346530F',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.82417,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '三郷中央',
#   'geo:long': 139.87806,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.MisatoChuo',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX09',
#   'odpt:stationTitle': {'en': 'Misato-chūō',
#    'ja': '三郷中央',
#    'ko': '미사토 주오',
#    'zh-Hans': '三乡中央',
#    'zh-Hant': '三鄉中央'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.MisatoChuo'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.MisatoChuo.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MisatoChuo.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MisatoChuo.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.MisatoChuo.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465310',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.95069,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '守谷',
#   'geo:long': 139.99225,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Moriya',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX15',
#   'odpt:stationTitle': {'en': 'Moriya',
#    'ja': '守谷',
#    'ko': '모리야',
#    'zh-Hans': '守谷',
#    'zh-Hant': '守谷'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Moriya'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Moriya.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Moriya.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Moriya.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Moriya.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:KantoRailway.Joso'],
#   'odpt:connectingStation': ['odpt.Station:KantoRailway.Joso.Moriya']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465311',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.85447,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '流山セントラルパーク',
#   'geo:long': 139.91522,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.NagareyamaCentralPark',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX11',
#   'odpt:stationTitle': {'en': 'Nagareyama-centralpark',
#    'ja': '流山セントラルパーク',
#    'ko': '나가레야마 센트럴파크',
#    'zh-Hans': '流山中央公园',
#    'zh-Hant': '流山中央公園'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.NagareyamaCentralPark'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.NagareyamaCentralPark.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.NagareyamaCentralPark.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.NagareyamaCentralPark.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.NagareyamaCentralPark.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C0000000000000100000310288C',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '登戸',
#   'owl:sameAs': 'odpt.Station:JR-East.Nambu.Noborito',
#   'odpt:railway': 'odpt.Railway:JR-East.Nambu',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Noborito', 'ja': '登戸'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465312',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.87186,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '流山おおたかの森',
#   'geo:long': 139.92506,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.NagareyamaOtakanomori',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX12',
#   'odpt:stationTitle': {'en': 'Nagareyama-ōtakanomori',
#    'ja': '流山おおたかの森',
#    'ko': '나가레야마 오타카노모리',
#    'zh-Hans': '流山大鷹之森',
#    'zh-Hant': '流山大鷹之森'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.NagareyamaOtakanomori'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.NagareyamaOtakanomori.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.NagareyamaOtakanomori.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.NagareyamaOtakanomori.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.NagareyamaOtakanomori.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Tobu.TobuUrbanPark'],
#   'odpt:connectingStation': ['odpt.Station:Tobu.TobuUrbanPark.NagareyamaOtakanomori']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465313',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.78492,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '六町',
#   'geo:long': 139.82181,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Rokucho',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX07',
#   'odpt:stationTitle': {'en': 'Rokuchō',
#    'ja': '六町',
#    'ko': '로쿠초',
#    'zh-Hans': '六町',
#    'zh-Hant': '六町'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Rokucho'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Rokucho.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Rokucho.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Rokucho.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Rokucho.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465314',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.70711,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '新御徒町',
#   'geo:long': 139.78194,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.ShinOkachimachi',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX02',
#   'odpt:stationTitle': {'en': 'Shin-Okachimachi',
#    'ja': '新御徒町',
#    'ko': '신 오카치마치',
#    'zh-Hans': '新御徒町',
#    'zh-Hant': '新御徒町'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.ShinOkachimachi'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.ShinOkachimachi.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.ShinOkachimachi.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.ShinOkachimachi.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.ShinOkachimachi.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Toei.Oedo'],
#   'odpt:connectingStation': ['odpt.Station:Toei.Oedo.ShinOkachimachi']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465315',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 36.08256,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'つくば',
#   'geo:long': 140.11169,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Tsukuba',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX20',
#   'odpt:stationTitle': {'en': 'Tsukuba',
#    'ja': 'つくば',
#    'ko': '츠쿠바',
#    'zh-Hans': '筑波',
#    'zh-Hant': '筑波'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Tsukuba'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Tsukuba.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Tsukuba.Inbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465316',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-05-14T14:00:00+09:00',
#   'geo:lat': 35.80786,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '八潮',
#   'geo:long': 139.84483,
#   'owl:sameAs': 'odpt.Station:MIR.TsukubaExpress.Yashio',
#   'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:stationCode': 'TX08',
#   'odpt:stationTitle': {'en': 'Yashio',
#    'ja': '八潮',
#    'ko': '야시오',
#    'zh-Hans': '八潮',
#    'zh-Hant': '八潮'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:MIR.Yashio'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:MIR.TsukubaExpress.Yashio.Inbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Yashio.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Yashio.Outbound.Weekday',
#    'odpt.StationTimetable:MIR.TsukubaExpress.Yashio.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003465858',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-03-27T09:00:00+09:00',
#   'geo:lat': 35.6962,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '立川南',
#   'geo:long': 139.4126,
#   'owl:sameAs': 'odpt.Station:TamaMonorail.TamaMonorail.TachikawaMinami',
#   'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#   'odpt:operator': 'odpt.Operator:TamaMonorail',
#   'odpt:stationCode': 'TT11',
#   'odpt:stationTitle': {'en': 'Tachikawa-Minami', 'ja': '立川南'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:TamaMonorail.TachikawaMinami'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:TamaMonorail.TamaMonorail.TachikawaMinami.Southbound.Weekday',
#    'odpt.StationTimetable:TamaMonorail.TamaMonorail.TachikawaMinami.Southbound.SaturdayHoliday',
#    'odpt.StationTimetable:TamaMonorail.TamaMonorail.TachikawaMinami.Northbound.Weekday',
#    'odpt.StationTimetable:TamaMonorail.TamaMonorail.TachikawaMinami.Northbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:JR-East.ChuoRapid',
#    'odpt.Railway:JR-East.Nambu',
#    'odpt.Railway:JR-East.Ome'],
#   'odpt:connectingStation': ['odpt.Station:JR-East.ChuoRapid.Tachikawa',
#    'odpt.Station:JR-East.Nambu.Tachikawa',
#    'odpt.Station:JR-East.Ome.Tachikawa']},
# ...
#    'odpt.StationTimetable:Tokyu.Ikegami.Hatanodai.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Hatanodai.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Tokyu.Oimachi'],
#   'odpt:connectingStation': ['odpt.Station:Tokyu.Oimachi.Hatanodai']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B8D',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.572147,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '池上',
#   'geo:long': 139.702896,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.Ikegami',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK13',
#   'odpt:stationTitle': {'en': 'Ikegami', 'ja': '池上'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Ikegami'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.Ikegami.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Ikegami.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Ikegami.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Ikegami.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B88',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.596999,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '石川台',
#   'geo:long': 139.685571,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.IshikawaDai',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK8',
#   'odpt:stationTitle': {'en': 'Ishikawa-dai', 'ja': '石川台'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.IshikawaDai'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.IshikawaDai.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.IshikawaDai.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.IshikawaDai.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.IshikawaDai.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B8F',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.561687,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '蒲田',
#   'geo:long': 139.71464,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.Kamata',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK15',
#   'odpt:stationTitle': {'en': 'Kamata', 'ja': '蒲田'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Ikegami.Kamata'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.Kamata.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Kamata.Inbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Tokyu.TokyuTamagawa',
#    'odpt.Railway:JR-East.KeihinTohokuNegishi'],
#   'odpt:connectingStation': ['odpt.Station:Tokyu.TokyuTamagawa.Kamata',
#    'odpt.Station:JR-East.KeihinTohokuNegishi.Kamata']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B8B',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.579837,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '久が原',
#   'geo:long': 139.685347,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.Kugahara',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK11',
#   'odpt:stationTitle': {'en': 'Kugahara', 'ja': '久が原'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Kugahara'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.Kugahara.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Kugahara.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Kugahara.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Kugahara.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B86',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.602201,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '長原',
#   'geo:long': 139.697689,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.Nagahara',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK6',
#   'odpt:stationTitle': {'en': 'Nagahara', 'ja': '長原'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Nagahara'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.Nagahara.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Nagahara.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Nagahara.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Nagahara.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B8A',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.585344,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '御嶽山',
#   'geo:long': 139.682156,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.Ontakesan',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK10',
#   'odpt:stationTitle': {'en': 'Ontakesan', 'ja': '御嶽山'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Ontakesan'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.Ontakesan.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Ontakesan.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Ontakesan.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Ontakesan.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B82',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.622722,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '大崎広小路',
#   'geo:long': 139.722711,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.Osakihirokoji',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK2',
#   'odpt:stationTitle': {'en': 'Osakihirokoji', 'ja': '大崎広小路'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Osakihirokoji'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.Osakihirokoji.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Osakihirokoji.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Osakihirokoji.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Osakihirokoji.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B87',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.599929,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '洗足池',
#   'geo:long': 139.691409,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.SenzokuIke',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK7',
#   'odpt:stationTitle': {'en': 'Senzoku-ike', 'ja': '洗足池'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.SenzokuIke'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.SenzokuIke.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.SenzokuIke.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.SenzokuIke.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.SenzokuIke.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B83',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.615775,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '戸越銀座',
#   'geo:long': 139.714764,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.TogoshiGinza',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK3',
#   'odpt:stationTitle': {'en': 'Togoshi-ginza', 'ja': '戸越銀座'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.TogoshiGinza'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.TogoshiGinza.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.TogoshiGinza.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.TogoshiGinza.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.TogoshiGinza.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Toei.Asakusa'],
#   'odpt:connectingStation': ['odpt.Station:Toei.Asakusa.Togoshi']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B89',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.59201,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '雪が谷大塚',
#   'geo:long': 139.680964,
#   'owl:sameAs': 'odpt.Station:Tokyu.Ikegami.Yukigayaotsuka',
#   'odpt:railway': 'odpt.Railway:Tokyu.Ikegami',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'IK9',
#   'odpt:stationTitle': {'en': 'Yukigayaotsuka', 'ja': '雪が谷大塚'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Yukigayaotsuka'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Ikegami.Yukigayaotsuka.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Yukigayaotsuka.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Yukigayaotsuka.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Ikegami.Yukigayaotsuka.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102BA3',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.558366,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'こどもの国',
#   'geo:long': 139.486418,
#   'owl:sameAs': 'odpt.Station:Tokyu.Kodomonokuni.Kodomonokuni',
#   'odpt:railway': 'odpt.Railway:Tokyu.Kodomonokuni',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'KD3',
#   'odpt:stationTitle': {'en': 'Kodomonokuni', 'ja': 'こどもの国'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Kodomonokuni'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Kodomonokuni.Kodomonokuni.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Kodomonokuni.Kodomonokuni.Inbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102C72',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 36.11696,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '玉淀',
#   'geo:long': 139.20019,
#   'owl:sameAs': 'odpt.Station:Tobu.Tojo.Tamayodo',
#   'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#   'odpt:operator': 'odpt.Operator:Tobu',
#   'odpt:stationCode': 'TJ-38',
#   'odpt:stationTitle': {'en': 'Tamayodo',
#    'ja': '玉淀',
#    'ko': '다마요도',
#    'ja-Hrkt': 'たまよど',
#    'zh-Hans': '玉淀',
#    'zh-Hant': '玉淀'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tobu.Tamayodo'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tobu.Tojo.Tamayodo.Inbound.Weekday',
#    'odpt.StationTimetable:Tobu.Tojo.Tamayodo.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tobu.Tojo.Tamayodo.Outbound.Weekday',
#    'odpt.StationTimetable:Tobu.Tojo.Tamayodo.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C000000000000010000031028D3',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '北朝霞',
#   'owl:sameAs': 'odpt.Station:JR-East.Musashino.KitaAsaka',
#   'odpt:railway': 'odpt.Railway:JR-East.Musashino',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:stationTitle': {'en': 'Kita-Asaka', 'ja': '北朝霞'}},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102BA1',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.532095,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '長津田',
#   'geo:long': 139.494486,
#   'owl:sameAs': 'odpt.Station:Tokyu.Kodomonokuni.Nagatsuta',
#   'odpt:railway': 'odpt.Railway:Tokyu.Kodomonokuni',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'KD1',
#   'odpt:stationTitle': {'en': 'Nagatsuta', 'ja': '長津田'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Kodomonokuni.Nagatsuta'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Kodomonokuni.Nagatsuta.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Kodomonokuni.Nagatsuta.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Tokyu.DenEnToshi',
#    'odpt.Railway:JR-East.Yokohama'],
#   'odpt:connectingStation': ['odpt.Station:Tokyu.DenEnToshi.Nagatsuta',
#    'odpt.Station:JR-East.Yokohama.Nagatsuta']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B4D',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.610303,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '洗足',
#   'geo:long': 139.694316,
#   'owl:sameAs': 'odpt.Station:Tokyu.Meguro.Senzoku',
#   'odpt:railway': 'odpt.Railway:Tokyu.Meguro',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'MG5',
#   'odpt:stationTitle': {'en': 'Senzoku', 'ja': '洗足'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Senzoku'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Meguro.Senzoku.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Meguro.Senzoku.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Meguro.Senzoku.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Meguro.Senzoku.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102BA2',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.545587,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '恩田',
#   'geo:long': 139.491938,
#   'owl:sameAs': 'odpt.Station:Tokyu.Kodomonokuni.Onda',
#   'odpt:railway': 'odpt.Railway:Tokyu.Kodomonokuni',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'KD2',
#   'odpt:stationTitle': {'en': 'Onda', 'ja': '恩田'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Onda'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Kodomonokuni.Onda.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Kodomonokuni.Onda.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Kodomonokuni.Onda.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Kodomonokuni.Onda.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B7C',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.607179,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '尾山台',
#   'geo:long': 139.653401,
#   'owl:sameAs': 'odpt.Station:Tokyu.Oimachi.Oyamadai',
#   'odpt:railway': 'odpt.Railway:Tokyu.Oimachi',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'OM12',
#   'odpt:stationTitle': {'en': 'Oyamadai', 'ja': '尾山台'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Oyamadai'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Oimachi.Oyamadai.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Oimachi.Oyamadai.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Oimachi.Oyamadai.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Oimachi.Oyamadai.Outbound.SaturdayHoliday']},
#  {'@id': 'urn:ucode:_00001C00000000000001000003102B50',
#   '@type': 'odpt:Station',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   'geo:lat': 35.596893,
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '田園調布',
#   'geo:long': 139.66729,
#   'owl:sameAs': 'odpt.Station:Tokyu.Meguro.DenEnChofu',
#   'odpt:railway': 'odpt.Railway:Tokyu.Meguro',
#   'odpt:operator': 'odpt.Operator:Tokyu',
#   'odpt:stationCode': 'MG8',
#   'odpt:stationTitle': {'en': 'Den-en-chofu', 'ja': '田園調布'},
#   'odpt:passengerSurvey': ['odpt.PassengerSurvey:Tokyu.Meguro.DenEnChofu'],
#   'odpt:stationTimetable': ['odpt.StationTimetable:Tokyu.Meguro.DenEnChofu.Inbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Meguro.DenEnChofu.Inbound.SaturdayHoliday',
#    'odpt.StationTimetable:Tokyu.Meguro.DenEnChofu.Outbound.Weekday',
#    'odpt.StationTimetable:Tokyu.Meguro.DenEnChofu.Outbound.SaturdayHoliday'],
#   'odpt:connectingRailway': ['odpt.Railway:Tokyu.Toyoko'],
#   'odpt:connectingStation': ['odpt.Station:Tokyu.Toyoko.DenEnChofu']},
#  ...]

# %%
station_geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.47601, 35.34812]},
#    'properties': {'id': 'odpt.Station:Odakyu.Enoshima.FujisawaHommachi',
#     'name': '藤沢本町',
#     'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#     'odpt:operator': 'odpt.Operator:Odakyu',
#     'odpt:stationCode': 'OE12',
#     'railway_name': '江ノ島線',
#     'operator_name': '小田急電鉄'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.48764, 35.33859]},
#    'properties': {'id': 'odpt.Station:Odakyu.Enoshima.Fujisawa',
#     'name': '藤沢',
#     'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#     'odpt:operator': 'odpt.Operator:Odakyu',
#     'odpt:stationCode': 'OE13',
#     'railway_name': '江ノ島線',
#     'operator_name': '小田急電鉄'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.47083, 35.38358]},
#    'properties': {'id': 'odpt.Station:Odakyu.Enoshima.MutsuaiNichidaiMae',
#     'name': '六会日大前',
#     'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#     'odpt:operator': 'odpt.Operator:Odakyu',
#     'odpt:stationCode': 'OE10',
#     'railway_name': '江ノ島線',
#     'operator_name': '小田急電鉄'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.47325, 35.36279]},
#    'properties': {'id': 'odpt.Station:Odakyu.Enoshima.Zengyo',
#     'name': '善行',
#     'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#     'odpt:operator': 'odpt.Operator:Odakyu',
#     'odpt:stationCode': 'OE11',
#     'railway_name': '江ノ島線',
#     'operator_name': '小田急電鉄'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.34394, 35.41764]},
#    'properties': {'id': 'odpt.Station:Odakyu.Odawara.AikoIshida',
#     'name': '愛甲石田',
#     'odpt:railway': 'odpt.Railway:Odakyu.Odawara',
#     'odpt:operator': 'odpt.Operator:Odakyu',
#     'odpt:stationCode': 'OH35',
#     'railway_name': '小田原線',
#     'operator_name': '小田急電鉄'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4483, 35.62987]},
#    'properties': {'id': 'odpt.Station:Odakyu.Tama.OdakyuNagayama',
#     'name': '小田急永山',
#     'odpt:railway': 'odpt.Railway:Odakyu.Tama',
#     'odpt:operator': 'odpt.Operator:Odakyu',
#     'odpt:stationCode': 'OT05',
#     'railway_name': '多摩線',
#     'operator_name': '小田急電鉄'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4127, 35.6995]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.TachikawaKita',
#     'name': '立川北',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT12',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.553876, 35.568022]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Azamino',
#     'name': 'あざみ野',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B32',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.579045, 35.553383]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.CenterKita',
#     'name': 'センター北',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B30',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.74967, 35.60897]},
#    'properties': {'id': 'odpt.Station:TWR.Rinkai.ShinagawaSeaside',
#     'name': '品川シーサイド',
#     'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#     'odpt:operator': 'odpt.Operator:TWR',
#     'odpt:stationCode': 'R6',
#     'railway_name': 'りんかい線',
#     'operator_name': '東京臨海高速鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.80328, 35.6406]},
#    'properties': {'id': 'odpt.Station:TWR.Rinkai.Shinonome',
#     'name': '東雲',
#     'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#     'odpt:operator': 'odpt.Operator:TWR',
#     'odpt:stationCode': 'R2',
#     'railway_name': 'りんかい線',
#     'operator_name': '東京臨海高速鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.77885, 35.62754]},
#    'properties': {'id': 'odpt.Station:TWR.Rinkai.TokyoTeleport',
#     'name': '東京テレポート',
#     'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#     'odpt:operator': 'odpt.Operator:TWR',
#     'odpt:stationCode': 'R4',
#     'railway_name': 'りんかい線',
#     'operator_name': '東京臨海高速鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.79163, 35.63457]},
#    'properties': {'id': 'odpt.Station:TWR.Rinkai.KokusaiTenjijo',
#     'name': '国際展示場',
#     'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#     'odpt:operator': 'odpt.Operator:TWR',
#     'odpt:stationCode': 'R3',
#     'railway_name': 'りんかい線',
#     'operator_name': '東京臨海高速鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.73474, 35.60741]},
#    'properties': {'id': 'odpt.Station:TWR.Rinkai.Oimachi',
#     'name': '大井町',
#     'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#     'odpt:operator': 'odpt.Operator:TWR',
#     'odpt:stationCode': 'R7',
#     'railway_name': 'りんかい線',
#     'operator_name': '東京臨海高速鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.7282, 35.62002]},
#    'properties': {'id': 'odpt.Station:TWR.Rinkai.Osaki',
#     'name': '大崎',
#     'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#     'odpt:operator': 'odpt.Operator:TWR',
#     'odpt:stationCode': 'R8',
#     'railway_name': 'りんかい線',
#     'operator_name': '東京臨海高速鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.82678, 35.64604]},
#    'properties': {'id': 'odpt.Station:TWR.Rinkai.ShinKiba',
#     'name': '新木場',
#     'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#     'odpt:operator': 'odpt.Operator:TWR',
#     'odpt:stationCode': 'R1',
#     'railway_name': 'りんかい線',
#     'operator_name': '東京臨海高速鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.75084, 35.62038]},
#    'properties': {'id': 'odpt.Station:TWR.Rinkai.TennozuIsle',
#     'name': '天王洲アイル',
#     'odpt:railway': 'odpt.Railway:TWR.Rinkai',
#     'odpt:operator': 'odpt.Operator:TWR',
#     'odpt:stationCode': 'R5',
#     'railway_name': 'りんかい線',
#     'operator_name': '東京臨海高速鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.42443, 35.62495]},
#    'properties': {'id': 'odpt.Station:Odakyu.Tama.OdakyuTamaCenter',
#     'name': '小田急多摩センター',
#     'odpt:railway': 'odpt.Railway:Odakyu.Tama',
#     'odpt:operator': 'odpt.Operator:Odakyu',
#     'odpt:stationCode': 'OT06',
#     'railway_name': '多摩線',
#     'operator_name': '小田急電鉄'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.9575, 35.911]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.KashiwaTanaka',
#     'name': '柏たなか',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX14',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.45084, 35.49021]},
#    'properties': {'id': 'odpt.Station:Odakyu.Enoshima.Tsuruma',
#     'name': '鶴間',
#     'odpt:railway': 'odpt.Railway:Odakyu.Enoshima',
#     'odpt:operator': 'odpt.Operator:Odakyu',
#     'odpt:stationCode': 'OE04',
#     'railway_name': '江ノ島線',
#     'operator_name': '小田急電鉄'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.77428, 35.69894]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Akihabara',
#     'name': '秋葉原',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX01',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.82033, 35.7725]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Aoi',
#     'name': '青井',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX06',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.79239, 35.714]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Asakusa',
#     'name': '浅草',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX03',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [140.05944, 36.05847]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.BampakuKinenKoen',
#     'name': '万博記念公園',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX18',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.9525, 35.89336]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.KashiwanohaCampus',
#     'name': '柏の葉キャンパス',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX13',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [140.08239, 36.08217]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.KenkyuGakuen',
#     'name': '研究学園',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX19',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.80533, 35.74975]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.KitaSenju',
#     'name': '北千住',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX05',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [140.05625, 36.02994]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Midorino',
#     'name': 'みどりの',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX17',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.90433, 35.83786]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.MinamiNagareyama',
#     'name': '南流山',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX10',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.79911, 35.73344]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.MinamiSenju',
#     'name': '南千住',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX04',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [140.03831, 35.99475]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Miraidaira',
#     'name': 'みらい平',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX16',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.87806, 35.82417]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.MisatoChuo',
#     'name': '三郷中央',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX09',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.99225, 35.95069]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Moriya',
#     'name': '守谷',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX15',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.91522, 35.85447]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.NagareyamaCentralPark',
#     'name': '流山セントラルパーク',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX11',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.92506, 35.87186]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.NagareyamaOtakanomori',
#     'name': '流山おおたかの森',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX12',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.82181, 35.78492]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Rokucho',
#     'name': '六町',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX07',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.78194, 35.70711]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.ShinOkachimachi',
#     'name': '新御徒町',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX02',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [140.11169, 36.08256]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Tsukuba',
#     'name': 'つくば',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX20',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.84483, 35.80786]},
#    'properties': {'id': 'odpt.Station:MIR.TsukubaExpress.Yashio',
#     'name': '八潮',
#     'odpt:railway': 'odpt.Railway:MIR.TsukubaExpress',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'odpt:stationCode': 'TX08',
#     'railway_name': 'つくばエクスプレス',
#     'operator_name': '首都圏新都市鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4126, 35.6962]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.TachikawaMinami',
#     'name': '立川南',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT11',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4152, 35.6613]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Takahatafudo',
#     'name': '高幡不動',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT07',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4228, 35.6239]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.TamaCenter',
#     'name': '多摩センター',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT01',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4038, 35.6485]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.TamaDobutsukoen',
#     'name': '多摩動物公園',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT05',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4177, 35.7322]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.TamagawaJosui',
#     'name': '玉川上水',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT17',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4087, 35.6419]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.ChuoDaigakuMeiseiDaigaku',
#     'name': '中央大学・明星大学',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT04',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4108, 35.6552]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Hodokubo',
#     'name': '程久保',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT06',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4196, 35.7188]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.IzumiTaiikukan',
#     'name': '泉体育館',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT15',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4159, 35.7458]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Kamikitadai',
#     'name': '上北台',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT19',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4092, 35.6782]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Koshukaido',
#     'name': '甲州街道',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT09',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4199, 35.6713]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Manganji',
#     'name': '万願寺',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT08',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.422, 35.6318]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Matsugaya',
#     'name': '松が谷',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT02',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4164, 35.6369]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.OtsukaTeikyoDaigaku',
#     'name': '大塚・帝京大学',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT03',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4166, 35.739]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Sakurakaido',
#     'name': '桜街道',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT18',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4093, 35.6898]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.ShibasakiTaiikukan',
#     'name': '柴崎体育館',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT10',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4181, 35.7234]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.SunagawaNanaban',
#     'name': '砂川七番',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT16',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4171, 35.7143]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Tachihi',
#     'name': '立飛',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT14',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4133, 35.71]},
#    'properties': {'id': 'odpt.Station:TamaMonorail.TamaMonorail.Takamatsu',
#     'name': '高松',
#     'odpt:railway': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'odpt:stationCode': 'TT13',
#     'railway_name': '多摩モノレール',
#     'operator_name': '多摩都市モノレール'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.574713, 35.545633]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.CenterMinami',
#     'name': 'センター南',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B29',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.595875, 35.408451]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Kamiooka',
#     'name': '上大岡',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B11',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.635978, 35.445714]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Kannai',
#     'name': '関内',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B17',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.630626, 35.449761]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Sakuragicho',
#     'name': '桜木町',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B18',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.602039, 35.423152]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Gumyoji',
#     'name': '弘明寺',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B12',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.574713, 35.545633]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.CenterMinami',
#     'name': 'センター南',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G04',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.617318, 35.508876]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.ShinYokohama',
#     'name': '新横浜',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B25',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.466502, 35.396565]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Shonandai',
#     'name': '湘南台',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B01',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.535125, 35.401142]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Totsuka',
#     'name': '戸塚',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B06',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.632601, 35.441008]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.IsezakiChojamachi',
#     'name': '伊勢佐木長者町',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B16',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.619948, 35.465624]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Yokohama',
#     'name': '横浜',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B20',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.579045, 35.553383]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.CenterKita',
#     'name': 'センター北',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G05',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.647449, 35.553207]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.Hiyoshi',
#     'name': '日吉',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G10',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.540439, 35.515143]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.Nakayama',
#     'name': '中山',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G01',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.606518, 35.489974]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Katakuracho',
#     'name': '片倉町',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B23',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.573079, 35.401456]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Kaminagaya',
#     'name': '上永谷',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B09',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.612816, 35.519237]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.KitaShinYokohama',
#     'name': '北新横浜',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B26',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.591578, 35.401317]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.KonanChuo',
#     'name': '港南中央',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B10',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.551498, 35.402538]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Maioka',
#     'name': '舞岡',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B07',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.610464, 35.430203]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Maita',
#     'name': '蒔田',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B13',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.511324, 35.411199]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Nakada',
#     'name': '中田',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B04',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.570296, 35.562659]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Nakagawa',
#     'name': '中川',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B31',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.589828, 35.53523]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Nakamachidai',
#     'name': '仲町台',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B28',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.612377, 35.527081]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Nippa',
#     'name': '新羽',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B27',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.518501, 35.405704]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Odoriba',
#     'name': '踊場',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B05',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.482969, 35.403362]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Shimoiida',
#     'name': '下飯田',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B02',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.559275, 35.402844]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Shimonagaya',
#     'name': '下永谷',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B08',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.623477, 35.458945]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Takashimacho',
#     'name': '高島町',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B19',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.50028, 35.41423]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Tateba',
#     'name': '立場',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B03',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.61888, 35.435424]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Yoshinocho',
#     'name': '吉野町',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B14',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.604928, 35.554184]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.HigashiYamata',
#     'name': '東山田',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G07',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.633413, 35.549961]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.HiyoshiHoncho',
#     'name': '日吉本町',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G09',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.549265, 35.528382]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.Kawawacho',
#     'name': '川和町',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G02',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.620231, 35.549594]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.Takata',
#     'name': '高田',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G08',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.561611, 35.536637]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.TsuzukiFureainooka',
#     'name': '都筑ふれあいの丘',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G03',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.625296, 35.437646]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Blue.Bandobashi',
#     'name': '阪東橋',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Blue',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'B15',
#     'railway_name': 'ブルーライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.592827, 35.56095]},
#    'properties': {'id': 'odpt.Station:YokohamaMunicipal.Green.KitaYamata',
#     'name': '北山田',
#     'odpt:railway': 'odpt.Railway:YokohamaMunicipal.Green',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'odpt:stationCode': 'G06',
#     'railway_name': 'グリーンライン',
#     'operator_name': '横浜市交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.698833, 35.644108]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hibiya.NakaMeguro',
#     'name': '中目黒',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hibiya',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'H01',
#     'railway_name': '日比谷線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.700548, 35.692452]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Marunouchi.Shinjuku',
#     'name': '新宿',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Marunouchi',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'M08',
#     'railway_name': '丸ノ内線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.806057, 35.688399]},
#    'properties': {'id': 'odpt.Station:Toei.Shinjuku.Kikukawa',
#     'name': '菊川',
#     'odpt:railway': 'odpt.Railway:Toei.Shinjuku',
#     'odpt:operator': 'odpt.Operator:Toei',
#     'odpt:stationCode': 'S-12',
#     'railway_name': '新宿線',
#     'operator_name': '東京都交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.714715, 35.7202]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Fukutoshin.Zoshigaya',
#     'name': '雑司が谷',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Fukutoshin',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'F10',
#     'railway_name': '副都心線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.737347, 35.676845]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Ginza.AkasakaMitsuke',
#     'name': '赤坂見附',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Ginza',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'G05',
#     'railway_name': '銀座線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.797774, 35.710746]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Ginza.Asakusa',
#     'name': '浅草',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Ginza',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'G19',
#     'railway_name': '銀座線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.657935, 35.683515]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.MarunouchiBranch.Honancho',
#     'name': '方南町',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.MarunouchiBranch',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'Mb03',
#     'railway_name': '丸ノ内線支線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.76575, 35.717325]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Chiyoda.Nezu',
#     'name': '根津',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Chiyoda',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'C14',
#     'railway_name': '千代田線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.765366, 35.6715]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Ginza.Ginza',
#     'name': '銀座',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Ginza',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'G09',
#     'railway_name': '銀座線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.712473, 35.665042]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Ginza.OmoteSando',
#     'name': '表参道',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Ginza',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'G02',
#     'railway_name': '銀座線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.758512, 35.667382]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Ginza.Shimbashi',
#     'name': '新橋',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Ginza',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'G08',
#     'railway_name': '銀座線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.741943, 35.671511]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Ginza.TameikeSanno',
#     'name': '溜池山王',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Ginza',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'G06',
#     'railway_name': '銀座線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.76178, 35.680505]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Chiyoda.Nijubashimae',
#     'name': '二重橋前〈丸の内〉',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Chiyoda',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'C10',
#     'railway_name': '千代田線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.74985, 35.654186]},
#    'properties': {'id': 'odpt.Station:Toei.Mita.Shibakoen',
#     'name': '芝公園',
#     'odpt:railway': 'odpt.Railway:Toei.Mita',
#     'odpt:operator': 'odpt.Operator:Toei',
#     'odpt:stationCode': 'I-05',
#     'railway_name': '三田線',
#     'operator_name': '東京都交通局'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.75012, 35.67016]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Ginza.Toranomon',
#     'name': '虎ノ門',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Ginza',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'G07',
#     'railway_name': '銀座線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.772473, 35.667928]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hibiya.Tsukiji',
#     'name': '築地',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hibiya',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'H11',
#     'railway_name': '日比谷線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.75756, 35.696021]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hanzomon.Jimbocho',
#     'name': '神保町',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hanzomon',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'Z07',
#     'railway_name': '半蔵門線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.814957, 35.697441]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hanzomon.Kinshicho',
#     'name': '錦糸町',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hanzomon',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'Z13',
#     'railway_name': '半蔵門線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.799841, 35.682119]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hanzomon.KiyosumiShirakawa',
#     'name': '清澄白河',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hanzomon',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'Z11',
#     'railway_name': '半蔵門線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.769981, 35.706805]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Chiyoda.Yushima',
#     'name': '湯島',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Chiyoda',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'C13',
#     'railway_name': '千代田線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.738865, 35.678407]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hanzomon.Nagatacho',
#     'name': '永田町',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hanzomon',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'Z04',
#     'railway_name': '半蔵門線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.712383, 35.665143]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hanzomon.OmoteSando',
#     'name': '表参道',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hanzomon',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'Z02',
#     'railway_name': '半蔵門線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.813735, 35.708467]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hanzomon.Oshiage',
#     'name': '押上〈スカイツリー前〉',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hanzomon',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'Z14',
#     'railway_name': '半蔵門線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.815667, 35.688704]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hanzomon.Sumiyoshi',
#     'name': '住吉',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hanzomon',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'Z12',
#     'railway_name': '半蔵門線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.77089, 35.693715]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Ginza.Kanda',
#     'name': '神田',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Ginza',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'G13',
#     'railway_name': '銀座線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.775529, 35.697965]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hibiya.Akihabara',
#     'name': '秋葉原',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hibiya',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'H16',
#     'railway_name': '日比谷線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.708701, 35.64704]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hibiya.Ebisu',
#     'name': '恵比寿',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hibiya',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'H02',
#     'railway_name': '日比谷線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.764007, 35.671983]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hibiya.Ginza',
#     'name': '銀座',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hibiya',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'H09',
#     'railway_name': '日比谷線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.777334, 35.675368]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hibiya.Hatchobori',
#     'name': '八丁堀',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hibiya',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'H12',
#     'railway_name': '日比谷線',
#     'operator_name': '東京メトロ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.79878, 35.73231]},
#    'properties': {'id': 'odpt.Station:TokyoMetro.Hibiya.MinamiSenju',
#     'name': '南千住',
#     'odpt:railway': 'odpt.Railway:TokyoMetro.Hibiya',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'odpt:stationCode': 'H21',
#     'railway_name': '日比谷線',
# ...
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-02',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.99221, 35.74165]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Magomezawa',
#     'name': '馬込沢',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-32',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.97632, 35.82982]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Masuo',
#     'name': '増尾',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-26',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.8084, 35.9806]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.MinamiSakurai',
#     'name': '南桜井',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-12',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.99925, 35.79371]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Mutsumi',
#     'name': '六実',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-29',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.92576, 35.87208]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.NagareyamaOtakanomori',
#     'name': '流山おおたかの森',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-22',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.85295, 35.97085]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Nanakodai',
#     'name': '七光台',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-14',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.66601, 35.93649]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Nanasato',
#     'name': '七里',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-05',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.87079, 35.94374]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Nodashi',
#     'name': '野田市',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-17',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.63308, 35.92388]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.OmiyaKoen',
#     'name': '大宮公園',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-03',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.62425, 35.90775]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Omiya',
#     'name': '大宮',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-01',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.65102, 35.92935]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Owada',
#     'name': '大和田',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-04',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.9837, 35.82328]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Sakasai',
#     'name': '逆井',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-27',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.8603, 35.95879]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.ShimizuKoen',
#     'name': '清水公園',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-15',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.97982, 35.71156]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.ShinFunabashi',
#     'name': '新船橋',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-34',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.99836, 35.77961]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.ShinKamagaya',
#     'name': '新鎌ヶ谷',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-30',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.96704, 35.8381]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.ShinKashiwa',
#     'name': '新柏',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-25',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.99898, 35.8083]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Takayanagi',
#     'name': '高柳',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-28',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.72619, 35.96804]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Toyoharu',
#     'name': '豊春',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-08',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.93928, 35.86653]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Toyoshiki',
#     'name': '豊四季',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-23',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.9829, 35.72212]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Tsukada',
#     'name': '塚田',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-33',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.89109, 35.93158]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Umesato',
#     'name': '梅郷',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-18',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.90604, 35.91437]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Unga',
#     'name': '運河',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-19',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.7423, 35.97858]},
#    'properties': {'id': 'odpt.Station:Tobu.TobuUrbanPark.Yagisaki',
#     'name': '八木崎',
#     'odpt:railway': 'odpt.Railway:Tobu.TobuUrbanPark',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TD-09',
#     'railway_name': '東武アーバンパークライン',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.5873, 35.81434]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Asakadai',
#     'name': '朝霞台',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-13',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.6003, 35.79676]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Asaka',
#     'name': '朝霞',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-12',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.52309, 35.86075]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Fujimino',
#     'name': 'ふじみ野',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-18',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.20863, 36.11372]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Hachigata',
#     'name': '鉢形',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-37',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.40158, 36.03464]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.HigashiMatsuyama',
#     'name': '東松山',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-29',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.71117, 35.73118]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Ikebukuro',
#     'name': '池袋',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-01',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.51187, 35.87387]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.KamiFukuoka',
#     'name': '上福岡',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-19',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.67621, 35.76362]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.KamiItabashi',
#     'name': '上板橋',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-07',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.44385, 35.92546]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Kasumigaseki',
#     'name': '霞ヶ関',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-23',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.4771, 35.91414]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Kawagoeshi',
#     'name': '川越市',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-22',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.69438, 35.75628]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.NakaItabashi',
#     'name': '中板橋',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-05',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.48299, 35.90735]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Kawagoe',
#     'name': '川越',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-21',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.71639, 35.74033]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.KitaIkebukuro',
#     'name': '北池袋',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-02',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.39685, 35.97198]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.KitaSakado',
#     'name': '北坂戸',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-27',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.23647, 36.09138]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.MinamiYorii',
#     'name': 'みなみ寄居<ホンダ寄居前>',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-35',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.55079, 35.8382]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Mizuhodai',
#     'name': 'みずほ台',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-16',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.32774, 36.04438]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.MusashiRanzan',
#     'name': '武蔵嵐山',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-32',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.6329, 35.77759]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Narimasu',
#     'name': '成増',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-10',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.234, 36.10786]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Obusuma',
#     'name': '男衾',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-36',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [139.26065, 36.05873]},
#    'properties': {'id': 'odpt.Station:Tobu.Tojo.Ogawamachi',
#     'name': '小川町',
#     'odpt:railway': 'odpt.Railway:Tobu.Tojo',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'odpt:stationCode': 'TJ-33',
#     'railway_name': '東上線',
#     'operator_name': '東武鉄道'}},
#   ...]}

# %%
with open(path_edit + 'Station.geojson', 'w') as f:
    json.dump(station_geojson, f)

# %% [markdown]
# ## Convert Railway to GeoJSON
#
# Taking the geometry as a chain of rails, convert railways to GeoJSON data
#
# The geometries should be improved to contain actual geometries.

# %%
# initialise GeoJSON
railway_geojson = {
    'type': 'FeatureCollection',
    'features': []
}

# add railway routes to GeoJSON
for r in railway_dict:
    # get linestring
    coords_list = []
    for s in r['odpt:stationOrder']:
        # get coordinates for each station
        station_data = [d for d in station_dict if d['owl:sameAs'] == s['odpt:station']][0]
        coords = [station_data['geo:long'], station_data['geo:lat']]

        # add to list
        coords_list.append(coords)

    # create feature
    feature = {
        'type': 'Feature',
        'geometry': {
            'type': 'LineString',
            'coordinates': coords_list
        },
        'properties': {
            'id': r['owl:sameAs'],
            'name': r['dc:title'],
            'odpt:operator': r['odpt:operator']     
        }
    }

    # add operator info
    operator_name = [d['dc:title'] for d in operator_dict if d['owl:sameAs'] == r['odpt:operator']][0]
    feature['properties']['operator_name'] = operator_name

    # add line name if any
    for c in ['odpt:lineCode', 'odpt:stationOrder']: 
        if c in r:
            feature['properties'][c] = r[c]

    railway_geojson['features'].append(feature)

# %%
railway_dict
# Out:
# [{'@id': 'urn:ucode:_00001C000000000000010000030C46B0',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '千代田線',
#   'odpt:color': '#00BB85',
#   'owl:sameAs': 'odpt.Railway:TokyoMetro.Chiyoda',
#   'odpt:lineCode': 'C',
#   'odpt:operator': 'odpt.Operator:TokyoMetro',
#   'odpt:railwayTitle': {'en': 'Chiyoda Line',
#    'ja': '千代田線',
#    'ko': '치요다선',
#    'zh-Hans': '千代田线',
#    'zh-Hant': '千代田線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.YoyogiUehara',
#     'odpt:stationTitle': {'en': 'Yoyogi-uehara',
#      'ja': '代々木上原',
#      'ko': '요요기우에하라',
#      'ja-Hrkt': 'よよぎうえはら',
#      'zh-Hans': '代々木上原',
#      'zh-Hant': '代代木上原'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.YoyogiKoen',
#     'odpt:stationTitle': {'en': 'Yoyogi-koen',
#      'ja': '代々木公園',
#      'ko': '요요기코엔',
#      'ja-Hrkt': 'よよぎこうえん',
#      'zh-Hans': '代々木公园',
#      'zh-Hant': '代代木公園'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.MeijiJingumae',
#     'odpt:stationTitle': {'en': 'Meiji-jingumae<Harajuku>',
#      'ja': '明治神宮前〈原宿〉',
#      'ko': '메이지진구마에<하라주쿠>',
#      'ja-Hrkt': 'めいじじんぐうまえ<はらじゅく>',
#      'zh-Hans': '明治神宫前<原宿>',
#      'zh-Hant': '明治神宮前<原宿>'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.OmoteSando',
#     'odpt:stationTitle': {'en': 'Omote-sando',
#      'ja': '表参道',
#      'ko': '오모테산도',
#      'ja-Hrkt': 'おもてさんどう',
#      'zh-Hans': '表参道',
#      'zh-Hant': '表參道'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Nogizaka',
#     'odpt:stationTitle': {'en': 'Nogizaka',
#      'ja': '乃木坂',
#      'ko': '노기자카',
#      'ja-Hrkt': 'のぎざか',
#      'zh-Hans': '乃木坂',
#      'zh-Hant': '乃木坂'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Akasaka',
#     'odpt:stationTitle': {'en': 'Akasaka',
#      'ja': '赤坂',
#      'ko': '아카사카',
#      'ja-Hrkt': 'あかさか',
#      'zh-Hans': '赤坂',
#      'zh-Hant': '赤坂'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.KokkaiGijidomae',
#     'odpt:stationTitle': {'en': 'Kokkai-gijidomae',
#      'ja': '国会議事堂前',
#      'ko': '곳카이기지도마에',
#      'ja-Hrkt': 'こっかいぎじどうまえ',
#      'zh-Hans': '国会议事堂前',
#      'zh-Hant': '國會議事堂前'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Kasumigaseki',
#     'odpt:stationTitle': {'en': 'Kasumigaseki',
#      'ja': '霞ケ関',
#      'ko': '가스미가세키',
#      'ja-Hrkt': 'かすみがせき',
#      'zh-Hans': '霞关',
#      'zh-Hant': '霞關'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Hibiya',
#     'odpt:stationTitle': {'en': 'Hibiya',
#      'ja': '日比谷',
#      'ko': '히비야',
#      'ja-Hrkt': 'ひびや',
#      'zh-Hans': '日比谷',
#      'zh-Hant': '日比谷'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Nijubashimae',
#     'odpt:stationTitle': {'en': 'Nijubashimae<Marunouchi>',
#      'ja': '二重橋前〈丸の内〉',
#      'ko': '니주바시마에<마루노우치선>',
#      'ja-Hrkt': 'にじゅうばしまえ<まるのうち>',
#      'zh-Hans': '二重桥前<丸之内>',
#      'zh-Hant': '二重橋前<丸之內>'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Otemachi',
#     'odpt:stationTitle': {'en': 'Otemachi',
#      'ja': '大手町',
#      'ko': '오테마치',
#      'ja-Hrkt': 'おおてまち',
#      'zh-Hans': '大手町',
#      'zh-Hant': '大手町'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.ShinOchanomizu',
#     'odpt:stationTitle': {'en': 'Shin-ochanomizu',
#      'ja': '新御茶ノ水',
#      'ko': '신오차노미즈',
#      'ja-Hrkt': 'しんおちゃのみず',
#      'zh-Hans': '新御茶之水',
#      'zh-Hant': '新御茶之水'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Yushima',
#     'odpt:stationTitle': {'en': 'Yushima',
#      'ja': '湯島',
#      'ko': '유시마',
#      'ja-Hrkt': 'ゆしま',
#      'zh-Hans': '汤岛',
#      'zh-Hant': '湯島'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Nezu',
#     'odpt:stationTitle': {'en': 'Nezu',
#      'ja': '根津',
#      'ko': '네즈',
#      'ja-Hrkt': 'ねづ',
#      'zh-Hans': '根津',
#      'zh-Hant': '根津'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Sendagi',
#     'odpt:stationTitle': {'en': 'Sendagi',
#      'ja': '千駄木',
#      'ko': '센다기',
#      'ja-Hrkt': 'せんだぎ',
#      'zh-Hans': '千驮木',
#      'zh-Hant': '千馱木'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.NishiNippori',
#     'odpt:stationTitle': {'en': 'Nishi-nippori',
#      'ja': '西日暮里',
#      'ko': '니시닛포리',
#      'ja-Hrkt': 'にしにっぽり',
#      'zh-Hans': '西日暮里',
#      'zh-Hant': '西日暮里'}},
#    {'odpt:index': 17,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Machiya',
#     'odpt:stationTitle': {'en': 'Machiya',
#      'ja': '町屋',
#      'ko': '마치야',
#      'ja-Hrkt': 'まちや',
#      'zh-Hans': '町屋',
#      'zh-Hant': '町屋'}},
#    {'odpt:index': 18,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.KitaSenju',
#     'odpt:stationTitle': {'en': 'Kita-senju',
#      'ja': '北千住',
#      'ko': '기타센주',
#      'ja-Hrkt': 'きたせんじゅ',
#      'zh-Hans': '北千住',
#      'zh-Hant': '北千住'}},
#    {'odpt:index': 19,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Ayase',
#     'odpt:stationTitle': {'en': 'Ayase',
#      'ja': '綾瀬',
#      'ko': '아야세',
#      'ja-Hrkt': 'あやせ',
#      'zh-Hans': '绫瀬',
#      'zh-Hant': '綾瀨'}},
#    {'odpt:index': 20,
#     'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.KitaAyase',
#     'odpt:stationTitle': {'en': 'Kita-ayase',
#      'ja': '北綾瀬',
#      'ko': '기타아야세',
#      'ja-Hrkt': 'きたあやせ',
#      'zh-Hans': '北绫瀬',
#      'zh-Hant': '北綾瀨'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:TokyoMetro.KitaAyase',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:TokyoMetro.YoyogiUehara'},
#  {'@id': 'urn:ucode:_00001C000000000000010000030C46B4',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '副都心線',
#   'odpt:color': '#9C5E31',
#   'owl:sameAs': 'odpt.Railway:TokyoMetro.Fukutoshin',
#   'odpt:lineCode': 'F',
#   'odpt:operator': 'odpt.Operator:TokyoMetro',
#   'odpt:railwayTitle': {'en': 'Fukutoshin Line',
#    'ja': '副都心線',
#    'ko': '후쿠토신선',
#    'zh-Hans': '副都心线',
#    'zh-Hant': '副都心線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Wakoshi',
#     'odpt:stationTitle': {'en': 'Wakoshi',
#      'ja': '和光市',
#      'ko': '와코시',
#      'ja-Hrkt': 'わこうし',
#      'zh-Hans': '和光市',
#      'zh-Hant': '和光市'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.ChikatetsuNarimasu',
#     'odpt:stationTitle': {'en': 'Chikatetsu-narimasu',
#      'ja': '地下鉄成増',
#      'ko': '지카테쓰나리마스',
#      'ja-Hrkt': 'ちかてつなります',
#      'zh-Hans': '地铁成増',
#      'zh-Hant': '地鐵成增'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.ChikatetsuAkatsuka',
#     'odpt:stationTitle': {'en': 'Chikatetsu-akatsuka',
#      'ja': '地下鉄赤塚',
#      'ko': '지카테쓰아카쓰카',
#      'ja-Hrkt': 'ちかてつあかつか',
#      'zh-Hans': '地铁赤冢',
#      'zh-Hant': '地鐵赤塚'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Heiwadai',
#     'odpt:stationTitle': {'en': 'Heiwadai',
#      'ja': '平和台',
#      'ko': '헤이와다이',
#      'ja-Hrkt': 'へいわだい',
#      'zh-Hans': '平和台',
#      'zh-Hant': '平和台'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Hikawadai',
#     'odpt:stationTitle': {'en': 'Hikawadai',
#      'ja': '氷川台',
#      'ko': '히카와다이',
#      'ja-Hrkt': 'ひかわだい',
#      'zh-Hans': '冰川台',
#      'zh-Hant': '冰川台'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.KotakeMukaihara',
#     'odpt:stationTitle': {'en': 'Kotake-mukaihara',
#      'ja': '小竹向原',
#      'ko': '고타케무카이하라',
#      'ja-Hrkt': 'こたけむかいはら',
#      'zh-Hans': '小竹向原',
#      'zh-Hant': '小竹向原'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Senkawa',
#     'odpt:stationTitle': {'en': 'Senkawa',
#      'ja': '千川',
#      'ko': '센카와',
#      'ja-Hrkt': 'せんかわ',
#      'zh-Hans': '千川',
#      'zh-Hant': '千川'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Kanamecho',
#     'odpt:stationTitle': {'en': 'Kanamecho',
#      'ja': '要町',
#      'ko': '가나메초',
#      'ja-Hrkt': 'かなめちょう',
#      'zh-Hans': '要町',
#      'zh-Hant': '要町'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Ikebukuro',
#     'odpt:stationTitle': {'en': 'Ikebukuro',
#      'ja': '池袋',
#      'ko': '이케부쿠로',
#      'ja-Hrkt': 'いけぶくろ',
#      'zh-Hans': '池袋',
#      'zh-Hant': '池袋'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Zoshigaya',
#     'odpt:stationTitle': {'en': 'Zoshigaya',
#      'ja': '雑司が谷',
#      'ko': '조시가야',
#      'ja-Hrkt': 'ぞうしがや',
#      'zh-Hans': '杂司谷',
#      'zh-Hant': '雜司谷'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.NishiWaseda',
#     'odpt:stationTitle': {'en': 'Nishi-waseda',
#      'ja': '西早稲田',
#      'ko': '니시와세다',
#      'ja-Hrkt': 'にしわせだ',
#      'zh-Hans': '西早稻田',
#      'zh-Hant': '西早稻田'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.HigashiShinjuku',
#     'odpt:stationTitle': {'en': 'Higashi-shinjuku',
#      'ja': '東新宿',
#      'ko': '히가시신주쿠',
#      'ja-Hrkt': 'ひがししんじゅく',
#      'zh-Hans': '东新宿',
#      'zh-Hant': '東新宿'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.ShinjukuSanchome',
#     'odpt:stationTitle': {'en': 'Shinjuku-sanchome',
#      'ja': '新宿三丁目',
#      'ko': '신주쿠산초메',
#      'ja-Hrkt': 'しんじゅくさんちょうめ',
#      'zh-Hans': '新宿三丁目',
#      'zh-Hant': '新宿三丁目'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.KitaSando',
#     'odpt:stationTitle': {'en': 'Kita-sando',
#      'ja': '北参道',
#      'ko': '기타산도',
#      'ja-Hrkt': 'きたさんどう',
#      'zh-Hans': '北参道',
#      'zh-Hant': '北參道'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.MeijiJingumae',
#     'odpt:stationTitle': {'en': 'Meiji-jingumae<Harajuku>',
#      'ja': '明治神宮前〈原宿〉',
#      'ko': '메이지진구마에<하라주쿠>',
#      'ja-Hrkt': 'めいじじんぐうまえ<はらじゅく>',
#      'zh-Hans': '明治神宫前<原宿>',
#      'zh-Hant': '明治神宮前<原宿>'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Shibuya',
#     'odpt:stationTitle': {'en': 'Shibuya',
#      'ja': '渋谷',
#      'ko': '시부야',
#      'ja-Hrkt': 'しぶや',
#      'zh-Hans': '涩谷',
#      'zh-Hant': '澀谷'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:TokyoMetro.Shibuya',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:TokyoMetro.Wakoshi'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E74',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'ゆりかもめ',
#   'odpt:color': '#0065A6',
#   'owl:sameAs': 'odpt.Railway:Yurikamome.Yurikamome',
#   'odpt:lineCode': 'U',
#   'odpt:operator': 'odpt.Operator:Yurikamome',
#   'odpt:railwayTitle': {'en': 'Yurikamome line',
#    'ja': 'ゆりかもめ',
#    'ko': '유리카모메선',
#    'zh-Hans': '百合鸥线'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Shimbashi',
#     'odpt:stationTitle': {'en': 'Shimbashi',
#      'ja': '新橋',
#      'ko': '신바시',
#      'zh-Hans': '新桥'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Shiodome',
#     'odpt:stationTitle': {'en': 'Shiodome',
#      'ja': '汐留',
#      'ko': '시오도메',
#      'zh-Hans': '汐留'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Takeshiba',
#     'odpt:stationTitle': {'en': 'Takeshiba',
#      'ja': '竹芝',
#      'ko': '다케시바',
#      'zh-Hans': '竹芝'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Hinode',
#     'odpt:stationTitle': {'en': 'Hinode',
#      'ja': '日の出',
#      'ko': '히노데',
#      'zh-Hans': '日之出'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.ShibauraFuto',
#     'odpt:stationTitle': {'en': 'Shibaura-futō',
#      'ja': '芝浦ふ頭',
#      'ko': '시바우라후토',
#      'zh-Hans': '芝浦埠头'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.OdaibaKaihinkoen',
#     'odpt:stationTitle': {'en': 'Odaiba-kaihinkōen',
#      'ja': 'お台場海浜公園',
#      'ko': '오다이바카이힌코엔',
#      'zh-Hans': '御台场海滨公园'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Daiba',
#     'odpt:stationTitle': {'en': 'Daiba',
#      'ja': '台場',
#      'ko': '다이바',
#      'zh-Hans': '台场'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.TokyoInternationalCruiseTerminal',
#     'odpt:stationTitle': {'en': 'Tokyo International Cruise Terminal',
#      'ja': '東京国際クルーズターミナル',
#      'ko': '도쿄국제크루즈터미널',
#      'zh-Hans': '东京国际邮轮码头'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.TelecomCenter',
#     'odpt:stationTitle': {'en': 'Telecom Center',
#      'ja': 'テレコムセンター',
#      'ko': '텔레콤센터',
#      'zh-Hans': '远程通信中心'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Aomi',
#     'odpt:stationTitle': {'en': 'Aomi',
#      'ja': '青海',
#      'ko': '아오미',
#      'zh-Hans': '青海'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.TokyoBigSight',
#     'odpt:stationTitle': {'en': 'Tokyo Big Sight',
#      'ja': '東京ビッグサイト',
#      'ko': '도쿄빅사이트',
#      'zh-Hans': '东京国际展览中心'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Ariake',
#     'odpt:stationTitle': {'en': 'Ariake',
#      'ja': '有明',
#      'ko': '아리아케',
#      'zh-Hans': '有明'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.AriakeTennisNoMori',
#     'odpt:stationTitle': {'en': 'Ariake-tennis-no-mori',
#      'ja': '有明テニスの森',
#      'ko': '아리아케테니스노모리',
#      'zh-Hans': '有明网球之森'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.ShijoMae',
#     'odpt:stationTitle': {'en': 'Shijō-mae',
#      'ja': '市場前',
#      'ko': '시조마에',
#      'zh-Hans': '市场前'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.ShinToyosu',
#     'odpt:stationTitle': {'en': 'Shin-Toyosu',
#      'ja': '新豊洲',
#      'ko': '신토요스',
#      'zh-Hans': '新丰洲'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Toyosu',
#     'odpt:stationTitle': {'en': 'Toyosu',
#      'ja': '豊洲',
#      'ko': '도요스',
#      'zh-Hans': '丰洲'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Outbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Inbound'},
#  {'@id': 'urn:ucode:_00001C0000000000000100000327A7BA',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'つくばエクスプレス',
#   'owl:sameAs': 'odpt.Railway:MIR.TsukubaExpress',
#   'odpt:lineCode': 'TX',
#   'odpt:operator': 'odpt.Operator:MIR',
#   'odpt:railwayTitle': {'en': 'Tsukuba Express Line',
#    'ja': 'つくばエクスプレス',
#    'ko': '츠쿠바 익스프레스선',
#    'zh-Hans': '筑波特快线',
#    'zh-Hant': '筑波快線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Akihabara',
#     'odpt:stationTitle': {'en': 'Akihabara',
#      'ja': '秋葉原',
#      'ko': '아키하바라',
#      'zh-Hans': '秋叶原',
#      'zh-Hant': '秋葉原'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.ShinOkachimachi',
#     'odpt:stationTitle': {'en': 'Shin-Okachimachi',
#      'ja': '新御徒町',
#      'ko': '신 오카치마치',
#      'zh-Hans': '新御徒町',
#      'zh-Hant': '新御徒町'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Asakusa',
#     'odpt:stationTitle': {'en': 'Asakusa',
#      'ja': '浅草',
#      'ko': '아사쿠사',
#      'zh-Hans': '浅草',
#      'zh-Hant': '淺草'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.MinamiSenju',
#     'odpt:stationTitle': {'en': 'Minami-Senju',
#      'ja': '南千住',
#      'ko': '미나미 센주',
#      'zh-Hans': '南千住',
#      'zh-Hant': '南千住'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.KitaSenju',
#     'odpt:stationTitle': {'en': 'Kita-Senju',
#      'ja': '北千住',
#      'ko': '기타 센주',
#      'zh-Hans': '北千住',
#      'zh-Hant': '北千住'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Aoi',
#     'odpt:stationTitle': {'en': 'Aoi',
#      'ja': '青井',
#      'ko': '아오이',
#      'zh-Hans': '青井',
#      'zh-Hant': '青井'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Rokucho',
#     'odpt:stationTitle': {'en': 'Rokuchō',
#      'ja': '六町',
#      'ko': '로쿠초',
#      'zh-Hans': '六町',
#      'zh-Hant': '六町'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Yashio',
#     'odpt:stationTitle': {'en': 'Yashio',
#      'ja': '八潮',
#      'ko': '야시오',
#      'zh-Hans': '八潮',
#      'zh-Hant': '八潮'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.MisatoChuo',
#     'odpt:stationTitle': {'en': 'Misato-chūō',
#      'ja': '三郷中央',
#      'ko': '미사토 주오',
#      'zh-Hans': '三乡中央',
#      'zh-Hant': '三鄉中央'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.MinamiNagareyama',
#     'odpt:stationTitle': {'en': 'Minami-Nagareyama',
#      'ja': '南流山',
#      'ko': '미나미 나가레야마',
#      'zh-Hans': '南流山',
#      'zh-Hant': '南流山'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.NagareyamaCentralPark',
#     'odpt:stationTitle': {'en': 'Nagareyama-centralpark',
#      'ja': '流山セントラルパーク',
#      'ko': '나가레야마 센트럴파크',
#      'zh-Hans': '流山中央公园',
#      'zh-Hant': '流山中央公園'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.NagareyamaOtakanomori',
#     'odpt:stationTitle': {'en': 'Nagareyama-ōtakanomori',
#      'ja': '流山おおたかの森',
#      'ko': '나가레야마 오타카노모리',
#      'zh-Hans': '流山大鷹之森',
#      'zh-Hant': '流山大鷹之森'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.KashiwanohaCampus',
#     'odpt:stationTitle': {'en': 'Kashiwanoha-campus',
#      'ja': '柏の葉キャンパス',
#      'ko': '가시와노하 캠퍼스',
#      'zh-Hans': '柏之叶校园',
#      'zh-Hant': '柏之葉園地'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.KashiwaTanaka',
#     'odpt:stationTitle': {'en': 'Kashiwa-Tanaka',
#      'ja': '柏たなか',
#      'ko': '가시와 다나카',
#      'zh-Hans': '柏田中',
#      'zh-Hant': '柏田中'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Moriya',
#     'odpt:stationTitle': {'en': 'Moriya',
#      'ja': '守谷',
#      'ko': '모리야',
#      'zh-Hans': '守谷',
#      'zh-Hant': '守谷'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Miraidaira',
#     'odpt:stationTitle': {'en': 'Miraidaira',
#      'ja': 'みらい平',
#      'ko': '미라이다이라',
#      'zh-Hans': '未来平',
#      'zh-Hant': '未來平'}},
#    {'odpt:index': 17,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Midorino',
#     'odpt:stationTitle': {'en': 'Midorino',
#      'ja': 'みどりの',
#      'ko': '미도리노',
#      'zh-Hans': '绿野',
#      'zh-Hant': '綠野'}},
#    {'odpt:index': 18,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.BampakuKinenKoen',
#     'odpt:stationTitle': {'en': 'Bampaku-kinenkōen',
#      'ja': '万博記念公園',
#      'ko': '반파쿠 기넨코엔',
#      'zh-Hans': '万博纪念公园',
#      'zh-Hant': '萬博紀念公園'}},
#    {'odpt:index': 19,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.KenkyuGakuen',
#     'odpt:stationTitle': {'en': 'Kenkyū-gakuen',
#      'ja': '研究学園',
#      'ko': '겐큐 가쿠엔',
#      'zh-Hans': '研究学园',
#      'zh-Hant': '研究學園'}},
#    {'odpt:index': 20,
#     'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Tsukuba',
#     'odpt:stationTitle': {'en': 'Tsukuba',
#      'ja': 'つくば',
#      'ko': '츠쿠바',
#      'zh-Hans': '筑波',
#      'zh-Hant': '筑波'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Outbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Inbound'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E6F',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '三田線',
#   'odpt:color': '#0067B0',
#   'owl:sameAs': 'odpt.Railway:Toei.Mita',
#   'odpt:lineCode': 'I',
#   'odpt:operator': 'odpt.Operator:Toei',
#   'odpt:railwayTitle': {'en': 'Mita Line', 'ja': '三田線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:Toei.Mita.Meguro',
#     'odpt:stationTitle': {'en': 'Meguro', 'ja': '目黒'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:Toei.Mita.Shirokanedai',
#     'odpt:stationTitle': {'en': 'Shirokanedai', 'ja': '白金台'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:Toei.Mita.ShirokaneTakanawa',
#     'odpt:stationTitle': {'en': 'Shirokane-takanawa', 'ja': '白金高輪'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:Toei.Mita.Mita',
#     'odpt:stationTitle': {'en': 'Mita', 'ja': '三田'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:Toei.Mita.Shibakoen',
#     'odpt:stationTitle': {'en': 'Shibakoen', 'ja': '芝公園'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:Toei.Mita.Onarimon',
#     'odpt:stationTitle': {'en': 'Onarimon', 'ja': '御成門'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:Toei.Mita.Uchisaiwaicho',
#     'odpt:stationTitle': {'en': 'Uchisaiwaicho', 'ja': '内幸町'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:Toei.Mita.Hibiya',
#     'odpt:stationTitle': {'en': 'Hibiya', 'ja': '日比谷'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:Toei.Mita.Otemachi',
#     'odpt:stationTitle': {'en': 'Otemachi', 'ja': '大手町'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:Toei.Mita.Jimbocho',
#     'odpt:stationTitle': {'en': 'Jimbocho', 'ja': '神保町'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:Toei.Mita.Suidobashi',
#     'odpt:stationTitle': {'en': 'Suidobashi', 'ja': '水道橋'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:Toei.Mita.Kasuga',
#     'odpt:stationTitle': {'en': 'Kasuga', 'ja': '春日'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:Toei.Mita.Hakusan',
#     'odpt:stationTitle': {'en': 'Hakusan', 'ja': '白山'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:Toei.Mita.Sengoku',
#     'odpt:stationTitle': {'en': 'Sengoku', 'ja': '千石'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:Toei.Mita.Sugamo',
#     'odpt:stationTitle': {'en': 'Sugamo', 'ja': '巣鴨'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:Toei.Mita.NishiSugamo',
#     'odpt:stationTitle': {'en': 'Nishi-sugamo', 'ja': '西巣鴨'}},
#    {'odpt:index': 17,
#     'odpt:station': 'odpt.Station:Toei.Mita.ShinItabashi',
#     'odpt:stationTitle': {'en': 'Shin-itabashi', 'ja': '新板橋'}},
#    {'odpt:index': 18,
#     'odpt:station': 'odpt.Station:Toei.Mita.ItabashiKuyakushomae',
#     'odpt:stationTitle': {'en': 'Itabashi-kuyakushomae', 'ja': '板橋区役所前'}},
#    {'odpt:index': 19,
#     'odpt:station': 'odpt.Station:Toei.Mita.Itabashihoncho',
#     'odpt:stationTitle': {'en': 'Itabashihoncho', 'ja': '板橋本町'}},
#    {'odpt:index': 20,
#     'odpt:station': 'odpt.Station:Toei.Mita.Motohasunuma',
#     'odpt:stationTitle': {'en': 'Motohasunuma', 'ja': '本蓮沼'}},
#    {'odpt:index': 21,
#     'odpt:station': 'odpt.Station:Toei.Mita.ShimuraSakaue',
#     'odpt:stationTitle': {'en': 'Shimura-sakaue', 'ja': '志村坂上'}},
#    {'odpt:index': 22,
#     'odpt:station': 'odpt.Station:Toei.Mita.ShimuraSanchome',
#     'odpt:stationTitle': {'en': 'Shimura-sanchome', 'ja': '志村三丁目'}},
#    {'odpt:index': 23,
#     'odpt:station': 'odpt.Station:Toei.Mita.Hasune',
#     'odpt:stationTitle': {'en': 'Hasune', 'ja': '蓮根'}},
#    {'odpt:index': 24,
#     'odpt:station': 'odpt.Station:Toei.Mita.Nishidai',
#     'odpt:stationTitle': {'en': 'Nishidai', 'ja': '西台'}},
#    {'odpt:index': 25,
#     'odpt:station': 'odpt.Station:Toei.Mita.Takashimadaira',
#     'odpt:stationTitle': {'en': 'Takashimadaira', 'ja': '高島平'}},
#    {'odpt:index': 26,
#     'odpt:station': 'odpt.Station:Toei.Mita.ShinTakashimadaira',
#     'odpt:stationTitle': {'en': 'Shin-takashimadaira', 'ja': '新高島平'}},
#    {'odpt:index': 27,
#     'odpt:station': 'odpt.Station:Toei.Mita.NishiTakashimadaira',
#     'odpt:stationTitle': {'en': 'Nishi-takashimadaira', 'ja': '西高島平'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Northbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Southbound'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E71',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '大江戸線',
#   'odpt:color': '#CF3366',
#   'owl:sameAs': 'odpt.Railway:Toei.Oedo',
#   'odpt:lineCode': 'E',
#   'odpt:operator': 'odpt.Operator:Toei',
#   'odpt:railwayTitle': {'en': 'Oedo Line', 'ja': '大江戸線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Tochomae',
#     'odpt:stationTitle': {'en': 'Tochomae', 'ja': '都庁前'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:Toei.Oedo.ShinjukuNishiguchi',
#     'odpt:stationTitle': {'en': 'Shinjuku-nishiguchi', 'ja': '新宿西口'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:Toei.Oedo.HigashiShinjuku',
#     'odpt:stationTitle': {'en': 'Higashi-shinjuku', 'ja': '東新宿'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:Toei.Oedo.WakamatsuKawada',
#     'odpt:stationTitle': {'en': 'Wakamatsu-kawada', 'ja': '若松河田'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:Toei.Oedo.UshigomeYanagicho',
#     'odpt:stationTitle': {'en': 'Ushigome-yanagicho', 'ja': '牛込柳町'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:Toei.Oedo.UshigomeKagurazaka',
#     'odpt:stationTitle': {'en': 'Ushigome-kagurazaka', 'ja': '牛込神楽坂'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Iidabashi',
#     'odpt:stationTitle': {'en': 'Iidabashi', 'ja': '飯田橋'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Kasuga',
#     'odpt:stationTitle': {'en': 'Kasuga', 'ja': '春日'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:Toei.Oedo.HongoSanchome',
#     'odpt:stationTitle': {'en': 'Hongo-sanchome', 'ja': '本郷三丁目'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:Toei.Oedo.UenoOkachimachi',
#     'odpt:stationTitle': {'en': 'Ueno-okachimachi', 'ja': '上野御徒町'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:Toei.Oedo.ShinOkachimachi',
#     'odpt:stationTitle': {'en': 'Shin-okachimachi', 'ja': '新御徒町'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Kuramae',
#     'odpt:stationTitle': {'en': 'Kuramae', 'ja': '蔵前'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Ryogoku',
#     'odpt:stationTitle': {'en': 'Ryogoku', 'ja': '両国'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Morishita',
#     'odpt:stationTitle': {'en': 'Morishita', 'ja': '森下'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:Toei.Oedo.KiyosumiShirakawa',
#     'odpt:stationTitle': {'en': 'Kiyosumi-shirakawa', 'ja': '清澄白河'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:Toei.Oedo.MonzenNakacho',
#     'odpt:stationTitle': {'en': 'Monzen-nakacho', 'ja': '門前仲町'}},
#    {'odpt:index': 17,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Tsukishima',
#     'odpt:stationTitle': {'en': 'Tsukishima', 'ja': '月島'}},
#    {'odpt:index': 18,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Kachidoki',
#     'odpt:stationTitle': {'en': 'Kachidoki', 'ja': '勝どき'}},
#    {'odpt:index': 19,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Tsukijishijo',
#     'odpt:stationTitle': {'en': 'Tsukijishijo', 'ja': '築地市場'}},
#    {'odpt:index': 20,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Shiodome',
#     'odpt:stationTitle': {'en': 'Shiodome', 'ja': '汐留'}},
#    {'odpt:index': 21,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Daimon',
#     'odpt:stationTitle': {'en': 'Daimon', 'ja': '大門'}},
#    {'odpt:index': 22,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Akabanebashi',
#     'odpt:stationTitle': {'en': 'Akabanebashi', 'ja': '赤羽橋'}},
#    {'odpt:index': 23,
#     'odpt:station': 'odpt.Station:Toei.Oedo.AzabuJuban',
#     'odpt:stationTitle': {'en': 'Azabu-juban', 'ja': '麻布十番'}},
#    {'odpt:index': 24,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Roppongi',
#     'odpt:stationTitle': {'en': 'Roppongi', 'ja': '六本木'}},
#    {'odpt:index': 25,
#     'odpt:station': 'odpt.Station:Toei.Oedo.AoyamaItchome',
#     'odpt:stationTitle': {'en': 'Aoyama-itchome', 'ja': '青山一丁目'}},
#    {'odpt:index': 26,
#     'odpt:station': 'odpt.Station:Toei.Oedo.KokuritsuKyogijo',
#     'odpt:stationTitle': {'en': 'Kokuritsu-kyogijo', 'ja': '国立競技場'}},
#    {'odpt:index': 27,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Yoyogi',
#     'odpt:stationTitle': {'en': 'Yoyogi', 'ja': '代々木'}},
#    {'odpt:index': 28,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Shinjuku',
#     'odpt:stationTitle': {'en': 'Shinjuku', 'ja': '新宿'}},
#    {'odpt:index': 29,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Tochomae',
#     'odpt:stationTitle': {'en': 'Tochomae', 'ja': '都庁前'}},
#    {'odpt:index': 30,
#     'odpt:station': 'odpt.Station:Toei.Oedo.NishiShinjukuGochome',
#     'odpt:stationTitle': {'en': 'Nishi-shinjuku-gochome', 'ja': '西新宿五丁目'}},
#    {'odpt:index': 31,
#     'odpt:station': 'odpt.Station:Toei.Oedo.NakanoSakaue',
#     'odpt:stationTitle': {'en': 'Nakano-sakaue', 'ja': '中野坂上'}},
#    {'odpt:index': 32,
#     'odpt:station': 'odpt.Station:Toei.Oedo.HigashiNakano',
#     'odpt:stationTitle': {'en': 'Higashi-nakano', 'ja': '東中野'}},
#    {'odpt:index': 33,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Nakai',
#     'odpt:stationTitle': {'en': 'Nakai', 'ja': '中井'}},
#    {'odpt:index': 34,
#     'odpt:station': 'odpt.Station:Toei.Oedo.OchiaiMinamiNagasaki',
#     'odpt:stationTitle': {'en': 'Ochiai-minami-nagasaki', 'ja': '落合南長崎'}},
#    {'odpt:index': 35,
#     'odpt:station': 'odpt.Station:Toei.Oedo.ShinEgota',
#     'odpt:stationTitle': {'en': 'Shin-egota', 'ja': '新江古田'}},
#    {'odpt:index': 36,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Nerima',
#     'odpt:stationTitle': {'en': 'Nerima', 'ja': '練馬'}},
#    {'odpt:index': 37,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Toshimaen',
#     'odpt:stationTitle': {'en': 'Toshimaen', 'ja': '豊島園'}},
#    {'odpt:index': 38,
#     'odpt:station': 'odpt.Station:Toei.Oedo.NerimaKasugacho',
#     'odpt:stationTitle': {'en': 'Nerima-kasugacho', 'ja': '練馬春日町'}},
#    {'odpt:index': 39,
#     'odpt:station': 'odpt.Station:Toei.Oedo.Hikarigaoka',
#     'odpt:stationTitle': {'en': 'Hikarigaoka', 'ja': '光が丘'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:OuterLoop',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:InnerLoop'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E28',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '南武線',
#   'owl:sameAs': 'odpt.Railway:JR-East.Nambu',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:railwayTitle': {'en': 'Nambu Line', 'ja': '南武線'},
#   'odpt:stationOrder': []},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E0E',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '青梅線',
#   'owl:sameAs': 'odpt.Railway:JR-East.Ome',
#   'odpt:operator': 'odpt.Operator:JR-East',
#   'odpt:railwayTitle': {'en': 'Ome Line', 'ja': '青梅線'},
#   'odpt:stationOrder': []},
#  {'@id': 'urn:ucode:_00001C00000000000001000003464DAE',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '多摩モノレール',
#   'odpt:color': '#286460',
#   'owl:sameAs': 'odpt.Railway:TamaMonorail.TamaMonorail',
#   'odpt:lineCode': 'TT',
#   'odpt:operator': 'odpt.Operator:TamaMonorail',
#   'odpt:railwayTitle': {'en': 'Tama Monorail Line', 'ja': '多摩モノレール'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TamaCenter',
#     'odpt:stationTitle': {'en': 'Tama Center', 'ja': '多摩センター'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Matsugaya',
#     'odpt:stationTitle': {'en': 'Matsugaya', 'ja': '松が谷'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.OtsukaTeikyoDaigaku',
#     'odpt:stationTitle': {'en': 'Otsuka-Teikyo-Daigaku', 'ja': '大塚・帝京大学'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.ChuoDaigakuMeiseiDaigaku',
#     'odpt:stationTitle': {'en': 'Chuo-Daigaku-Meisei-Daigaku',
#      'ja': '中央大学・明星大学'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TamaDobutsukoen',
#     'odpt:stationTitle': {'en': 'Tama-Dobutsukoen', 'ja': '多摩動物公園'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Hodokubo',
#     'odpt:stationTitle': {'en': 'Hodokubo', 'ja': '程久保'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Takahatafudo',
#     'odpt:stationTitle': {'en': 'Takahatafudo', 'ja': '高幡不動'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Manganji',
#     'odpt:stationTitle': {'en': 'Manganji', 'ja': '万願寺'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Koshukaido',
#     'odpt:stationTitle': {'en': 'Koshukaido', 'ja': '甲州街道'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.ShibasakiTaiikukan',
#     'odpt:stationTitle': {'en': 'Shibasaki-Taiikukan', 'ja': '柴崎体育館'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TachikawaMinami',
#     'odpt:stationTitle': {'en': 'Tachikawa-Minami', 'ja': '立川南'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TachikawaKita',
#     'odpt:stationTitle': {'en': 'Tachikawa-Kita', 'ja': '立川北'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Takamatsu',
#     'odpt:stationTitle': {'en': 'Takamatsu', 'ja': '高松'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Tachihi',
#     'odpt:stationTitle': {'en': 'Tachihi', 'ja': '立飛'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.IzumiTaiikukan',
#     'odpt:stationTitle': {'en': 'Izumi-Taiikukan', 'ja': '泉体育館'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.SunagawaNanaban',
#     'odpt:stationTitle': {'en': 'Sunagawa-Nanaban', 'ja': '砂川七番'}},
#    {'odpt:index': 17,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TamagawaJosui',
#     'odpt:stationTitle': {'en': 'Tamagawa-Josui', 'ja': '玉川上水'}},
#    {'odpt:index': 18,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Sakurakaido',
#     'odpt:stationTitle': {'en': 'Sakurakaido', 'ja': '桜街道'}},
#    {'odpt:index': 19,
#     'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Kamikitadai',
#     'odpt:stationTitle': {'en': 'Kamikitadai', 'ja': '上北台'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Northbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Southbound'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003395505',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': 'グリーンライン',
#   'odpt:color': '#00B050',
#   'owl:sameAs': 'odpt.Railway:YokohamaMunicipal.Green',
#   'odpt:lineCode': 'G',
#   'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#   'odpt:railwayTitle': {'en': 'Green Line', 'ja': 'グリーンライン'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.Nakayama',
#     'odpt:stationTitle': {'en': 'Nakayama', 'ja': '中山'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.Kawawacho',
#     'odpt:stationTitle': {'en': 'Kawawacho', 'ja': '川和町'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.TsuzukiFureainooka',
#     'odpt:stationTitle': {'en': 'Tsuzuki-fureainooka', 'ja': '都筑ふれあいの丘'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.CenterMinami',
#     'odpt:stationTitle': {'en': 'Center Minami', 'ja': 'センター南'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.CenterKita',
#     'odpt:stationTitle': {'en': 'Center Kita', 'ja': 'センター北'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.KitaYamata',
#     'odpt:stationTitle': {'en': 'Kita-Yamata', 'ja': '北山田'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.HigashiYamata',
#     'odpt:stationTitle': {'en': 'Higashi-Yamata', 'ja': '東山田'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.Takata',
#     'odpt:stationTitle': {'en': 'Takata', 'ja': '高田'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.HiyoshiHoncho',
#     'odpt:stationTitle': {'en': 'Hiyoshi-Honcho', 'ja': '日吉本町'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.Hiyoshi',
#     'odpt:stationTitle': {'en': 'Hiyoshi', 'ja': '日吉'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Inbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Outbound'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003230642',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '箱根登山線',
#   'owl:sameAs': 'odpt.Railway:OdakyuHakone.HakoneTozan',
#   'odpt:operator': 'odpt.Operator:OdakyuHakone',
#   'odpt:railwayTitle': {'en': 'Hakone-Tozan Line', 'ja': '箱根登山線'},
#   'odpt:stationOrder': []},
#  {'@id': 'urn:ucode:_00001C000000000000010000030C46AC',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '銀座線',
#   'odpt:color': '#FF9500',
#   'owl:sameAs': 'odpt.Railway:TokyoMetro.Ginza',
#   'odpt:lineCode': 'G',
#   'odpt:operator': 'odpt.Operator:TokyoMetro',
#   'odpt:railwayTitle': {'en': 'Ginza Line',
#    'ja': '銀座線',
#    'ko': '긴자선',
#    'zh-Hans': '银座线',
#    'zh-Hant': '銀座線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Shibuya',
#     'odpt:stationTitle': {'en': 'Shibuya',
#      'ja': '渋谷',
#      'ko': '시부야',
#      'ja-Hrkt': 'しぶや',
#      'zh-Hans': '涩谷',
#      'zh-Hant': '澀谷'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.OmoteSando',
#     'odpt:stationTitle': {'en': 'Omote-sando',
#      'ja': '表参道',
#      'ko': '오모테산도',
#      'ja-Hrkt': 'おもてさんどう',
#      'zh-Hans': '表参道',
#      'zh-Hant': '表參道'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Gaiemmae',
#     'odpt:stationTitle': {'en': 'Gaiemmae',
#      'ja': '外苑前',
#      'ko': '가이엔마에',
#      'ja-Hrkt': 'がいえんまえ',
#      'zh-Hans': '外苑前',
#      'zh-Hant': '外苑前'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.AoyamaItchome',
#     'odpt:stationTitle': {'en': 'Aoyama-itchome',
#      'ja': '青山一丁目',
#      'ko': '아오야마잇초메',
#      'ja-Hrkt': 'あおやまいっちょうめ',
#      'zh-Hans': '青山一丁目',
#      'zh-Hant': '青山一丁目'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.AkasakaMitsuke',
#     'odpt:stationTitle': {'en': 'Akasaka-mitsuke',
#      'ja': '赤坂見附',
#      'ko': '아카사카미쓰케',
#      'ja-Hrkt': 'あかさかみつけ',
#      'zh-Hans': '赤坂见附',
#      'zh-Hant': '赤坂見附'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.TameikeSanno',
#     'odpt:stationTitle': {'en': 'Tameike-sanno',
#      'ja': '溜池山王',
#      'ko': '다메이케산노',
#      'ja-Hrkt': 'ためいけさんのう',
#      'zh-Hans': '溜池山王',
#      'zh-Hant': '溜池山王'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Toranomon',
#     'odpt:stationTitle': {'en': 'Toranomon',
#      'ja': '虎ノ門',
#      'ko': '도라노몬',
#      'ja-Hrkt': 'とらのもん',
#      'zh-Hans': '虎之门',
#      'zh-Hant': '虎之門'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Shimbashi',
#     'odpt:stationTitle': {'en': 'Shimbashi',
#      'ja': '新橋',
#      'ko': '신바시',
#      'ja-Hrkt': 'しんばし',
#      'zh-Hans': '新桥',
#      'zh-Hant': '新橋'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Ginza',
#     'odpt:stationTitle': {'en': 'Ginza',
#      'ja': '銀座',
#      'ko': '긴자',
#      'ja-Hrkt': 'ぎんざ',
#      'zh-Hans': '银座',
#      'zh-Hant': '銀座'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Kyobashi',
#     'odpt:stationTitle': {'en': 'Kyobashi',
#      'ja': '京橋',
#      'ko': '교바시',
#      'ja-Hrkt': 'きょうばし',
#      'zh-Hans': '京桥',
#      'zh-Hant': '京橋'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Nihombashi',
#     'odpt:stationTitle': {'en': 'Nihombashi',
#      'ja': '日本橋',
#      'ko': '니혼바시',
#      'ja-Hrkt': 'にほんばし',
#      'zh-Hans': '日本桥',
#      'zh-Hant': '日本橋'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Mitsukoshimae',
#     'odpt:stationTitle': {'en': 'Mitsukoshimae',
#      'ja': '三越前',
#      'ko': '미쓰코시마에',
#      'ja-Hrkt': 'みつこしまえ',
#      'zh-Hans': '三越前',
#      'zh-Hant': '三越前'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Kanda',
#     'odpt:stationTitle': {'en': 'Kanda',
#      'ja': '神田',
#      'ko': '간다',
#      'ja-Hrkt': 'かんだ',
#      'zh-Hans': '神田',
#      'zh-Hant': '神田'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Suehirocho',
#     'odpt:stationTitle': {'en': 'Suehirocho',
#      'ja': '末広町',
#      'ko': '수에히로초',
#      'ja-Hrkt': 'すえひろちょう',
#      'zh-Hans': '末广町',
#      'zh-Hant': '末廣町'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.UenoHirokoji',
#     'odpt:stationTitle': {'en': 'Ueno-hirokoji',
#      'ja': '上野広小路',
#      'ko': '우에노히로코지',
#      'ja-Hrkt': 'うえのひろこうじ',
#      'zh-Hans': '上野广小路',
#      'zh-Hant': '上野廣小路'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Ueno',
#     'odpt:stationTitle': {'en': 'Ueno',
#      'ja': '上野',
#      'ko': '우에노',
#      'ja-Hrkt': 'うえの',
#      'zh-Hans': '上野',
#      'zh-Hant': '上野'}},
#    {'odpt:index': 17,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Inaricho',
#     'odpt:stationTitle': {'en': 'Inaricho',
#      'ja': '稲荷町',
#      'ko': '이나리초',
#      'ja-Hrkt': 'いなりちょう',
#      'zh-Hans': '稻荷町',
#      'zh-Hant': '稻荷町'}},
#    {'odpt:index': 18,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Tawaramachi',
#     'odpt:stationTitle': {'en': 'Tawaramachi',
#      'ja': '田原町',
#      'ko': '다와라마치',
#      'ja-Hrkt': 'たわらまち',
#      'zh-Hans': '田原町',
#      'zh-Hant': '田原町'}},
#    {'odpt:index': 19,
#     'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Asakusa',
#     'odpt:stationTitle': {'en': 'Asakusa',
#      'ja': '浅草',
#      'ko': '아사쿠사',
#      'ja-Hrkt': 'あさくさ',
#      'zh-Hans': '浅草',
#      'zh-Hant': '淺草'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:TokyoMetro.Asakusa',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:TokyoMetro.Shibuya'},
#  {'@id': 'urn:ucode:_00001C000000000000010000030C46B2',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '半蔵門線',
#   'odpt:color': '#8F76D6',
#   'owl:sameAs': 'odpt.Railway:TokyoMetro.Hanzomon',
#   'odpt:lineCode': 'Z',
#   'odpt:operator': 'odpt.Operator:TokyoMetro',
#   'odpt:railwayTitle': {'en': 'Hanzomon Line',
#    'ja': '半蔵門線',
#    'ko': '한조몬선',
#    'zh-Hans': '半藏门线',
#    'zh-Hant': '半藏門線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Shibuya',
#     'odpt:stationTitle': {'en': 'Shibuya',
#      'ja': '渋谷',
#      'ko': '시부야',
#      'ja-Hrkt': 'しぶや',
#      'zh-Hans': '涩谷',
#      'zh-Hant': '澀谷'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.OmoteSando',
#     'odpt:stationTitle': {'en': 'Omote-sando',
#      'ja': '表参道',
#      'ko': '오모테산도',
#      'ja-Hrkt': 'おもてさんどう',
#      'zh-Hans': '表参道',
#      'zh-Hant': '表參道'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.AoyamaItchome',
#     'odpt:stationTitle': {'en': 'Aoyama-itchome',
#      'ja': '青山一丁目',
#      'ko': '아오야마잇초메',
#      'ja-Hrkt': 'あおやまいっちょうめ',
#      'zh-Hans': '青山一丁目',
#      'zh-Hant': '青山一丁目'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Nagatacho',
#     'odpt:stationTitle': {'en': 'Nagatacho',
#      'ja': '永田町',
#      'ko': '나가타초',
#      'ja-Hrkt': 'ながたちょう',
#      'zh-Hans': '永田町',
#      'zh-Hant': '永田町'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Hanzomon',
#     'odpt:stationTitle': {'en': 'Hanzomon',
#      'ja': '半蔵門',
#      'ko': '한조몬',
#      'ja-Hrkt': 'はんぞうもん',
#      'zh-Hans': '半藏门',
#      'zh-Hant': '半藏門'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Kudanshita',
#     'odpt:stationTitle': {'en': 'Kudanshita',
#      'ja': '九段下',
#      'ko': '구단시타',
#      'ja-Hrkt': 'くだんした',
#      'zh-Hans': '九段下',
#      'zh-Hant': '九段下'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Jimbocho',
#     'odpt:stationTitle': {'en': 'Jimbocho',
#      'ja': '神保町',
#      'ko': '진보초',
#      'ja-Hrkt': 'じんぼうちょう',
#      'zh-Hans': '神保町',
#      'zh-Hant': '神保町'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Otemachi',
#     'odpt:stationTitle': {'en': 'Otemachi',
#      'ja': '大手町',
#      'ko': '오테마치',
#      'ja-Hrkt': 'おおてまち',
#      'zh-Hans': '大手町',
#      'zh-Hant': '大手町'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Mitsukoshimae',
#     'odpt:stationTitle': {'en': 'Mitsukoshimae',
#      'ja': '三越前',
#      'ko': '미쓰코시마에',
#      'ja-Hrkt': 'みつこしまえ',
#      'zh-Hans': '三越前',
#      'zh-Hant': '三越前'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Suitengumae',
#     'odpt:stationTitle': {'en': 'Suitengumae',
#      'ja': '水天宮前',
#      'ko': '스이텐구마에',
#      'ja-Hrkt': 'すいてんぐうまえ',
#      'zh-Hans': '水天宮前',
#      'zh-Hant': '水天宮前'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.KiyosumiShirakawa',
#     'odpt:stationTitle': {'en': 'Kiyosumi-shirakawa',
#      'ja': '清澄白河',
#      'ko': '기요스미시라카와',
#      'ja-Hrkt': 'きよすみしらかわ',
#      'zh-Hans': '清澄白河',
#      'zh-Hant': '清澄白河'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Sumiyoshi',
#     'odpt:stationTitle': {'en': 'Sumiyoshi',
#      'ja': '住吉',
#      'ko': '수미요시',
#      'ja-Hrkt': 'すみよし',
#      'zh-Hans': '住吉',
#      'zh-Hant': '住吉'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Kinshicho',
#     'odpt:stationTitle': {'en': 'Kinshicho',
#      'ja': '錦糸町',
#      'ko': '긴시초',
#      'ja-Hrkt': 'きんしちょう',
#      'zh-Hans': '锦糸町',
#      'zh-Hant': '錦糸町'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Oshiage',
#     'odpt:stationTitle': {'en': 'Oshiage<SKYTREE>',
#      'ja': '押上〈スカイツリー前〉',
#      'ko': '오시아게<스가이트리>',
#      'ja-Hrkt': 'おしあげ<スカイツリーまえ>',
#      'zh-Hans': '押上<晴空塔>',
#      'zh-Hant': '押上<晴空塔>'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:TokyoMetro.Oshiage',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:TokyoMetro.Shibuya'},
#  {'@id': 'urn:ucode:_00001C000000000000010000030C46AE',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-06-27T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '日比谷線',
#   'odpt:color': '#B5B5AC',
#   'owl:sameAs': 'odpt.Railway:TokyoMetro.Hibiya',
#   'odpt:lineCode': 'H',
#   'odpt:operator': 'odpt.Operator:TokyoMetro',
#   'odpt:railwayTitle': {'en': 'Hibiya Line',
#    'ja': '日比谷線',
#    'ko': '히비야선',
#    'zh-Hans': '日比谷线',
#    'zh-Hant': '日比谷線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hibiya.NakaMeguro',
#     'odpt:stationTitle': {'en': 'Naka-meguro',
#      'ja': '中目黒',
#      'ko': '나카메구로',
#      'ja-Hrkt': 'なかめぐろ',
#      'zh-Hans': '中目黒',
#      'zh-Hant': '中目黑'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hibiya.Ebisu',
#     'odpt:stationTitle': {'en': 'Ebisu',
#      'ja': '恵比寿',
#      'ko': '에비스',
#      'ja-Hrkt': 'えびす',
#      'zh-Hans': '恵比寿',
#      'zh-Hant': '惠比壽'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hibiya.HiroO',
#     'odpt:stationTitle': {'en': 'Hiro-o',
#      'ja': '広尾',
#      'ko': '히로오',
#      'ja-Hrkt': 'ひろお',
#      'zh-Hans': '广尾',
#      'zh-Hant': '廣尾'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hibiya.Roppongi',
#     'odpt:stationTitle': {'en': 'Roppongi',
#      'ja': '六本木',
#      'ko': '롯폰기',
#      'ja-Hrkt': 'ろっぽんぎ',
#      'zh-Hans': '六本木',
#      'zh-Hant': '六本木'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:TokyoMetro.Hibiya.Kamiyacho',
#     'odpt:stationTitle': {'en': 'Kamiyacho',
#      'ja': '神谷町',
#      'ko': '가미야초',
#      'ja-Hrkt': 'かみやちょう',
#      'zh-Hans': '神谷町',
#      'zh-Hant': '神谷町'}},
#    {'odpt:index': 6,
# ...
#     'odpt:stationTitle': {'en': 'Koizumimachi',
#      'ja': '小泉町',
#      'ko': '고이즈미마치',
#      'ja-Hrkt': 'こいずみまち',
#      'zh-Hans': '小泉町',
#      'zh-Hant': '小泉町'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:Tobu.Koizumi.NishiKoizumi',
#     'odpt:stationTitle': {'en': 'Nishi-koizumi',
#      'ja': '西小泉',
#      'ko': '니시코이즈미',
#      'ja-Hrkt': 'にしこいずみ',
#      'zh-Hans': '西小泉',
#      'zh-Hant': '西小泉'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Outbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Inbound'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E68',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '日光線',
#   'odpt:color': '#F5A302',
#   'owl:sameAs': 'odpt.Railway:Tobu.Nikko',
#   'odpt:operator': 'odpt.Operator:Tobu',
#   'odpt:railwayTitle': {'en': 'Nikko Line',
#    'ja': '日光線',
#    'ko': '닛코선',
#    'ja-Hrkt': 'にっこうせん',
#    'zh-Hans': '日光线',
#    'zh-Hant': '日光線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.TobuDobutsuKoen',
#     'odpt:stationTitle': {'en': 'Tobu-dobutsu-koen',
#      'ja': '東武動物公園',
#      'ko': '도부도부쓰코엔',
#      'ja-Hrkt': 'とうぶどうぶつこうえん',
#      'zh-Hans': '东武动物公园',
#      'zh-Hant': '東武動物公園'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.SugitoTakanodai',
#     'odpt:stationTitle': {'en': 'Sugito-takanodai',
#      'ja': '杉戸高野台',
#      'ko': '스기토타카노다이',
#      'ja-Hrkt': 'すぎとたかのだい',
#      'zh-Hans': '杉户高野台',
#      'zh-Hant': '杉戶高野台'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Satte',
#     'odpt:stationTitle': {'en': 'Satte',
#      'ja': '幸手',
#      'ko': '삿테',
#      'ja-Hrkt': 'さって',
#      'zh-Hans': '幸手',
#      'zh-Hant': '幸手'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.MinamiKurihashi',
#     'odpt:stationTitle': {'en': 'Minami-kurihashi',
#      'ja': '南栗橋',
#      'ko': '미나미쿠리하시',
#      'ja-Hrkt': 'みなみくりはし',
#      'zh-Hans': '南栗桥',
#      'zh-Hant': '南栗橋'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Kurihashi',
#     'odpt:stationTitle': {'en': 'Kurihashi',
#      'ja': '栗橋',
#      'ko': '구리하시',
#      'ja-Hrkt': 'くりはし',
#      'zh-Hans': '栗桥',
#      'zh-Hant': '栗橋'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.ShinKoga',
#     'odpt:stationTitle': {'en': 'Shin-koga',
#      'ja': '新古河',
#      'ko': '신코가',
#      'ja-Hrkt': 'しんこが',
#      'zh-Hans': '新古河',
#      'zh-Hant': '新古河'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Yagyu',
#     'odpt:stationTitle': {'en': 'Yagyu',
#      'ja': '柳生',
#      'ko': '야규',
#      'ja-Hrkt': 'やぎゅう',
#      'zh-Hans': '柳生',
#      'zh-Hant': '柳生'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.ItakuraToyodaimae',
#     'odpt:stationTitle': {'en': 'Itakura-toyodaimae',
#      'ja': '板倉東洋大前',
#      'ko': '이타쿠라토요다이마에',
#      'ja-Hrkt': 'いたくらとうようだいまえ',
#      'zh-Hans': '板仓东洋大前',
#      'zh-Hant': '板倉東洋大前'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Fujioka',
#     'odpt:stationTitle': {'en': 'Fujioka',
#      'ja': '藤岡',
#      'ko': '후지오카',
#      'ja-Hrkt': 'ふじおか',
#      'zh-Hans': '藤冈',
#      'zh-Hant': '藤岡'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Shizuwa',
#     'odpt:stationTitle': {'en': 'Shizuwa',
#      'ja': '静和',
#      'ko': '시즈와',
#      'ja-Hrkt': 'しずわ',
#      'zh-Hans': '静和',
#      'zh-Hant': '靜和'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.ShinOhirashita',
#     'odpt:stationTitle': {'en': 'Shin-ohirashita',
#      'ja': '新大平下',
#      'ko': '신오히라시타',
#      'ja-Hrkt': 'しんおおひらした',
#      'zh-Hans': '新大平下',
#      'zh-Hant': '新大平下'}},
#    {'odpt:index': 12,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Tochigi',
#     'odpt:stationTitle': {'en': 'Tochigi',
#      'ja': '栃木',
#      'ko': '도치기',
#      'ja-Hrkt': 'とちぎ',
#      'zh-Hans': '枥木',
#      'zh-Hant': '櫔木'}},
#    {'odpt:index': 13,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.ShinTochigi',
#     'odpt:stationTitle': {'en': 'Shin-tochigi',
#      'ja': '新栃木',
#      'ko': '신토치기',
#      'ja-Hrkt': 'しんとちぎ',
#      'zh-Hans': '新枥木',
#      'zh-Hant': '新櫔木'}},
#    {'odpt:index': 14,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Kassemba',
#     'odpt:stationTitle': {'en': 'Kassemba',
#      'ja': '合戦場',
#      'ko': '갓센바',
#      'ja-Hrkt': 'かっせんば',
#      'zh-Hans': '合战场',
#      'zh-Hant': '合戰場'}},
#    {'odpt:index': 15,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Ienaka',
#     'odpt:stationTitle': {'en': 'Ienaka',
#      'ja': '家中',
#      'ko': '이에나카',
#      'ja-Hrkt': 'いえなか',
#      'zh-Hans': '家中',
#      'zh-Hant': '家中'}},
#    {'odpt:index': 16,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.TobuKanasaki',
#     'odpt:stationTitle': {'en': 'Tobu-kanasaki',
#      'ja': '東武金崎',
#      'ko': '도부카나사키',
#      'ja-Hrkt': 'とうぶかなさき',
#      'zh-Hans': '东武金崎',
#      'zh-Hant': '東武金崎'}},
#    {'odpt:index': 17,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Niregi',
#     'odpt:stationTitle': {'en': 'Niregi',
#      'ja': '楡木',
#      'ko': '니레기',
#      'ja-Hrkt': 'にれぎ',
#      'zh-Hans': '榆木',
#      'zh-Hant': '榆木'}},
#    {'odpt:index': 18,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Momiyama',
#     'odpt:stationTitle': {'en': 'Momiyama',
#      'ja': '樅山',
#      'ko': '모미야마',
#      'ja-Hrkt': 'もみやま',
#      'zh-Hans': '枞山',
#      'zh-Hant': '樅山'}},
#    {'odpt:index': 19,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.ShinKanuma',
#     'odpt:stationTitle': {'en': 'Shin-kanuma',
#      'ja': '新鹿沼',
#      'ko': '신카누마',
#      'ja-Hrkt': 'しんかぬま',
#      'zh-Hans': '新鹿沼',
#      'zh-Hant': '新鹿沼'}},
#    {'odpt:index': 20,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.KitaKanuma',
#     'odpt:stationTitle': {'en': 'Kita-kanuma',
#      'ja': '北鹿沼',
#      'ko': '기타카누마',
#      'ja-Hrkt': 'きたかぬま',
#      'zh-Hans': '北鹿沼',
#      'zh-Hant': '北鹿沼'}},
#    {'odpt:index': 21,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Itaga',
#     'odpt:stationTitle': {'en': 'Itaga',
#      'ja': '板荷',
#      'ko': '이타가',
#      'ja-Hrkt': 'いたが',
#      'zh-Hans': '板荷',
#      'zh-Hant': '板荷'}},
#    {'odpt:index': 22,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.ShimoGoshiro',
#     'odpt:stationTitle': {'en': 'Shimo-goshiro',
#      'ja': '下小代',
#      'ko': '시모고시로',
#      'ja-Hrkt': 'しもごしろ',
#      'zh-Hans': '下小代',
#      'zh-Hant': '下小代'}},
#    {'odpt:index': 23,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.Myojin',
#     'odpt:stationTitle': {'en': 'Myojin',
#      'ja': '明神',
#      'ko': '묘진',
#      'ja-Hrkt': 'みょうじん',
#      'zh-Hans': '明神',
#      'zh-Hant': '明神'}},
#    {'odpt:index': 24,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.ShimoImaichi',
#     'odpt:stationTitle': {'en': 'Shimo-imaichi',
#      'ja': '下今市',
#      'ko': '시모이마이치',
#      'ja-Hrkt': 'しもいまいち',
#      'zh-Hans': '下今市',
#      'zh-Hant': '下今市'}},
#    {'odpt:index': 25,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.KamiImaichi',
#     'odpt:stationTitle': {'en': 'Kami-imaichi',
#      'ja': '上今市',
#      'ko': '가미이마이치',
#      'ja-Hrkt': 'かみいまいち',
#      'zh-Hans': '上今市',
#      'zh-Hant': '上今市'}},
#    {'odpt:index': 26,
#     'odpt:station': 'odpt.Station:Tobu.Nikko.TobuNikko',
#     'odpt:stationTitle': {'en': 'Tobu-nikko',
#      'ja': '東武日光',
#      'ko': '도부닛코',
#      'ja-Hrkt': 'とうぶにっこう',
#      'zh-Hans': '东武日光',
#      'zh-Hant': '東武日光'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Outbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Inbound'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E6D',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '越生線',
#   'odpt:color': '#10428B',
#   'owl:sameAs': 'odpt.Railway:Tobu.Ogose',
#   'odpt:lineCode': 'TJ',
#   'odpt:operator': 'odpt.Operator:Tobu',
#   'odpt:railwayTitle': {'en': 'Ogose Line',
#    'ja': '越生線',
#    'ko': '오고세선',
#    'ja-Hrkt': 'おごせせん',
#    'zh-Hans': '越生线',
#    'zh-Hant': '越生線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:Tobu.Ogose.Sakado',
#     'odpt:stationTitle': {'en': 'Sakado',
#      'ja': '坂戸',
#      'ko': '사카도',
#      'ja-Hrkt': 'さかど',
#      'zh-Hans': '坂户',
#      'zh-Hant': '坂戶'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:Tobu.Ogose.Ippommatsu',
#     'odpt:stationTitle': {'en': 'Ippommatsu',
#      'ja': '一本松',
#      'ko': '잇폰마쓰',
#      'ja-Hrkt': 'いっぽんまつ',
#      'zh-Hans': '一本松',
#      'zh-Hant': '一本松'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:Tobu.Ogose.NishiOya',
#     'odpt:stationTitle': {'en': 'Nishi-oya',
#      'ja': '西大家',
#      'ko': '니시오야',
#      'ja-Hrkt': 'にしおおや',
#      'zh-Hans': '西大家',
#      'zh-Hant': '西大家'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:Tobu.Ogose.Kawakado',
#     'odpt:stationTitle': {'en': 'Kawakado',
#      'ja': '川角',
#      'ko': '가와카도',
#      'ja-Hrkt': 'かわかど',
#      'zh-Hans': '川角',
#      'zh-Hant': '川角'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:Tobu.Ogose.BushuNagase',
#     'odpt:stationTitle': {'en': 'Bushu-nagase',
#      'ja': '武州長瀬',
#      'ko': '부슈나가세',
#      'ja-Hrkt': 'ぶしゅうながせ',
#      'zh-Hans': '武州长濑',
#      'zh-Hant': '武州長瀨'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:Tobu.Ogose.HigashiMoro',
#     'odpt:stationTitle': {'en': 'Higashi-moro',
#      'ja': '東毛呂',
#      'ko': '히가시모로',
#      'ja-Hrkt': 'ひがしもろ',
#      'zh-Hans': '东毛吕',
#      'zh-Hant': '東毛呂'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:Tobu.Ogose.BushuKarasawa',
#     'odpt:stationTitle': {'en': 'Bushu-karasawa',
#      'ja': '武州唐沢',
#      'ko': '부슈카라사와',
#      'ja-Hrkt': 'ぶしゅうからさわ',
#      'zh-Hans': '武州唐沢',
#      'zh-Hant': '武州唐澤'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:Tobu.Ogose.Ogose',
#     'odpt:stationTitle': {'en': 'Ogose',
#      'ja': '越生',
#      'ko': '오고세',
#      'ja-Hrkt': 'おごせ',
#      'zh-Hans': '越生',
#      'zh-Hant': '越生'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Outbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Inbound'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E65',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '佐野線',
#   'odpt:color': '#E62119',
#   'owl:sameAs': 'odpt.Railway:Tobu.Sano',
#   'odpt:lineCode': 'TI',
#   'odpt:operator': 'odpt.Operator:Tobu',
#   'odpt:railwayTitle': {'en': 'Sano Line',
#    'ja': '佐野線',
#    'ko': '사노선',
#    'ja-Hrkt': 'さのせん',
#    'zh-Hans': '佐野线',
#    'zh-Hant': '佐野線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Tatebayashi',
#     'odpt:stationTitle': {'en': 'Tatebayashi',
#      'ja': '館林',
#      'ko': '다테바야시',
#      'ja-Hrkt': 'たてばやし',
#      'zh-Hans': '馆林',
#      'zh-Hant': '館林'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Watarase',
#     'odpt:stationTitle': {'en': 'Watarase',
#      'ja': '渡瀬',
#      'ko': '와타라세',
#      'ja-Hrkt': 'わたらせ',
#      'zh-Hans': '渡濑',
#      'zh-Hant': '渡瀨'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Tajima',
#     'odpt:stationTitle': {'en': 'Tajima',
#      'ja': '田島',
#      'ko': '다지마',
#      'ja-Hrkt': 'たじま',
#      'zh-Hans': '田岛',
#      'zh-Hant': '田島'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Sanoshi',
#     'odpt:stationTitle': {'en': 'Sanoshi',
#      'ja': '佐野市',
#      'ko': '사노시',
#      'ja-Hrkt': 'さのし',
#      'zh-Hans': '佐野市',
#      'zh-Hant': '佐野市'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Sano',
#     'odpt:stationTitle': {'en': 'Sano',
#      'ja': '佐野',
#      'ko': '사노',
#      'ja-Hrkt': 'さの',
#      'zh-Hans': '佐野',
#      'zh-Hant': '佐野'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Horigome',
#     'odpt:stationTitle': {'en': 'Horigome',
#      'ja': '堀米',
#      'ko': '호리고메',
#      'ja-Hrkt': 'ほりごめ',
#      'zh-Hans': '堀米',
#      'zh-Hant': '堀米'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Yoshimizu',
#     'odpt:stationTitle': {'en': 'Yoshimizu',
#      'ja': '吉水',
#      'ko': '요시미즈',
#      'ja-Hrkt': 'よしみず',
#      'zh-Hans': '吉水',
#      'zh-Hant': '吉水'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Tanuma',
#     'odpt:stationTitle': {'en': 'Tanuma',
#      'ja': '田沼',
#      'ko': '다누마',
#      'ja-Hrkt': 'たぬま',
#      'zh-Hans': '田沼',
#      'zh-Hant': '田沼'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Tada',
#     'odpt:stationTitle': {'en': 'Tada',
#      'ja': '多田',
#      'ko': '다다',
#      'ja-Hrkt': 'ただ',
#      'zh-Hans': '多田',
#      'zh-Hant': '多田'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:Tobu.Sano.Kuzu',
#     'odpt:stationTitle': {'en': 'Kuzu',
#      'ja': '葛生',
#      'ko': '구즈우',
#      'ja-Hrkt': 'くずう',
#      'zh-Hans': '葛生',
#      'zh-Hant': '葛生'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Outbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Inbound'},
#  {'@id': 'urn:ucode:_00001C00000000000001000003100E69',
#   '@type': 'odpt:Railway',
#   'dc:date': '2024-07-16T08:00:00+09:00',
#   '@context': 'http://vocab.odpt.org/context_odpt.jsonld',
#   'dc:title': '宇都宮線',
#   'odpt:color': '#F5A302',
#   'owl:sameAs': 'odpt.Railway:Tobu.Utsunomiya',
#   'odpt:lineCode': 'TN',
#   'odpt:operator': 'odpt.Operator:Tobu',
#   'odpt:railwayTitle': {'en': 'Utsunomiya Line',
#    'ja': '宇都宮線',
#    'ko': '우쓰노미야선',
#    'ja-Hrkt': 'うつのみやせん',
#    'zh-Hans': '宇都宫线',
#    'zh-Hant': '宇都宮線'},
#   'odpt:stationOrder': [{'odpt:index': 1,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.ShinTochigi',
#     'odpt:stationTitle': {'en': 'Shin-tochigi',
#      'ja': '新栃木',
#      'ko': '신토치기',
#      'ja-Hrkt': 'しんとちぎ',
#      'zh-Hans': '新枥木',
#      'zh-Hant': '新櫔木'}},
#    {'odpt:index': 2,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.YashuHirakawa',
#     'odpt:stationTitle': {'en': 'Yashu-hirakawa',
#      'ja': '野州平川',
#      'ko': '야슈히라카와',
#      'ja-Hrkt': 'やしゅうひらかわ',
#      'zh-Hans': '野州平川',
#      'zh-Hant': '野州平川'}},
#    {'odpt:index': 3,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.YashuOtsuka',
#     'odpt:stationTitle': {'en': 'Yashu-otsuka',
#      'ja': '野州大塚',
#      'ko': '야슈오쓰카',
#      'ja-Hrkt': 'やしゅうおおつか',
#      'zh-Hans': '野州大塚',
#      'zh-Hant': '野州大塚'}},
#    {'odpt:index': 4,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Mibu',
#     'odpt:stationTitle': {'en': 'Mibu',
#      'ja': '壬生',
#      'ko': '미부',
#      'ja-Hrkt': 'みぶ',
#      'zh-Hans': '壬生',
#      'zh-Hant': '壬生'}},
#    {'odpt:index': 5,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Kuniya',
#     'odpt:stationTitle': {'en': 'Kuniya',
#      'ja': '国谷',
#      'ko': '구니야',
#      'ja-Hrkt': 'くにや',
#      'zh-Hans': '国谷',
#      'zh-Hant': '國谷'}},
#    {'odpt:index': 6,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Omochanomachi',
#     'odpt:stationTitle': {'en': 'Omochanomachi',
#      'ja': 'おもちゃのまち',
#      'ko': '오모차노마치',
#      'ja-Hrkt': 'おもちゃのまち',
#      'zh-Hans': '玩具町',
#      'zh-Hant': '玩具町'}},
#    {'odpt:index': 7,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Yasuzuka',
#     'odpt:stationTitle': {'en': 'Yasuzuka',
#      'ja': '安塚',
#      'ko': '야스즈카',
#      'ja-Hrkt': 'やすづか',
#      'zh-Hans': '安塚',
#      'zh-Hant': '安塚'}},
#    {'odpt:index': 8,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Nishikawada',
#     'odpt:stationTitle': {'en': 'Nishikawada',
#      'ja': '西川田',
#      'ko': '니시카와다',
#      'ja-Hrkt': 'にしかわだ',
#      'zh-Hans': '西川田',
#      'zh-Hant': '西川田'}},
#    {'odpt:index': 9,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Esojima',
#     'odpt:stationTitle': {'en': 'Esojima',
#      'ja': '江曽島',
#      'ko': '에소지마',
#      'ja-Hrkt': 'えそじま',
#      'zh-Hans': '江曾岛',
#      'zh-Hant': '江曾島'}},
#    {'odpt:index': 10,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.MinamiUtsunomiya',
#     'odpt:stationTitle': {'en': 'Minami-utsunomiya',
#      'ja': '南宇都宮',
#      'ko': '미나미우쓰노미야',
#      'ja-Hrkt': 'みなみうつのみや',
#      'zh-Hans': '南宇都宫',
#      'zh-Hant': '南宇都宮'}},
#    {'odpt:index': 11,
#     'odpt:station': 'odpt.Station:Tobu.Utsunomiya.TobuUtsunomiya',
#     'odpt:stationTitle': {'en': 'Tobu-utsunomiya',
#      'ja': '東武宇都宮',
#      'ko': '도부우쓰노미야',
#      'ja-Hrkt': 'とうぶうつのみや',
#      'zh-Hans': '东武宇都宫',
#      'zh-Hant': '東武宇都宮'}}],
#   'odpt:ascendingRailDirection': 'odpt.RailDirection:Outbound',
#   'odpt:descendingRailDirection': 'odpt.RailDirection:Inbound'}]

# %%
railway_geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.679884, 35.669017],
#      [139.689791, 35.669104],
#      [139.703944, 35.669123],
#      [139.711346, 35.665652],
#      [139.726229, 35.666592],
#      [139.736413, 35.672104],
#      [139.743188, 35.673566],
#      [139.75177, 35.67256],
#      [139.758765, 35.673955],
#      [139.76178, 35.680505],
#      [139.763285, 35.68525],
#      [139.76545, 35.696925],
#      [139.769981, 35.706805],
#      [139.76575, 35.717325],
#      [139.763303, 35.725746],
#      [139.76689, 35.732355],
#      [139.780047, 35.742068],
#      [139.804403, 35.7492],
#      [139.82489, 35.762285],
#      [139.832095, 35.77689]]},
#    'properties': {'id': 'odpt.Railway:TokyoMetro.Chiyoda',
#     'name': '千代田線',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'operator_name': '東京メトロ',
#     'odpt:lineCode': 'C',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.YoyogiUehara',
#       'odpt:stationTitle': {'en': 'Yoyogi-uehara',
#        'ja': '代々木上原',
#        'ko': '요요기우에하라',
#        'ja-Hrkt': 'よよぎうえはら',
#        'zh-Hans': '代々木上原',
#        'zh-Hant': '代代木上原'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.YoyogiKoen',
#       'odpt:stationTitle': {'en': 'Yoyogi-koen',
#        'ja': '代々木公園',
#        'ko': '요요기코엔',
#        'ja-Hrkt': 'よよぎこうえん',
#        'zh-Hans': '代々木公园',
#        'zh-Hant': '代代木公園'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.MeijiJingumae',
#       'odpt:stationTitle': {'en': 'Meiji-jingumae<Harajuku>',
#        'ja': '明治神宮前〈原宿〉',
#        'ko': '메이지진구마에<하라주쿠>',
#        'ja-Hrkt': 'めいじじんぐうまえ<はらじゅく>',
#        'zh-Hans': '明治神宫前<原宿>',
#        'zh-Hant': '明治神宮前<原宿>'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.OmoteSando',
#       'odpt:stationTitle': {'en': 'Omote-sando',
#        'ja': '表参道',
#        'ko': '오모테산도',
#        'ja-Hrkt': 'おもてさんどう',
#        'zh-Hans': '表参道',
#        'zh-Hant': '表參道'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Nogizaka',
#       'odpt:stationTitle': {'en': 'Nogizaka',
#        'ja': '乃木坂',
#        'ko': '노기자카',
#        'ja-Hrkt': 'のぎざか',
#        'zh-Hans': '乃木坂',
#        'zh-Hant': '乃木坂'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Akasaka',
#       'odpt:stationTitle': {'en': 'Akasaka',
#        'ja': '赤坂',
#        'ko': '아카사카',
#        'ja-Hrkt': 'あかさか',
#        'zh-Hans': '赤坂',
#        'zh-Hant': '赤坂'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.KokkaiGijidomae',
#       'odpt:stationTitle': {'en': 'Kokkai-gijidomae',
#        'ja': '国会議事堂前',
#        'ko': '곳카이기지도마에',
#        'ja-Hrkt': 'こっかいぎじどうまえ',
#        'zh-Hans': '国会议事堂前',
#        'zh-Hant': '國會議事堂前'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Kasumigaseki',
#       'odpt:stationTitle': {'en': 'Kasumigaseki',
#        'ja': '霞ケ関',
#        'ko': '가스미가세키',
#        'ja-Hrkt': 'かすみがせき',
#        'zh-Hans': '霞关',
#        'zh-Hant': '霞關'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Hibiya',
#       'odpt:stationTitle': {'en': 'Hibiya',
#        'ja': '日比谷',
#        'ko': '히비야',
#        'ja-Hrkt': 'ひびや',
#        'zh-Hans': '日比谷',
#        'zh-Hant': '日比谷'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Nijubashimae',
#       'odpt:stationTitle': {'en': 'Nijubashimae<Marunouchi>',
#        'ja': '二重橋前〈丸の内〉',
#        'ko': '니주바시마에<마루노우치선>',
#        'ja-Hrkt': 'にじゅうばしまえ<まるのうち>',
#        'zh-Hans': '二重桥前<丸之内>',
#        'zh-Hant': '二重橋前<丸之內>'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Otemachi',
#       'odpt:stationTitle': {'en': 'Otemachi',
#        'ja': '大手町',
#        'ko': '오테마치',
#        'ja-Hrkt': 'おおてまち',
#        'zh-Hans': '大手町',
#        'zh-Hant': '大手町'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.ShinOchanomizu',
#       'odpt:stationTitle': {'en': 'Shin-ochanomizu',
#        'ja': '新御茶ノ水',
#        'ko': '신오차노미즈',
#        'ja-Hrkt': 'しんおちゃのみず',
#        'zh-Hans': '新御茶之水',
#        'zh-Hant': '新御茶之水'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Yushima',
#       'odpt:stationTitle': {'en': 'Yushima',
#        'ja': '湯島',
#        'ko': '유시마',
#        'ja-Hrkt': 'ゆしま',
#        'zh-Hans': '汤岛',
#        'zh-Hant': '湯島'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Nezu',
#       'odpt:stationTitle': {'en': 'Nezu',
#        'ja': '根津',
#        'ko': '네즈',
#        'ja-Hrkt': 'ねづ',
#        'zh-Hans': '根津',
#        'zh-Hant': '根津'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Sendagi',
#       'odpt:stationTitle': {'en': 'Sendagi',
#        'ja': '千駄木',
#        'ko': '센다기',
#        'ja-Hrkt': 'せんだぎ',
#        'zh-Hans': '千驮木',
#        'zh-Hant': '千馱木'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.NishiNippori',
#       'odpt:stationTitle': {'en': 'Nishi-nippori',
#        'ja': '西日暮里',
#        'ko': '니시닛포리',
#        'ja-Hrkt': 'にしにっぽり',
#        'zh-Hans': '西日暮里',
#        'zh-Hant': '西日暮里'}},
#      {'odpt:index': 17,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Machiya',
#       'odpt:stationTitle': {'en': 'Machiya',
#        'ja': '町屋',
#        'ko': '마치야',
#        'ja-Hrkt': 'まちや',
#        'zh-Hans': '町屋',
#        'zh-Hant': '町屋'}},
#      {'odpt:index': 18,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.KitaSenju',
#       'odpt:stationTitle': {'en': 'Kita-senju',
#        'ja': '北千住',
#        'ko': '기타센주',
#        'ja-Hrkt': 'きたせんじゅ',
#        'zh-Hans': '北千住',
#        'zh-Hant': '北千住'}},
#      {'odpt:index': 19,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.Ayase',
#       'odpt:stationTitle': {'en': 'Ayase',
#        'ja': '綾瀬',
#        'ko': '아야세',
#        'ja-Hrkt': 'あやせ',
#        'zh-Hans': '绫瀬',
#        'zh-Hant': '綾瀨'}},
#      {'odpt:index': 20,
#       'odpt:station': 'odpt.Station:TokyoMetro.Chiyoda.KitaAyase',
#       'odpt:stationTitle': {'en': 'Kita-ayase',
#        'ja': '北綾瀬',
#        'ko': '기타아야세',
#        'ja-Hrkt': 'きたあやせ',
#        'zh-Hans': '北绫瀬',
#        'zh-Hant': '北綾瀨'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.612865, 35.78835],
#      [139.63117, 35.77674],
#      [139.644001, 35.76998],
#      [139.6543, 35.757555],
#      [139.66547, 35.74962],
#      [139.67952, 35.743395],
#      [139.6894, 35.738175],
#      [139.69848, 35.733215],
#      [139.71115, 35.730345],
#      [139.714715, 35.7202],
#      [139.70912, 35.707806],
#      [139.707846, 35.699829],
#      [139.704727, 35.690609],
#      [139.705469, 35.678503],
#      [139.70524, 35.668205],
#      [139.70257, 35.659092]]},
#    'properties': {'id': 'odpt.Railway:TokyoMetro.Fukutoshin',
#     'name': '副都心線',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'operator_name': '東京メトロ',
#     'odpt:lineCode': 'F',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Wakoshi',
#       'odpt:stationTitle': {'en': 'Wakoshi',
#        'ja': '和光市',
#        'ko': '와코시',
#        'ja-Hrkt': 'わこうし',
#        'zh-Hans': '和光市',
#        'zh-Hant': '和光市'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.ChikatetsuNarimasu',
#       'odpt:stationTitle': {'en': 'Chikatetsu-narimasu',
#        'ja': '地下鉄成増',
#        'ko': '지카테쓰나리마스',
#        'ja-Hrkt': 'ちかてつなります',
#        'zh-Hans': '地铁成増',
#        'zh-Hant': '地鐵成增'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.ChikatetsuAkatsuka',
#       'odpt:stationTitle': {'en': 'Chikatetsu-akatsuka',
#        'ja': '地下鉄赤塚',
#        'ko': '지카테쓰아카쓰카',
#        'ja-Hrkt': 'ちかてつあかつか',
#        'zh-Hans': '地铁赤冢',
#        'zh-Hant': '地鐵赤塚'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Heiwadai',
#       'odpt:stationTitle': {'en': 'Heiwadai',
#        'ja': '平和台',
#        'ko': '헤이와다이',
#        'ja-Hrkt': 'へいわだい',
#        'zh-Hans': '平和台',
#        'zh-Hant': '平和台'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Hikawadai',
#       'odpt:stationTitle': {'en': 'Hikawadai',
#        'ja': '氷川台',
#        'ko': '히카와다이',
#        'ja-Hrkt': 'ひかわだい',
#        'zh-Hans': '冰川台',
#        'zh-Hant': '冰川台'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.KotakeMukaihara',
#       'odpt:stationTitle': {'en': 'Kotake-mukaihara',
#        'ja': '小竹向原',
#        'ko': '고타케무카이하라',
#        'ja-Hrkt': 'こたけむかいはら',
#        'zh-Hans': '小竹向原',
#        'zh-Hant': '小竹向原'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Senkawa',
#       'odpt:stationTitle': {'en': 'Senkawa',
#        'ja': '千川',
#        'ko': '센카와',
#        'ja-Hrkt': 'せんかわ',
#        'zh-Hans': '千川',
#        'zh-Hant': '千川'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Kanamecho',
#       'odpt:stationTitle': {'en': 'Kanamecho',
#        'ja': '要町',
#        'ko': '가나메초',
#        'ja-Hrkt': 'かなめちょう',
#        'zh-Hans': '要町',
#        'zh-Hant': '要町'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Ikebukuro',
#       'odpt:stationTitle': {'en': 'Ikebukuro',
#        'ja': '池袋',
#        'ko': '이케부쿠로',
#        'ja-Hrkt': 'いけぶくろ',
#        'zh-Hans': '池袋',
#        'zh-Hant': '池袋'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Zoshigaya',
#       'odpt:stationTitle': {'en': 'Zoshigaya',
#        'ja': '雑司が谷',
#        'ko': '조시가야',
#        'ja-Hrkt': 'ぞうしがや',
#        'zh-Hans': '杂司谷',
#        'zh-Hant': '雜司谷'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.NishiWaseda',
#       'odpt:stationTitle': {'en': 'Nishi-waseda',
#        'ja': '西早稲田',
#        'ko': '니시와세다',
#        'ja-Hrkt': 'にしわせだ',
#        'zh-Hans': '西早稻田',
#        'zh-Hant': '西早稻田'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.HigashiShinjuku',
#       'odpt:stationTitle': {'en': 'Higashi-shinjuku',
#        'ja': '東新宿',
#        'ko': '히가시신주쿠',
#        'ja-Hrkt': 'ひがししんじゅく',
#        'zh-Hans': '东新宿',
#        'zh-Hant': '東新宿'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.ShinjukuSanchome',
#       'odpt:stationTitle': {'en': 'Shinjuku-sanchome',
#        'ja': '新宿三丁目',
#        'ko': '신주쿠산초메',
#        'ja-Hrkt': 'しんじゅくさんちょうめ',
#        'zh-Hans': '新宿三丁目',
#        'zh-Hant': '新宿三丁目'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.KitaSando',
#       'odpt:stationTitle': {'en': 'Kita-sando',
#        'ja': '北参道',
#        'ko': '기타산도',
#        'ja-Hrkt': 'きたさんどう',
#        'zh-Hans': '北参道',
#        'zh-Hant': '北參道'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.MeijiJingumae',
#       'odpt:stationTitle': {'en': 'Meiji-jingumae<Harajuku>',
#        'ja': '明治神宮前〈原宿〉',
#        'ko': '메이지진구마에<하라주쿠>',
#        'ja-Hrkt': 'めいじじんぐうまえ<はらじゅく>',
#        'zh-Hans': '明治神宫前<原宿>',
#        'zh-Hant': '明治神宮前<原宿>'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:TokyoMetro.Fukutoshin.Shibuya',
#       'odpt:stationTitle': {'en': 'Shibuya',
#        'ja': '渋谷',
#        'ko': '시부야',
#        'ja-Hrkt': 'しぶや',
#        'zh-Hans': '涩谷',
#        'zh-Hant': '澀谷'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.75964, 35.66554],
#      [139.75983, 35.66281],
#      [139.76192, 35.654],
#      [139.75908, 35.64923],
#      [139.75781, 35.64178],
#      [139.77878, 35.6299],
#      [139.77142, 35.62591],
#      [139.77309, 35.62135],
#      [139.77939, 35.61756],
#      [139.78131, 35.62479],
#      [139.79134, 35.63025],
#      [139.79325, 35.63468],
#      [139.78887, 35.63998],
#      [139.78565, 35.64569],
#      [139.79001, 35.64871],
#      [139.79546, 35.65374]]},
#    'properties': {'id': 'odpt.Railway:Yurikamome.Yurikamome',
#     'name': 'ゆりかもめ',
#     'odpt:operator': 'odpt.Operator:Yurikamome',
#     'operator_name': 'ゆりかもめ',
#     'odpt:lineCode': 'U',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Shimbashi',
#       'odpt:stationTitle': {'en': 'Shimbashi',
#        'ja': '新橋',
#        'ko': '신바시',
#        'zh-Hans': '新桥'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Shiodome',
#       'odpt:stationTitle': {'en': 'Shiodome',
#        'ja': '汐留',
#        'ko': '시오도메',
#        'zh-Hans': '汐留'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Takeshiba',
#       'odpt:stationTitle': {'en': 'Takeshiba',
#        'ja': '竹芝',
#        'ko': '다케시바',
#        'zh-Hans': '竹芝'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Hinode',
#       'odpt:stationTitle': {'en': 'Hinode',
#        'ja': '日の出',
#        'ko': '히노데',
#        'zh-Hans': '日之出'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.ShibauraFuto',
#       'odpt:stationTitle': {'en': 'Shibaura-futō',
#        'ja': '芝浦ふ頭',
#        'ko': '시바우라후토',
#        'zh-Hans': '芝浦埠头'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.OdaibaKaihinkoen',
#       'odpt:stationTitle': {'en': 'Odaiba-kaihinkōen',
#        'ja': 'お台場海浜公園',
#        'ko': '오다이바카이힌코엔',
#        'zh-Hans': '御台场海滨公园'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Daiba',
#       'odpt:stationTitle': {'en': 'Daiba',
#        'ja': '台場',
#        'ko': '다이바',
#        'zh-Hans': '台场'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.TokyoInternationalCruiseTerminal',
#       'odpt:stationTitle': {'en': 'Tokyo International Cruise Terminal',
#        'ja': '東京国際クルーズターミナル',
#        'ko': '도쿄국제크루즈터미널',
#        'zh-Hans': '东京国际邮轮码头'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.TelecomCenter',
#       'odpt:stationTitle': {'en': 'Telecom Center',
#        'ja': 'テレコムセンター',
#        'ko': '텔레콤센터',
#        'zh-Hans': '远程通信中心'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Aomi',
#       'odpt:stationTitle': {'en': 'Aomi',
#        'ja': '青海',
#        'ko': '아오미',
#        'zh-Hans': '青海'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.TokyoBigSight',
#       'odpt:stationTitle': {'en': 'Tokyo Big Sight',
#        'ja': '東京ビッグサイト',
#        'ko': '도쿄빅사이트',
#        'zh-Hans': '东京国际展览中心'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Ariake',
#       'odpt:stationTitle': {'en': 'Ariake',
#        'ja': '有明',
#        'ko': '아리아케',
#        'zh-Hans': '有明'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.AriakeTennisNoMori',
#       'odpt:stationTitle': {'en': 'Ariake-tennis-no-mori',
#        'ja': '有明テニスの森',
#        'ko': '아리아케테니스노모리',
#        'zh-Hans': '有明网球之森'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.ShijoMae',
#       'odpt:stationTitle': {'en': 'Shijō-mae',
#        'ja': '市場前',
#        'ko': '시조마에',
#        'zh-Hans': '市场前'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.ShinToyosu',
#       'odpt:stationTitle': {'en': 'Shin-Toyosu',
#        'ja': '新豊洲',
#        'ko': '신토요스',
#        'zh-Hans': '新丰洲'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:Yurikamome.Yurikamome.Toyosu',
#       'odpt:stationTitle': {'en': 'Toyosu',
#        'ja': '豊洲',
#        'ko': '도요스',
#        'zh-Hans': '丰洲'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.77428, 35.69894],
#      [139.78194, 35.70711],
#      [139.79239, 35.714],
#      [139.79911, 35.73344],
#      [139.80533, 35.74975],
#      [139.82033, 35.7725],
#      [139.82181, 35.78492],
#      [139.84483, 35.80786],
#      [139.87806, 35.82417],
#      [139.90433, 35.83786],
#      [139.91522, 35.85447],
#      [139.92506, 35.87186],
#      [139.9525, 35.89336],
#      [139.9575, 35.911],
#      [139.99225, 35.95069],
#      [140.03831, 35.99475],
#      [140.05625, 36.02994],
#      [140.05944, 36.05847],
#      [140.08239, 36.08217],
#      [140.11169, 36.08256]]},
#    'properties': {'id': 'odpt.Railway:MIR.TsukubaExpress',
#     'name': 'つくばエクスプレス',
#     'odpt:operator': 'odpt.Operator:MIR',
#     'operator_name': '首都圏新都市鉄道',
#     'odpt:lineCode': 'TX',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Akihabara',
#       'odpt:stationTitle': {'en': 'Akihabara',
#        'ja': '秋葉原',
#        'ko': '아키하바라',
#        'zh-Hans': '秋叶原',
#        'zh-Hant': '秋葉原'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.ShinOkachimachi',
#       'odpt:stationTitle': {'en': 'Shin-Okachimachi',
#        'ja': '新御徒町',
#        'ko': '신 오카치마치',
#        'zh-Hans': '新御徒町',
#        'zh-Hant': '新御徒町'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Asakusa',
#       'odpt:stationTitle': {'en': 'Asakusa',
#        'ja': '浅草',
#        'ko': '아사쿠사',
#        'zh-Hans': '浅草',
#        'zh-Hant': '淺草'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.MinamiSenju',
#       'odpt:stationTitle': {'en': 'Minami-Senju',
#        'ja': '南千住',
#        'ko': '미나미 센주',
#        'zh-Hans': '南千住',
#        'zh-Hant': '南千住'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.KitaSenju',
#       'odpt:stationTitle': {'en': 'Kita-Senju',
#        'ja': '北千住',
#        'ko': '기타 센주',
#        'zh-Hans': '北千住',
#        'zh-Hant': '北千住'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Aoi',
#       'odpt:stationTitle': {'en': 'Aoi',
#        'ja': '青井',
#        'ko': '아오이',
#        'zh-Hans': '青井',
#        'zh-Hant': '青井'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Rokucho',
#       'odpt:stationTitle': {'en': 'Rokuchō',
#        'ja': '六町',
#        'ko': '로쿠초',
#        'zh-Hans': '六町',
#        'zh-Hant': '六町'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Yashio',
#       'odpt:stationTitle': {'en': 'Yashio',
#        'ja': '八潮',
#        'ko': '야시오',
#        'zh-Hans': '八潮',
#        'zh-Hant': '八潮'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.MisatoChuo',
#       'odpt:stationTitle': {'en': 'Misato-chūō',
#        'ja': '三郷中央',
#        'ko': '미사토 주오',
#        'zh-Hans': '三乡中央',
#        'zh-Hant': '三鄉中央'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.MinamiNagareyama',
#       'odpt:stationTitle': {'en': 'Minami-Nagareyama',
#        'ja': '南流山',
#        'ko': '미나미 나가레야마',
#        'zh-Hans': '南流山',
#        'zh-Hant': '南流山'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.NagareyamaCentralPark',
#       'odpt:stationTitle': {'en': 'Nagareyama-centralpark',
#        'ja': '流山セントラルパーク',
#        'ko': '나가레야마 센트럴파크',
#        'zh-Hans': '流山中央公园',
#        'zh-Hant': '流山中央公園'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.NagareyamaOtakanomori',
#       'odpt:stationTitle': {'en': 'Nagareyama-ōtakanomori',
#        'ja': '流山おおたかの森',
#        'ko': '나가레야마 오타카노모리',
#        'zh-Hans': '流山大鷹之森',
#        'zh-Hant': '流山大鷹之森'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.KashiwanohaCampus',
#       'odpt:stationTitle': {'en': 'Kashiwanoha-campus',
#        'ja': '柏の葉キャンパス',
#        'ko': '가시와노하 캠퍼스',
#        'zh-Hans': '柏之叶校园',
#        'zh-Hant': '柏之葉園地'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.KashiwaTanaka',
#       'odpt:stationTitle': {'en': 'Kashiwa-Tanaka',
#        'ja': '柏たなか',
#        'ko': '가시와 다나카',
#        'zh-Hans': '柏田中',
#        'zh-Hant': '柏田中'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Moriya',
#       'odpt:stationTitle': {'en': 'Moriya',
#        'ja': '守谷',
#        'ko': '모리야',
#        'zh-Hans': '守谷',
#        'zh-Hant': '守谷'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Miraidaira',
#       'odpt:stationTitle': {'en': 'Miraidaira',
#        'ja': 'みらい平',
#        'ko': '미라이다이라',
#        'zh-Hans': '未来平',
#        'zh-Hant': '未來平'}},
#      {'odpt:index': 17,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Midorino',
#       'odpt:stationTitle': {'en': 'Midorino',
#        'ja': 'みどりの',
#        'ko': '미도리노',
#        'zh-Hans': '绿野',
#        'zh-Hant': '綠野'}},
#      {'odpt:index': 18,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.BampakuKinenKoen',
#       'odpt:stationTitle': {'en': 'Bampaku-kinenkōen',
#        'ja': '万博記念公園',
#        'ko': '반파쿠 기넨코엔',
#        'zh-Hans': '万博纪念公园',
#        'zh-Hant': '萬博紀念公園'}},
#      {'odpt:index': 19,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.KenkyuGakuen',
#       'odpt:stationTitle': {'en': 'Kenkyū-gakuen',
#        'ja': '研究学園',
#        'ko': '겐큐 가쿠엔',
#        'zh-Hans': '研究学园',
#        'zh-Hant': '研究學園'}},
#      {'odpt:index': 20,
#       'odpt:station': 'odpt.Station:MIR.TsukubaExpress.Tsukuba',
#       'odpt:stationTitle': {'en': 'Tsukuba',
#        'ja': 'つくば',
#        'ko': '츠쿠바',
#        'zh-Hans': '筑波',
#        'zh-Hant': '筑波'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.715444, 35.633635],
#      [139.726007, 35.637851],
#      [139.734344, 35.643283],
#      [139.748998, 35.64865],
#      [139.74985, 35.654186],
#      [139.751366, 35.660774],
#      [139.75533, 35.669344],
#      [139.760274, 35.676585],
#      [139.762798, 35.684093],
#      [139.758213, 35.695331],
#      [139.755147, 35.70346],
#      [139.753287, 35.709532],
#      [139.752134, 35.721682],
#      [139.744984, 35.727772],
#      [139.738154, 35.733793],
#      [139.728703, 35.743568],
#      [139.719808, 35.748772],
#      [139.71012, 35.751372],
#      [139.705544, 35.761309],
#      [139.70241, 35.768566],
#      [139.695097, 35.776082],
#      [139.685751, 35.777468],
#      [139.678947, 35.784262],
#      [139.672867, 35.787074],
#      [139.661361, 35.788908],
#      [139.65405, 35.790289],
#      [139.645421, 35.791965]]},
#    'properties': {'id': 'odpt.Railway:Toei.Mita',
#     'name': '三田線',
#     'odpt:operator': 'odpt.Operator:Toei',
#     'operator_name': '東京都交通局',
#     'odpt:lineCode': 'I',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:Toei.Mita.Meguro',
#       'odpt:stationTitle': {'en': 'Meguro', 'ja': '目黒'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:Toei.Mita.Shirokanedai',
#       'odpt:stationTitle': {'en': 'Shirokanedai', 'ja': '白金台'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:Toei.Mita.ShirokaneTakanawa',
#       'odpt:stationTitle': {'en': 'Shirokane-takanawa', 'ja': '白金高輪'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:Toei.Mita.Mita',
#       'odpt:stationTitle': {'en': 'Mita', 'ja': '三田'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:Toei.Mita.Shibakoen',
#       'odpt:stationTitle': {'en': 'Shibakoen', 'ja': '芝公園'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:Toei.Mita.Onarimon',
#       'odpt:stationTitle': {'en': 'Onarimon', 'ja': '御成門'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:Toei.Mita.Uchisaiwaicho',
#       'odpt:stationTitle': {'en': 'Uchisaiwaicho', 'ja': '内幸町'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:Toei.Mita.Hibiya',
#       'odpt:stationTitle': {'en': 'Hibiya', 'ja': '日比谷'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:Toei.Mita.Otemachi',
#       'odpt:stationTitle': {'en': 'Otemachi', 'ja': '大手町'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:Toei.Mita.Jimbocho',
#       'odpt:stationTitle': {'en': 'Jimbocho', 'ja': '神保町'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:Toei.Mita.Suidobashi',
#       'odpt:stationTitle': {'en': 'Suidobashi', 'ja': '水道橋'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:Toei.Mita.Kasuga',
#       'odpt:stationTitle': {'en': 'Kasuga', 'ja': '春日'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:Toei.Mita.Hakusan',
#       'odpt:stationTitle': {'en': 'Hakusan', 'ja': '白山'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:Toei.Mita.Sengoku',
#       'odpt:stationTitle': {'en': 'Sengoku', 'ja': '千石'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:Toei.Mita.Sugamo',
#       'odpt:stationTitle': {'en': 'Sugamo', 'ja': '巣鴨'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:Toei.Mita.NishiSugamo',
#       'odpt:stationTitle': {'en': 'Nishi-sugamo', 'ja': '西巣鴨'}},
#      {'odpt:index': 17,
#       'odpt:station': 'odpt.Station:Toei.Mita.ShinItabashi',
#       'odpt:stationTitle': {'en': 'Shin-itabashi', 'ja': '新板橋'}},
#      {'odpt:index': 18,
#       'odpt:station': 'odpt.Station:Toei.Mita.ItabashiKuyakushomae',
#       'odpt:stationTitle': {'en': 'Itabashi-kuyakushomae', 'ja': '板橋区役所前'}},
#      {'odpt:index': 19,
#       'odpt:station': 'odpt.Station:Toei.Mita.Itabashihoncho',
#       'odpt:stationTitle': {'en': 'Itabashihoncho', 'ja': '板橋本町'}},
#      {'odpt:index': 20,
#       'odpt:station': 'odpt.Station:Toei.Mita.Motohasunuma',
#       'odpt:stationTitle': {'en': 'Motohasunuma', 'ja': '本蓮沼'}},
#      {'odpt:index': 21,
#       'odpt:station': 'odpt.Station:Toei.Mita.ShimuraSakaue',
#       'odpt:stationTitle': {'en': 'Shimura-sakaue', 'ja': '志村坂上'}},
#      {'odpt:index': 22,
#       'odpt:station': 'odpt.Station:Toei.Mita.ShimuraSanchome',
#       'odpt:stationTitle': {'en': 'Shimura-sanchome', 'ja': '志村三丁目'}},
#      {'odpt:index': 23,
#       'odpt:station': 'odpt.Station:Toei.Mita.Hasune',
#       'odpt:stationTitle': {'en': 'Hasune', 'ja': '蓮根'}},
#      {'odpt:index': 24,
#       'odpt:station': 'odpt.Station:Toei.Mita.Nishidai',
#       'odpt:stationTitle': {'en': 'Nishidai', 'ja': '西台'}},
#      {'odpt:index': 25,
#       'odpt:station': 'odpt.Station:Toei.Mita.Takashimadaira',
#       'odpt:stationTitle': {'en': 'Takashimadaira', 'ja': '高島平'}},
#      {'odpt:index': 26,
#       'odpt:station': 'odpt.Station:Toei.Mita.ShinTakashimadaira',
#       'odpt:stationTitle': {'en': 'Shin-takashimadaira', 'ja': '新高島平'}},
#      {'odpt:index': 27,
#       'odpt:station': 'odpt.Station:Toei.Mita.NishiTakashimadaira',
#       'odpt:stationTitle': {'en': 'Nishi-takashimadaira', 'ja': '西高島平'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.692677, 35.690607],
#      [139.699121, 35.693367],
#      [139.707434, 35.697957],
#      [139.718043, 35.699188],
#      [139.72504, 35.699501],
#      [139.735894, 35.700911],
#      [139.745257, 35.702952],
#      [139.752487, 35.708493],
#      [139.760524, 35.70751],
#      [139.773351, 35.707949],
#      [139.782166, 35.707009],
#      [139.792244, 35.705587],
#      [139.797469, 35.696807],
#      [139.798251, 35.687926],
#      [139.798758, 35.682355],
#      [139.795124, 35.672772],
#      [139.783912, 35.663757],
#      [139.777138, 35.658934],
#      [139.766929, 35.664919],
#      [139.760225, 35.663193],
#      [139.755696, 35.656671],
#      [139.743989, 35.654985],
#      [139.73633, 35.656448],
#      [139.731354, 35.664106],
#      [139.723925, 35.673067],
#      [139.714667, 35.679896],
#      [139.701603, 35.683505],
#      [139.699019, 35.688462],
#      [139.692677, 35.690607],
#      [139.684545, 35.689892],
#      [139.682899, 35.697887],
#      [139.683112, 35.70716],
#      [139.686296, 35.713935],
#      [139.683389, 35.723435],
#      [139.670498, 35.732579],
#      [139.654762, 35.737411],
#      [139.649116, 35.741711],
#      [139.6403, 35.75141],
#      [139.628901, 35.758527]]},
#    'properties': {'id': 'odpt.Railway:Toei.Oedo',
#     'name': '大江戸線',
#     'odpt:operator': 'odpt.Operator:Toei',
#     'operator_name': '東京都交通局',
#     'odpt:lineCode': 'E',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Tochomae',
#       'odpt:stationTitle': {'en': 'Tochomae', 'ja': '都庁前'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:Toei.Oedo.ShinjukuNishiguchi',
#       'odpt:stationTitle': {'en': 'Shinjuku-nishiguchi', 'ja': '新宿西口'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:Toei.Oedo.HigashiShinjuku',
#       'odpt:stationTitle': {'en': 'Higashi-shinjuku', 'ja': '東新宿'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:Toei.Oedo.WakamatsuKawada',
#       'odpt:stationTitle': {'en': 'Wakamatsu-kawada', 'ja': '若松河田'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:Toei.Oedo.UshigomeYanagicho',
#       'odpt:stationTitle': {'en': 'Ushigome-yanagicho', 'ja': '牛込柳町'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:Toei.Oedo.UshigomeKagurazaka',
#       'odpt:stationTitle': {'en': 'Ushigome-kagurazaka', 'ja': '牛込神楽坂'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Iidabashi',
#       'odpt:stationTitle': {'en': 'Iidabashi', 'ja': '飯田橋'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Kasuga',
#       'odpt:stationTitle': {'en': 'Kasuga', 'ja': '春日'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:Toei.Oedo.HongoSanchome',
#       'odpt:stationTitle': {'en': 'Hongo-sanchome', 'ja': '本郷三丁目'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:Toei.Oedo.UenoOkachimachi',
#       'odpt:stationTitle': {'en': 'Ueno-okachimachi', 'ja': '上野御徒町'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:Toei.Oedo.ShinOkachimachi',
#       'odpt:stationTitle': {'en': 'Shin-okachimachi', 'ja': '新御徒町'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Kuramae',
#       'odpt:stationTitle': {'en': 'Kuramae', 'ja': '蔵前'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Ryogoku',
#       'odpt:stationTitle': {'en': 'Ryogoku', 'ja': '両国'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Morishita',
#       'odpt:stationTitle': {'en': 'Morishita', 'ja': '森下'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:Toei.Oedo.KiyosumiShirakawa',
#       'odpt:stationTitle': {'en': 'Kiyosumi-shirakawa', 'ja': '清澄白河'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:Toei.Oedo.MonzenNakacho',
#       'odpt:stationTitle': {'en': 'Monzen-nakacho', 'ja': '門前仲町'}},
#      {'odpt:index': 17,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Tsukishima',
#       'odpt:stationTitle': {'en': 'Tsukishima', 'ja': '月島'}},
#      {'odpt:index': 18,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Kachidoki',
#       'odpt:stationTitle': {'en': 'Kachidoki', 'ja': '勝どき'}},
#      {'odpt:index': 19,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Tsukijishijo',
#       'odpt:stationTitle': {'en': 'Tsukijishijo', 'ja': '築地市場'}},
#      {'odpt:index': 20,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Shiodome',
#       'odpt:stationTitle': {'en': 'Shiodome', 'ja': '汐留'}},
#      {'odpt:index': 21,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Daimon',
#       'odpt:stationTitle': {'en': 'Daimon', 'ja': '大門'}},
#      {'odpt:index': 22,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Akabanebashi',
#       'odpt:stationTitle': {'en': 'Akabanebashi', 'ja': '赤羽橋'}},
#      {'odpt:index': 23,
#       'odpt:station': 'odpt.Station:Toei.Oedo.AzabuJuban',
#       'odpt:stationTitle': {'en': 'Azabu-juban', 'ja': '麻布十番'}},
#      {'odpt:index': 24,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Roppongi',
#       'odpt:stationTitle': {'en': 'Roppongi', 'ja': '六本木'}},
#      {'odpt:index': 25,
#       'odpt:station': 'odpt.Station:Toei.Oedo.AoyamaItchome',
#       'odpt:stationTitle': {'en': 'Aoyama-itchome', 'ja': '青山一丁目'}},
#      {'odpt:index': 26,
#       'odpt:station': 'odpt.Station:Toei.Oedo.KokuritsuKyogijo',
#       'odpt:stationTitle': {'en': 'Kokuritsu-kyogijo', 'ja': '国立競技場'}},
#      {'odpt:index': 27,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Yoyogi',
#       'odpt:stationTitle': {'en': 'Yoyogi', 'ja': '代々木'}},
#      {'odpt:index': 28,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Shinjuku',
#       'odpt:stationTitle': {'en': 'Shinjuku', 'ja': '新宿'}},
#      {'odpt:index': 29,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Tochomae',
#       'odpt:stationTitle': {'en': 'Tochomae', 'ja': '都庁前'}},
#      {'odpt:index': 30,
#       'odpt:station': 'odpt.Station:Toei.Oedo.NishiShinjukuGochome',
#       'odpt:stationTitle': {'en': 'Nishi-shinjuku-gochome', 'ja': '西新宿五丁目'}},
#      {'odpt:index': 31,
#       'odpt:station': 'odpt.Station:Toei.Oedo.NakanoSakaue',
#       'odpt:stationTitle': {'en': 'Nakano-sakaue', 'ja': '中野坂上'}},
#      {'odpt:index': 32,
#       'odpt:station': 'odpt.Station:Toei.Oedo.HigashiNakano',
#       'odpt:stationTitle': {'en': 'Higashi-nakano', 'ja': '東中野'}},
#      {'odpt:index': 33,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Nakai',
#       'odpt:stationTitle': {'en': 'Nakai', 'ja': '中井'}},
#      {'odpt:index': 34,
#       'odpt:station': 'odpt.Station:Toei.Oedo.OchiaiMinamiNagasaki',
#       'odpt:stationTitle': {'en': 'Ochiai-minami-nagasaki', 'ja': '落合南長崎'}},
#      {'odpt:index': 35,
#       'odpt:station': 'odpt.Station:Toei.Oedo.ShinEgota',
#       'odpt:stationTitle': {'en': 'Shin-egota', 'ja': '新江古田'}},
#      {'odpt:index': 36,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Nerima',
#       'odpt:stationTitle': {'en': 'Nerima', 'ja': '練馬'}},
#      {'odpt:index': 37,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Toshimaen',
#       'odpt:stationTitle': {'en': 'Toshimaen', 'ja': '豊島園'}},
#      {'odpt:index': 38,
#       'odpt:station': 'odpt.Station:Toei.Oedo.NerimaKasugacho',
#       'odpt:stationTitle': {'en': 'Nerima-kasugacho', 'ja': '練馬春日町'}},
#      {'odpt:index': 39,
#       'odpt:station': 'odpt.Station:Toei.Oedo.Hikarigaoka',
#       'odpt:stationTitle': {'en': 'Hikarigaoka', 'ja': '光が丘'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString', 'coordinates': []},
#    'properties': {'id': 'odpt.Railway:JR-East.Nambu',
#     'name': '南武線',
#     'odpt:operator': 'odpt.Operator:JR-East',
#     'operator_name': 'JR東日本',
#     'odpt:stationOrder': []}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString', 'coordinates': []},
#    'properties': {'id': 'odpt.Railway:JR-East.Ome',
#     'name': '青梅線',
#     'odpt:operator': 'odpt.Operator:JR-East',
#     'operator_name': 'JR東日本',
#     'odpt:stationOrder': []}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.4228, 35.6239],
#      [139.422, 35.6318],
#      [139.4164, 35.6369],
#      [139.4087, 35.6419],
#      [139.4038, 35.6485],
#      [139.4108, 35.6552],
#      [139.4152, 35.6613],
#      [139.4199, 35.6713],
#      [139.4092, 35.6782],
#      [139.4093, 35.6898],
#      [139.4126, 35.6962],
#      [139.4127, 35.6995],
#      [139.4133, 35.71],
#      [139.4171, 35.7143],
#      [139.4196, 35.7188],
#      [139.4181, 35.7234],
#      [139.4177, 35.7322],
#      [139.4166, 35.739],
#      [139.4159, 35.7458]]},
#    'properties': {'id': 'odpt.Railway:TamaMonorail.TamaMonorail',
#     'name': '多摩モノレール',
#     'odpt:operator': 'odpt.Operator:TamaMonorail',
#     'operator_name': '多摩都市モノレール',
#     'odpt:lineCode': 'TT',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TamaCenter',
#       'odpt:stationTitle': {'en': 'Tama Center', 'ja': '多摩センター'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Matsugaya',
#       'odpt:stationTitle': {'en': 'Matsugaya', 'ja': '松が谷'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.OtsukaTeikyoDaigaku',
#       'odpt:stationTitle': {'en': 'Otsuka-Teikyo-Daigaku', 'ja': '大塚・帝京大学'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.ChuoDaigakuMeiseiDaigaku',
#       'odpt:stationTitle': {'en': 'Chuo-Daigaku-Meisei-Daigaku',
#        'ja': '中央大学・明星大学'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TamaDobutsukoen',
#       'odpt:stationTitle': {'en': 'Tama-Dobutsukoen', 'ja': '多摩動物公園'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Hodokubo',
#       'odpt:stationTitle': {'en': 'Hodokubo', 'ja': '程久保'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Takahatafudo',
#       'odpt:stationTitle': {'en': 'Takahatafudo', 'ja': '高幡不動'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Manganji',
#       'odpt:stationTitle': {'en': 'Manganji', 'ja': '万願寺'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Koshukaido',
#       'odpt:stationTitle': {'en': 'Koshukaido', 'ja': '甲州街道'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.ShibasakiTaiikukan',
#       'odpt:stationTitle': {'en': 'Shibasaki-Taiikukan', 'ja': '柴崎体育館'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TachikawaMinami',
#       'odpt:stationTitle': {'en': 'Tachikawa-Minami', 'ja': '立川南'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TachikawaKita',
#       'odpt:stationTitle': {'en': 'Tachikawa-Kita', 'ja': '立川北'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Takamatsu',
#       'odpt:stationTitle': {'en': 'Takamatsu', 'ja': '高松'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Tachihi',
#       'odpt:stationTitle': {'en': 'Tachihi', 'ja': '立飛'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.IzumiTaiikukan',
#       'odpt:stationTitle': {'en': 'Izumi-Taiikukan', 'ja': '泉体育館'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.SunagawaNanaban',
#       'odpt:stationTitle': {'en': 'Sunagawa-Nanaban', 'ja': '砂川七番'}},
#      {'odpt:index': 17,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.TamagawaJosui',
#       'odpt:stationTitle': {'en': 'Tamagawa-Josui', 'ja': '玉川上水'}},
#      {'odpt:index': 18,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Sakurakaido',
#       'odpt:stationTitle': {'en': 'Sakurakaido', 'ja': '桜街道'}},
#      {'odpt:index': 19,
#       'odpt:station': 'odpt.Station:TamaMonorail.TamaMonorail.Kamikitadai',
#       'odpt:stationTitle': {'en': 'Kamikitadai', 'ja': '上北台'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.540439, 35.515143],
#      [139.549265, 35.528382],
#      [139.561611, 35.536637],
#      [139.574713, 35.545633],
#      [139.579045, 35.553383],
#      [139.592827, 35.56095],
#      [139.604928, 35.554184],
#      [139.620231, 35.549594],
#      [139.633413, 35.549961],
#      [139.647449, 35.553207]]},
#    'properties': {'id': 'odpt.Railway:YokohamaMunicipal.Green',
#     'name': 'グリーンライン',
#     'odpt:operator': 'odpt.Operator:YokohamaMunicipal',
#     'operator_name': '横浜市交通局',
#     'odpt:lineCode': 'G',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.Nakayama',
#       'odpt:stationTitle': {'en': 'Nakayama', 'ja': '中山'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.Kawawacho',
#       'odpt:stationTitle': {'en': 'Kawawacho', 'ja': '川和町'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.TsuzukiFureainooka',
#       'odpt:stationTitle': {'en': 'Tsuzuki-fureainooka', 'ja': '都筑ふれあいの丘'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.CenterMinami',
#       'odpt:stationTitle': {'en': 'Center Minami', 'ja': 'センター南'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.CenterKita',
#       'odpt:stationTitle': {'en': 'Center Kita', 'ja': 'センター北'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.KitaYamata',
#       'odpt:stationTitle': {'en': 'Kita-Yamata', 'ja': '北山田'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.HigashiYamata',
#       'odpt:stationTitle': {'en': 'Higashi-Yamata', 'ja': '東山田'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.Takata',
#       'odpt:stationTitle': {'en': 'Takata', 'ja': '高田'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.HiyoshiHoncho',
#       'odpt:stationTitle': {'en': 'Hiyoshi-Honcho', 'ja': '日吉本町'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:YokohamaMunicipal.Green.Hiyoshi',
#       'odpt:stationTitle': {'en': 'Hiyoshi', 'ja': '日吉'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString', 'coordinates': []},
#    'properties': {'id': 'odpt.Railway:OdakyuHakone.HakoneTozan',
#     'name': '箱根登山線',
#     'odpt:operator': 'odpt.Operator:OdakyuHakone',
#     'operator_name': '小田急箱根',
#     'odpt:stationOrder': []}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.702673, 35.659097],
#      [139.712473, 35.665042],
#      [139.717825, 35.670375],
#      [139.724145, 35.67279],
#      [139.737347, 35.676845],
#      [139.741943, 35.671511],
#      [139.75012, 35.67016],
#      [139.758512, 35.667382],
#      [139.765366, 35.6715],
#      [139.77011, 35.676704],
#      [139.773335, 35.681879],
#      [139.773582, 35.687173],
#      [139.77089, 35.693715],
#      [139.771762, 35.70278],
#      [139.773011, 35.707765],
#      [139.775625, 35.711835],
#      [139.78221, 35.711389],
#      [139.790306, 35.709917],
#      [139.797774, 35.710746]]},
#    'properties': {'id': 'odpt.Railway:TokyoMetro.Ginza',
#     'name': '銀座線',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'operator_name': '東京メトロ',
#     'odpt:lineCode': 'G',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Shibuya',
#       'odpt:stationTitle': {'en': 'Shibuya',
#        'ja': '渋谷',
#        'ko': '시부야',
#        'ja-Hrkt': 'しぶや',
#        'zh-Hans': '涩谷',
#        'zh-Hant': '澀谷'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.OmoteSando',
#       'odpt:stationTitle': {'en': 'Omote-sando',
#        'ja': '表参道',
#        'ko': '오모테산도',
#        'ja-Hrkt': 'おもてさんどう',
#        'zh-Hans': '表参道',
#        'zh-Hant': '表參道'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Gaiemmae',
#       'odpt:stationTitle': {'en': 'Gaiemmae',
#        'ja': '外苑前',
#        'ko': '가이엔마에',
#        'ja-Hrkt': 'がいえんまえ',
#        'zh-Hans': '外苑前',
#        'zh-Hant': '外苑前'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.AoyamaItchome',
#       'odpt:stationTitle': {'en': 'Aoyama-itchome',
#        'ja': '青山一丁目',
#        'ko': '아오야마잇초메',
#        'ja-Hrkt': 'あおやまいっちょうめ',
#        'zh-Hans': '青山一丁目',
#        'zh-Hant': '青山一丁目'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.AkasakaMitsuke',
#       'odpt:stationTitle': {'en': 'Akasaka-mitsuke',
#        'ja': '赤坂見附',
#        'ko': '아카사카미쓰케',
#        'ja-Hrkt': 'あかさかみつけ',
#        'zh-Hans': '赤坂见附',
#        'zh-Hant': '赤坂見附'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.TameikeSanno',
#       'odpt:stationTitle': {'en': 'Tameike-sanno',
#        'ja': '溜池山王',
#        'ko': '다메이케산노',
#        'ja-Hrkt': 'ためいけさんのう',
#        'zh-Hans': '溜池山王',
#        'zh-Hant': '溜池山王'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Toranomon',
#       'odpt:stationTitle': {'en': 'Toranomon',
#        'ja': '虎ノ門',
#        'ko': '도라노몬',
#        'ja-Hrkt': 'とらのもん',
#        'zh-Hans': '虎之门',
#        'zh-Hant': '虎之門'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Shimbashi',
#       'odpt:stationTitle': {'en': 'Shimbashi',
#        'ja': '新橋',
#        'ko': '신바시',
#        'ja-Hrkt': 'しんばし',
#        'zh-Hans': '新桥',
#        'zh-Hant': '新橋'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Ginza',
#       'odpt:stationTitle': {'en': 'Ginza',
#        'ja': '銀座',
#        'ko': '긴자',
#        'ja-Hrkt': 'ぎんざ',
#        'zh-Hans': '银座',
#        'zh-Hant': '銀座'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Kyobashi',
#       'odpt:stationTitle': {'en': 'Kyobashi',
#        'ja': '京橋',
#        'ko': '교바시',
#        'ja-Hrkt': 'きょうばし',
#        'zh-Hans': '京桥',
#        'zh-Hant': '京橋'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Nihombashi',
#       'odpt:stationTitle': {'en': 'Nihombashi',
#        'ja': '日本橋',
#        'ko': '니혼바시',
#        'ja-Hrkt': 'にほんばし',
#        'zh-Hans': '日本桥',
#        'zh-Hant': '日本橋'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Mitsukoshimae',
#       'odpt:stationTitle': {'en': 'Mitsukoshimae',
#        'ja': '三越前',
#        'ko': '미쓰코시마에',
#        'ja-Hrkt': 'みつこしまえ',
#        'zh-Hans': '三越前',
#        'zh-Hant': '三越前'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Kanda',
#       'odpt:stationTitle': {'en': 'Kanda',
#        'ja': '神田',
#        'ko': '간다',
#        'ja-Hrkt': 'かんだ',
#        'zh-Hans': '神田',
#        'zh-Hant': '神田'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Suehirocho',
#       'odpt:stationTitle': {'en': 'Suehirocho',
#        'ja': '末広町',
#        'ko': '수에히로초',
#        'ja-Hrkt': 'すえひろちょう',
#        'zh-Hans': '末广町',
#        'zh-Hant': '末廣町'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.UenoHirokoji',
#       'odpt:stationTitle': {'en': 'Ueno-hirokoji',
#        'ja': '上野広小路',
#        'ko': '우에노히로코지',
#        'ja-Hrkt': 'うえのひろこうじ',
#        'zh-Hans': '上野广小路',
#        'zh-Hant': '上野廣小路'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Ueno',
#       'odpt:stationTitle': {'en': 'Ueno',
#        'ja': '上野',
#        'ko': '우에노',
#        'ja-Hrkt': 'うえの',
#        'zh-Hans': '上野',
#        'zh-Hant': '上野'}},
#      {'odpt:index': 17,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Inaricho',
#       'odpt:stationTitle': {'en': 'Inaricho',
#        'ja': '稲荷町',
#        'ko': '이나리초',
#        'ja-Hrkt': 'いなりちょう',
#        'zh-Hans': '稻荷町',
#        'zh-Hant': '稻荷町'}},
#      {'odpt:index': 18,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Tawaramachi',
#       'odpt:stationTitle': {'en': 'Tawaramachi',
#        'ja': '田原町',
#        'ko': '다와라마치',
#        'ja-Hrkt': 'たわらまち',
#        'zh-Hans': '田原町',
#        'zh-Hant': '田原町'}},
#      {'odpt:index': 19,
#       'odpt:station': 'odpt.Station:TokyoMetro.Ginza.Asakusa',
#       'odpt:stationTitle': {'en': 'Asakusa',
#        'ja': '浅草',
#        'ko': '아사쿠사',
#        'ja-Hrkt': 'あさくさ',
#        'zh-Hans': '浅草',
#        'zh-Hant': '淺草'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.701035, 35.65945],
#      [139.712383, 35.665143],
#      [139.724075, 35.672956],
#      [139.738865, 35.678407],
#      [139.741695, 35.68538],
#      [139.751117, 35.695501],
#      [139.75756, 35.696021],
#      [139.764905, 35.686745],
#      [139.77308, 35.684928],
#      [139.785171, 35.683],
#      [139.799841, 35.682119],
#      [139.815667, 35.688704],
#      [139.814957, 35.697441],
#      [139.813735, 35.708467]]},
#    'properties': {'id': 'odpt.Railway:TokyoMetro.Hanzomon',
#     'name': '半蔵門線',
#     'odpt:operator': 'odpt.Operator:TokyoMetro',
#     'operator_name': '東京メトロ',
#     'odpt:lineCode': 'Z',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Shibuya',
#       'odpt:stationTitle': {'en': 'Shibuya',
#        'ja': '渋谷',
#        'ko': '시부야',
#        'ja-Hrkt': 'しぶや',
#        'zh-Hans': '涩谷',
#        'zh-Hant': '澀谷'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.OmoteSando',
#       'odpt:stationTitle': {'en': 'Omote-sando',
#        'ja': '表参道',
#        'ko': '오모테산도',
#        'ja-Hrkt': 'おもてさんどう',
#        'zh-Hans': '表参道',
#        'zh-Hant': '表參道'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.AoyamaItchome',
#       'odpt:stationTitle': {'en': 'Aoyama-itchome',
#        'ja': '青山一丁目',
#        'ko': '아오야마잇초메',
#        'ja-Hrkt': 'あおやまいっちょうめ',
#        'zh-Hans': '青山一丁目',
#        'zh-Hant': '青山一丁目'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:TokyoMetro.Hanzomon.Nagatacho',
#       'odpt:stationTitle': {'en': 'Nagatacho',
#        'ja': '永田町',
#        'ko': '나가타초',
#        'ja-Hrkt': 'ながたちょう',
#        'zh-Hans': '永田町',
#        'zh-Hant': '永田町'}},
#      {'odpt:index': 5,
# ...
#      [139.74235, 36.39006],
#      [139.74102, 36.40758],
#      [139.74745, 36.42979],
#      [139.74948, 36.4663],
#      [139.74527, 36.50688],
#      [139.74174, 36.53333],
#      [139.74478, 36.55683],
#      [139.73776, 36.58068],
#      [139.70778, 36.6194],
#      [139.71395, 36.65111],
#      [139.71221, 36.67656],
#      [139.69277, 36.7256],
#      [139.68086, 36.72801],
#      [139.61993, 36.74809]]},
#    'properties': {'id': 'odpt.Railway:Tobu.Nikko',
#     'name': '日光線',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'operator_name': '東武鉄道',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.TobuDobutsuKoen',
#       'odpt:stationTitle': {'en': 'Tobu-dobutsu-koen',
#        'ja': '東武動物公園',
#        'ko': '도부도부쓰코엔',
#        'ja-Hrkt': 'とうぶどうぶつこうえん',
#        'zh-Hans': '东武动物公园',
#        'zh-Hant': '東武動物公園'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.SugitoTakanodai',
#       'odpt:stationTitle': {'en': 'Sugito-takanodai',
#        'ja': '杉戸高野台',
#        'ko': '스기토타카노다이',
#        'ja-Hrkt': 'すぎとたかのだい',
#        'zh-Hans': '杉户高野台',
#        'zh-Hant': '杉戶高野台'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Satte',
#       'odpt:stationTitle': {'en': 'Satte',
#        'ja': '幸手',
#        'ko': '삿테',
#        'ja-Hrkt': 'さって',
#        'zh-Hans': '幸手',
#        'zh-Hant': '幸手'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.MinamiKurihashi',
#       'odpt:stationTitle': {'en': 'Minami-kurihashi',
#        'ja': '南栗橋',
#        'ko': '미나미쿠리하시',
#        'ja-Hrkt': 'みなみくりはし',
#        'zh-Hans': '南栗桥',
#        'zh-Hant': '南栗橋'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Kurihashi',
#       'odpt:stationTitle': {'en': 'Kurihashi',
#        'ja': '栗橋',
#        'ko': '구리하시',
#        'ja-Hrkt': 'くりはし',
#        'zh-Hans': '栗桥',
#        'zh-Hant': '栗橋'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.ShinKoga',
#       'odpt:stationTitle': {'en': 'Shin-koga',
#        'ja': '新古河',
#        'ko': '신코가',
#        'ja-Hrkt': 'しんこが',
#        'zh-Hans': '新古河',
#        'zh-Hant': '新古河'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Yagyu',
#       'odpt:stationTitle': {'en': 'Yagyu',
#        'ja': '柳生',
#        'ko': '야규',
#        'ja-Hrkt': 'やぎゅう',
#        'zh-Hans': '柳生',
#        'zh-Hant': '柳生'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.ItakuraToyodaimae',
#       'odpt:stationTitle': {'en': 'Itakura-toyodaimae',
#        'ja': '板倉東洋大前',
#        'ko': '이타쿠라토요다이마에',
#        'ja-Hrkt': 'いたくらとうようだいまえ',
#        'zh-Hans': '板仓东洋大前',
#        'zh-Hant': '板倉東洋大前'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Fujioka',
#       'odpt:stationTitle': {'en': 'Fujioka',
#        'ja': '藤岡',
#        'ko': '후지오카',
#        'ja-Hrkt': 'ふじおか',
#        'zh-Hans': '藤冈',
#        'zh-Hant': '藤岡'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Shizuwa',
#       'odpt:stationTitle': {'en': 'Shizuwa',
#        'ja': '静和',
#        'ko': '시즈와',
#        'ja-Hrkt': 'しずわ',
#        'zh-Hans': '静和',
#        'zh-Hant': '靜和'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.ShinOhirashita',
#       'odpt:stationTitle': {'en': 'Shin-ohirashita',
#        'ja': '新大平下',
#        'ko': '신오히라시타',
#        'ja-Hrkt': 'しんおおひらした',
#        'zh-Hans': '新大平下',
#        'zh-Hant': '新大平下'}},
#      {'odpt:index': 12,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Tochigi',
#       'odpt:stationTitle': {'en': 'Tochigi',
#        'ja': '栃木',
#        'ko': '도치기',
#        'ja-Hrkt': 'とちぎ',
#        'zh-Hans': '枥木',
#        'zh-Hant': '櫔木'}},
#      {'odpt:index': 13,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.ShinTochigi',
#       'odpt:stationTitle': {'en': 'Shin-tochigi',
#        'ja': '新栃木',
#        'ko': '신토치기',
#        'ja-Hrkt': 'しんとちぎ',
#        'zh-Hans': '新枥木',
#        'zh-Hant': '新櫔木'}},
#      {'odpt:index': 14,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Kassemba',
#       'odpt:stationTitle': {'en': 'Kassemba',
#        'ja': '合戦場',
#        'ko': '갓센바',
#        'ja-Hrkt': 'かっせんば',
#        'zh-Hans': '合战场',
#        'zh-Hant': '合戰場'}},
#      {'odpt:index': 15,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Ienaka',
#       'odpt:stationTitle': {'en': 'Ienaka',
#        'ja': '家中',
#        'ko': '이에나카',
#        'ja-Hrkt': 'いえなか',
#        'zh-Hans': '家中',
#        'zh-Hant': '家中'}},
#      {'odpt:index': 16,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.TobuKanasaki',
#       'odpt:stationTitle': {'en': 'Tobu-kanasaki',
#        'ja': '東武金崎',
#        'ko': '도부카나사키',
#        'ja-Hrkt': 'とうぶかなさき',
#        'zh-Hans': '东武金崎',
#        'zh-Hant': '東武金崎'}},
#      {'odpt:index': 17,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Niregi',
#       'odpt:stationTitle': {'en': 'Niregi',
#        'ja': '楡木',
#        'ko': '니레기',
#        'ja-Hrkt': 'にれぎ',
#        'zh-Hans': '榆木',
#        'zh-Hant': '榆木'}},
#      {'odpt:index': 18,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Momiyama',
#       'odpt:stationTitle': {'en': 'Momiyama',
#        'ja': '樅山',
#        'ko': '모미야마',
#        'ja-Hrkt': 'もみやま',
#        'zh-Hans': '枞山',
#        'zh-Hant': '樅山'}},
#      {'odpt:index': 19,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.ShinKanuma',
#       'odpt:stationTitle': {'en': 'Shin-kanuma',
#        'ja': '新鹿沼',
#        'ko': '신카누마',
#        'ja-Hrkt': 'しんかぬま',
#        'zh-Hans': '新鹿沼',
#        'zh-Hant': '新鹿沼'}},
#      {'odpt:index': 20,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.KitaKanuma',
#       'odpt:stationTitle': {'en': 'Kita-kanuma',
#        'ja': '北鹿沼',
#        'ko': '기타카누마',
#        'ja-Hrkt': 'きたかぬま',
#        'zh-Hans': '北鹿沼',
#        'zh-Hant': '北鹿沼'}},
#      {'odpt:index': 21,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Itaga',
#       'odpt:stationTitle': {'en': 'Itaga',
#        'ja': '板荷',
#        'ko': '이타가',
#        'ja-Hrkt': 'いたが',
#        'zh-Hans': '板荷',
#        'zh-Hant': '板荷'}},
#      {'odpt:index': 22,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.ShimoGoshiro',
#       'odpt:stationTitle': {'en': 'Shimo-goshiro',
#        'ja': '下小代',
#        'ko': '시모고시로',
#        'ja-Hrkt': 'しもごしろ',
#        'zh-Hans': '下小代',
#        'zh-Hant': '下小代'}},
#      {'odpt:index': 23,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.Myojin',
#       'odpt:stationTitle': {'en': 'Myojin',
#        'ja': '明神',
#        'ko': '묘진',
#        'ja-Hrkt': 'みょうじん',
#        'zh-Hans': '明神',
#        'zh-Hant': '明神'}},
#      {'odpt:index': 24,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.ShimoImaichi',
#       'odpt:stationTitle': {'en': 'Shimo-imaichi',
#        'ja': '下今市',
#        'ko': '시모이마이치',
#        'ja-Hrkt': 'しもいまいち',
#        'zh-Hans': '下今市',
#        'zh-Hant': '下今市'}},
#      {'odpt:index': 25,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.KamiImaichi',
#       'odpt:stationTitle': {'en': 'Kami-imaichi',
#        'ja': '上今市',
#        'ko': '가미이마이치',
#        'ja-Hrkt': 'かみいまいち',
#        'zh-Hans': '上今市',
#        'zh-Hant': '上今市'}},
#      {'odpt:index': 26,
#       'odpt:station': 'odpt.Station:Tobu.Nikko.TobuNikko',
#       'odpt:stationTitle': {'en': 'Tobu-nikko',
#        'ja': '東武日光',
#        'ko': '도부닛코',
#        'ja-Hrkt': 'とうぶにっこう',
#        'zh-Hans': '东武日光',
#        'zh-Hant': '東武日光'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.39391, 35.95724],
#      [139.37008, 35.94022],
#      [139.35646, 35.93176],
#      [139.34648, 35.93761],
#      [139.32619, 35.94199],
#      [139.31533, 35.94715],
#      [139.30928, 35.9522],
#      [139.29961, 35.9628]]},
#    'properties': {'id': 'odpt.Railway:Tobu.Ogose',
#     'name': '越生線',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'operator_name': '東武鉄道',
#     'odpt:lineCode': 'TJ',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:Tobu.Ogose.Sakado',
#       'odpt:stationTitle': {'en': 'Sakado',
#        'ja': '坂戸',
#        'ko': '사카도',
#        'ja-Hrkt': 'さかど',
#        'zh-Hans': '坂户',
#        'zh-Hant': '坂戶'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:Tobu.Ogose.Ippommatsu',
#       'odpt:stationTitle': {'en': 'Ippommatsu',
#        'ja': '一本松',
#        'ko': '잇폰마쓰',
#        'ja-Hrkt': 'いっぽんまつ',
#        'zh-Hans': '一本松',
#        'zh-Hant': '一本松'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:Tobu.Ogose.NishiOya',
#       'odpt:stationTitle': {'en': 'Nishi-oya',
#        'ja': '西大家',
#        'ko': '니시오야',
#        'ja-Hrkt': 'にしおおや',
#        'zh-Hans': '西大家',
#        'zh-Hant': '西大家'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:Tobu.Ogose.Kawakado',
#       'odpt:stationTitle': {'en': 'Kawakado',
#        'ja': '川角',
#        'ko': '가와카도',
#        'ja-Hrkt': 'かわかど',
#        'zh-Hans': '川角',
#        'zh-Hant': '川角'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:Tobu.Ogose.BushuNagase',
#       'odpt:stationTitle': {'en': 'Bushu-nagase',
#        'ja': '武州長瀬',
#        'ko': '부슈나가세',
#        'ja-Hrkt': 'ぶしゅうながせ',
#        'zh-Hans': '武州长濑',
#        'zh-Hant': '武州長瀨'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:Tobu.Ogose.HigashiMoro',
#       'odpt:stationTitle': {'en': 'Higashi-moro',
#        'ja': '東毛呂',
#        'ko': '히가시모로',
#        'ja-Hrkt': 'ひがしもろ',
#        'zh-Hans': '东毛吕',
#        'zh-Hant': '東毛呂'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:Tobu.Ogose.BushuKarasawa',
#       'odpt:stationTitle': {'en': 'Bushu-karasawa',
#        'ja': '武州唐沢',
#        'ko': '부슈카라사와',
#        'ja-Hrkt': 'ぶしゅうからさわ',
#        'zh-Hans': '武州唐沢',
#        'zh-Hant': '武州唐澤'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:Tobu.Ogose.Ogose',
#       'odpt:stationTitle': {'en': 'Ogose',
#        'ja': '越生',
#        'ko': '오고세',
#        'ja-Hrkt': 'おごせ',
#        'zh-Hans': '越生',
#        'zh-Hant': '越生'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.52781, 36.24662],
#      [139.53748, 36.26184],
#      [139.56491, 36.29022],
#      [139.5759, 36.30624],
#      [139.57913, 36.31684],
#      [139.58033, 36.32844],
#      [139.57935, 36.34562],
#      [139.58191, 36.36707],
#      [139.59296, 36.37808],
#      [139.60928, 36.39788]]},
#    'properties': {'id': 'odpt.Railway:Tobu.Sano',
#     'name': '佐野線',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'operator_name': '東武鉄道',
#     'odpt:lineCode': 'TI',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Tatebayashi',
#       'odpt:stationTitle': {'en': 'Tatebayashi',
#        'ja': '館林',
#        'ko': '다테바야시',
#        'ja-Hrkt': 'たてばやし',
#        'zh-Hans': '馆林',
#        'zh-Hant': '館林'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Watarase',
#       'odpt:stationTitle': {'en': 'Watarase',
#        'ja': '渡瀬',
#        'ko': '와타라세',
#        'ja-Hrkt': 'わたらせ',
#        'zh-Hans': '渡濑',
#        'zh-Hant': '渡瀨'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Tajima',
#       'odpt:stationTitle': {'en': 'Tajima',
#        'ja': '田島',
#        'ko': '다지마',
#        'ja-Hrkt': 'たじま',
#        'zh-Hans': '田岛',
#        'zh-Hant': '田島'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Sanoshi',
#       'odpt:stationTitle': {'en': 'Sanoshi',
#        'ja': '佐野市',
#        'ko': '사노시',
#        'ja-Hrkt': 'さのし',
#        'zh-Hans': '佐野市',
#        'zh-Hant': '佐野市'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Sano',
#       'odpt:stationTitle': {'en': 'Sano',
#        'ja': '佐野',
#        'ko': '사노',
#        'ja-Hrkt': 'さの',
#        'zh-Hans': '佐野',
#        'zh-Hant': '佐野'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Horigome',
#       'odpt:stationTitle': {'en': 'Horigome',
#        'ja': '堀米',
#        'ko': '호리고메',
#        'ja-Hrkt': 'ほりごめ',
#        'zh-Hans': '堀米',
#        'zh-Hant': '堀米'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Yoshimizu',
#       'odpt:stationTitle': {'en': 'Yoshimizu',
#        'ja': '吉水',
#        'ko': '요시미즈',
#        'ja-Hrkt': 'よしみず',
#        'zh-Hans': '吉水',
#        'zh-Hant': '吉水'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Tanuma',
#       'odpt:stationTitle': {'en': 'Tanuma',
#        'ja': '田沼',
#        'ko': '다누마',
#        'ja-Hrkt': 'たぬま',
#        'zh-Hans': '田沼',
#        'zh-Hant': '田沼'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Tada',
#       'odpt:stationTitle': {'en': 'Tada',
#        'ja': '多田',
#        'ko': '다다',
#        'ja-Hrkt': 'ただ',
#        'zh-Hans': '多田',
#        'zh-Hant': '多田'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:Tobu.Sano.Kuzu',
#       'odpt:stationTitle': {'en': 'Kuzu',
#        'ja': '葛生',
#        'ko': '구즈우',
#        'ja-Hrkt': 'くずう',
#        'zh-Hans': '葛生',
#        'zh-Hant': '葛生'}}]}},
#   {'type': 'Feature',
#    'geometry': {'type': 'LineString',
#     'coordinates': [[139.74235, 36.39006],
#      [139.75378, 36.40156],
#      [139.77259, 36.40877],
#      [139.80501, 36.42243],
#      [139.82385, 36.45145],
#      [139.82954, 36.46674],
#      [139.83562, 36.48565],
#      [139.8503, 36.51425],
#      [139.86082, 36.53096],
#      [139.87195, 36.54371],
#      [139.8806, 36.55866]]},
#    'properties': {'id': 'odpt.Railway:Tobu.Utsunomiya',
#     'name': '宇都宮線',
#     'odpt:operator': 'odpt.Operator:Tobu',
#     'operator_name': '東武鉄道',
#     'odpt:lineCode': 'TN',
#     'odpt:stationOrder': [{'odpt:index': 1,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.ShinTochigi',
#       'odpt:stationTitle': {'en': 'Shin-tochigi',
#        'ja': '新栃木',
#        'ko': '신토치기',
#        'ja-Hrkt': 'しんとちぎ',
#        'zh-Hans': '新枥木',
#        'zh-Hant': '新櫔木'}},
#      {'odpt:index': 2,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.YashuHirakawa',
#       'odpt:stationTitle': {'en': 'Yashu-hirakawa',
#        'ja': '野州平川',
#        'ko': '야슈히라카와',
#        'ja-Hrkt': 'やしゅうひらかわ',
#        'zh-Hans': '野州平川',
#        'zh-Hant': '野州平川'}},
#      {'odpt:index': 3,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.YashuOtsuka',
#       'odpt:stationTitle': {'en': 'Yashu-otsuka',
#        'ja': '野州大塚',
#        'ko': '야슈오쓰카',
#        'ja-Hrkt': 'やしゅうおおつか',
#        'zh-Hans': '野州大塚',
#        'zh-Hant': '野州大塚'}},
#      {'odpt:index': 4,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Mibu',
#       'odpt:stationTitle': {'en': 'Mibu',
#        'ja': '壬生',
#        'ko': '미부',
#        'ja-Hrkt': 'みぶ',
#        'zh-Hans': '壬生',
#        'zh-Hant': '壬生'}},
#      {'odpt:index': 5,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Kuniya',
#       'odpt:stationTitle': {'en': 'Kuniya',
#        'ja': '国谷',
#        'ko': '구니야',
#        'ja-Hrkt': 'くにや',
#        'zh-Hans': '国谷',
#        'zh-Hant': '國谷'}},
#      {'odpt:index': 6,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Omochanomachi',
#       'odpt:stationTitle': {'en': 'Omochanomachi',
#        'ja': 'おもちゃのまち',
#        'ko': '오모차노마치',
#        'ja-Hrkt': 'おもちゃのまち',
#        'zh-Hans': '玩具町',
#        'zh-Hant': '玩具町'}},
#      {'odpt:index': 7,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Yasuzuka',
#       'odpt:stationTitle': {'en': 'Yasuzuka',
#        'ja': '安塚',
#        'ko': '야스즈카',
#        'ja-Hrkt': 'やすづか',
#        'zh-Hans': '安塚',
#        'zh-Hant': '安塚'}},
#      {'odpt:index': 8,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Nishikawada',
#       'odpt:stationTitle': {'en': 'Nishikawada',
#        'ja': '西川田',
#        'ko': '니시카와다',
#        'ja-Hrkt': 'にしかわだ',
#        'zh-Hans': '西川田',
#        'zh-Hant': '西川田'}},
#      {'odpt:index': 9,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.Esojima',
#       'odpt:stationTitle': {'en': 'Esojima',
#        'ja': '江曽島',
#        'ko': '에소지마',
#        'ja-Hrkt': 'えそじま',
#        'zh-Hans': '江曾岛',
#        'zh-Hant': '江曾島'}},
#      {'odpt:index': 10,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.MinamiUtsunomiya',
#       'odpt:stationTitle': {'en': 'Minami-utsunomiya',
#        'ja': '南宇都宮',
#        'ko': '미나미우쓰노미야',
#        'ja-Hrkt': 'みなみうつのみや',
#        'zh-Hans': '南宇都宫',
#        'zh-Hant': '南宇都宮'}},
#      {'odpt:index': 11,
#       'odpt:station': 'odpt.Station:Tobu.Utsunomiya.TobuUtsunomiya',
#       'odpt:stationTitle': {'en': 'Tobu-utsunomiya',
#        'ja': '東武宇都宮',
#        'ko': '도부우쓰노미야',
#        'ja-Hrkt': 'とうぶうつのみや',
#        'zh-Hans': '东武宇都宫',
#        'zh-Hant': '東武宇都宮'}}]}}]}

# %%
with open(path_edit + 'Railway.geojson', 'w') as f:
    json.dump(railway_geojson, f)
